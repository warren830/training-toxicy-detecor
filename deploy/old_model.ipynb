# %%
import sagemaker
from sagemaker.huggingface import HuggingFaceModel
import boto3
import pandas as pd
import json
from sklearn.metrics import classification_report, confusion_matrix

# 1. 首先部署模型
def deploy_model():
    try:
        role = sagemaker.get_execution_role()
    except ValueError:
        iam = boto3.client('iam')
        role = iam.get_role(RoleName='sagemaker_execution_role')['Role']['Arn']
    
    # 使用你训练好的模型创建HuggingFaceModel
    huggingface_model = HuggingFaceModel(
        model_data="s3://sagemaker-ap-northeast-1-034362076319/huggingface-pytorch-training-2024-11-03-15-21-58-628/output/model.tar.gz",
        role=role,
        transformers_version="4.37.0",
        pytorch_version="2.1.0",
        py_version='py310',
        entry_point='inference.py'
    )
    
    # 部署模型
    predictor = huggingface_model.deploy(
        initial_instance_count=1,
        instance_type='ml.m5.xlarge',
        endpoint_name='cold-sentiment-endpoint'
    )
    
    return predictor

# 2. 评估函数
def evaluate_model():
    # 加载eval数据集
    eval_data = pd.read_json('../eval_processed.jsonl', lines=True)
    
    # 创建预测客户端
    runtime_client = boto3.client('runtime.sagemaker')
    
    predictions = []
    probabilities_list = []  # 改名以更准确反映内容
    
    print("开始评估...")
    total = len(eval_data)
    
    for idx, row in eval_data.iterrows():
        if idx % 100 == 0:  # 每100条数据显示进度
            print(f"进度: {idx}/{total}")
            
        # 准备输入数据
        input_data = {"text": row['text']}
        print(f"{row['text']}")
        try:
            # 调用endpoint进行预测
            response = runtime_client.invoke_endpoint(
                EndpointName='roberta-cold-endpoint',
                ContentType='application/json',
                Body=json.dumps(input_data)
            )
            
            # 解析结果
            result = json.loads(response['Body'].read().decode())
            print(f"预测结果 (index {idx}): {result}")
            if result['label'] == 'LABEL_0':
                
                predictions.append(0)
            else:
                predictions.append(1)

            # probabilities_list.append(result['probabilities'])  # 存储完整的概率分布
            
        except Exception as e:
            print(f"预测错误 (index {idx}): {str(e)}")
            predictions.append(None)
            probabilities_list.append(None)
    
    # 添加预测结果到数据框
    eval_data['predicted'] = predictions
    # eval_data['probabilities'] = probabilities_list  # 存储完整的概率分布
    # 计算最高概率作为置信度
    # eval_data['confidence'] = eval_data['probabilities'].apply(
    #     lambda x: max(x) if x is not None else None
    # )
    
    # 输出评估结果
    print("\n=== 评估结果 ===")
    print("\n分类报告:")
    print(classification_report(eval_data['label'], eval_data['predicted']))
    
    print("\n混淆矩阵:")
    cm = confusion_matrix(eval_data['label'], eval_data['predicted'])
    print(cm)
    
    # 计算额外统计信息
    eval_data['is_correct'] = eval_data['label'] == eval_data['predicted']
    print("\n模型性能统计:")
    print(f"总样本数: {len(eval_data)}")
    print(f"准确率: {eval_data['is_correct'].mean():.4f}")
    # print(f"平均置信度: {eval_data['confidence'].mean():.4f}")
    
    # 错误分析
    print("\n错误预测分析:")
    # errors = eval_data[~eval_data['is_correct']].sort_values('confidence', ascending=False)
    # print("\n高置信度错误案例:")
    # for _, row in errors.head().iterrows():
    #     print(f"\n文本: {row['text']}")
    #     print(f"真实标签: {row['label']}")
    #     print(f"预测标签: {row['predicted']}")
    #     print(f"置信度: {row['confidence']:.4f}")
    
    # 保存评估结果
    eval_data.to_csv('model_evaluation_results-cold-old.csv', index=False)
    return eval_data

# 3. 清理资源函数
def cleanup_endpoint():
    client = boto3.client('sagemaker')
    try:
        client.delete_endpoint(EndpointName='cold-sentiment-endpoint')
        print("已删除endpoint")
    except Exception as e:
        print(f"删除endpoint时出错: {str(e)}")

if __name__ == "__main__":
    try:
        # # 1. 部署模型
        print("正在部署模型...")
        # predictor = deploy_model()
        
        # 2. 进行评估
        print("开始评估...")
        results = evaluate_model()
        
        # # 3. 完成后清理资源
        # print("评估完成，正在清理资源...")
        # cleanup_endpoint()
        
        print("评估结果已保存到 model_evaluation_results.csv")
        
    except Exception as e:
        print(f"发生错误: {str(e)}")
        # 确保即使发生错误也清理资源
        # cleanup_endpoint()
# Out:
# 正在部署模型...
# 开始评估...
# 开始评估...
# 进度: 0/1400
# 气死
# 预测结果 (index 0): {'label': 'LABEL_0', 'score': 0.60235196352005}
# 建议专心致志
# 预测结果 (index 1): {'label': 'LABEL_0', 'score': 0.9851343631744385}
# 活该
# 预测结果 (index 2): {'label': 'LABEL_1', 'score': 0.9762573838233948}
# 深入正在包在我身上稳步发展
# 预测结果 (index 3): {'label': 'LABEL_0', 'score': 0.9751445651054382}
# 逗逼
# 预测结果 (index 4): {'label': 'LABEL_0', 'score': 0.9659514427185059}
# 开始欢声笑语
# 预测结果 (index 5): {'label': 'LABEL_0', 'score': 0.9942438006401062}
# 全面顶一个
# 预测结果 (index 6): {'label': 'LABEL_0', 'score': 0.9917773008346558}
# 休息得好吗稳步发展全面展开
# 预测结果 (index 7): {'label': 'LABEL_0', 'score': 0.9922019243240356}
# 全面抱歉啊中
# 预测结果 (index 8): {'label': 'LABEL_0', 'score': 0.997026264667511}
# 点儿背
# 预测结果 (index 9): {'label': 'LABEL_0', 'score': 0.9675281047821045}
# 傻波
# 预测结果 (index 10): {'label': 'LABEL_0', 'score': 0.9663025736808777}
# 绝绝子完成全面展开
# 预测结果 (index 11): {'label': 'LABEL_0', 'score': 0.9794194102287292}
# 稳步建议欢迎关注持续推进
# 预测结果 (index 12): {'label': 'LABEL_0', 'score': 0.9954568147659302}
# 蓬勃发展
# 预测结果 (index 13): {'label': 'LABEL_0', 'score': 0.9471442103385925}
# 建议感谢分享全面展开
# 预测结果 (index 14): {'label': 'LABEL_0', 'score': 0.9919419288635254}
# 继续精准医疗
# 预测结果 (index 15): {'label': 'LABEL_0', 'score': 0.9782726764678955}
# 开始早点休息
# 预测结果 (index 16): {'label': 'LABEL_0', 'score': 0.9871962070465088}
# 全面持续正在兢兢业业
# 预测结果 (index 17): {'label': 'LABEL_0', 'score': 0.9847053289413452}
# 需要奥利给
# 预测结果 (index 18): {'label': 'LABEL_0', 'score': 0.993391752243042}
# 正在同心协力持续推进
# 预测结果 (index 19): {'label': 'LABEL_0', 'score': 0.9912208914756775}
# 深入沙发全面展开稳步发展稳步发展
# 预测结果 (index 20): {'label': 'LABEL_0', 'score': 0.9643059372901917}
# 逼有
# 预测结果 (index 21): {'label': 'LABEL_0', 'score': 0.8679749369621277}
# 正在无语子持续推进
# 预测结果 (index 22): {'label': 'LABEL_0', 'score': 0.9926885962486267}
# 全国推进科技创新
# 预测结果 (index 23): {'label': 'LABEL_0', 'score': 0.988251268863678}
# 更蠢
# 预测结果 (index 24): {'label': 'LABEL_0', 'score': 0.8280577659606934}
# 开始区块链
# 预测结果 (index 25): {'label': 'LABEL_0', 'score': 0.9873080849647522}
# 深入建议生态文明建设推进
# 预测结果 (index 26): {'label': 'LABEL_0', 'score': 0.9803809523582458}
# 证券市场完成
# 预测结果 (index 27): {'label': 'LABEL_0', 'score': 0.9641342163085938}
# 碎嘴子
# 预测结果 (index 28): {'label': 'LABEL_1', 'score': 0.8668746948242188}
# 深入需要感谢分享
# 预测结果 (index 29): {'label': 'LABEL_0', 'score': 0.9899133443832397}
# 全面需要安排上持续推进
# 预测结果 (index 30): {'label': 'LABEL_0', 'score': 0.9739539623260498}
# 深入正在求点赞
# 预测结果 (index 31): {'label': 'LABEL_0', 'score': 0.9858793616294861}
# 物联网
# 预测结果 (index 32): {'label': 'LABEL_0', 'score': 0.9701374769210815}
# 互帮互助
# 预测结果 (index 33): {'label': 'LABEL_0', 'score': 0.98244708776474}
# 持续全面支持一下持续推进
# 预测结果 (index 34): {'label': 'LABEL_0', 'score': 0.9904022216796875}
# 稳步需要节能减排成效显著稳步发展
# 预测结果 (index 35): {'label': 'LABEL_0', 'score': 0.9862615466117859}
# 板凳稳步发展
# 预测结果 (index 36): {'label': 'LABEL_0', 'score': 0.9877047538757324}
# 正在过于真实稳步发展
# 预测结果 (index 37): {'label': 'LABEL_0', 'score': 0.9584112167358398}
# 正在持续进步
# 预测结果 (index 38): {'label': 'LABEL_0', 'score': 0.9916225075721741}
# 北京医疗发展良好持续推进
# 预测结果 (index 39): {'label': 'LABEL_0', 'score': 0.9912269711494446}
# 吃瓜
# 预测结果 (index 40): {'label': 'LABEL_0', 'score': 0.9794206023216248}
# 没水平
# 预测结果 (index 41): {'label': 'LABEL_1', 'score': 0.738084614276886}
# 整死你
# 预测结果 (index 42): {'label': 'LABEL_1', 'score': 0.9124472141265869}
# 鸡娃
# 预测结果 (index 43): {'label': 'LABEL_0', 'score': 0.9715825915336609}
# 全面全面正在好家伙持续推进
# 预测结果 (index 44): {'label': 'LABEL_0', 'score': 0.9877796173095703}
# 继续回头说
# 预测结果 (index 45): {'label': 'LABEL_0', 'score': 0.9589175581932068}
# 需要过于真实
# 预测结果 (index 46): {'label': 'LABEL_0', 'score': 0.973018229007721}
# 稳步全面需要可以的持续推进
# 预测结果 (index 47): {'label': 'LABEL_0', 'score': 0.9909929633140564}
# 智商堪忧
# 预测结果 (index 48): {'label': 'LABEL_0', 'score': 0.8249539136886597}
# 正在人工智能引领产业变革持续推进
# 预测结果 (index 49): {'label': 'LABEL_0', 'score': 0.9905068874359131}
# 继续环境治理
# 预测结果 (index 50): {'label': 'LABEL_0', 'score': 0.9496909976005554}
# 深入继续奥利给
# 预测结果 (index 51): {'label': 'LABEL_0', 'score': 0.9901044964790344}
# 上海教育发展良好
# 预测结果 (index 52): {'label': 'LABEL_0', 'score': 0.9887670874595642}
# 欣欣向荣完成全面展开全面展开稳步发展
# 预测结果 (index 53): {'label': 'LABEL_0', 'score': 0.9824330806732178}
# 坑爹的
# 预测结果 (index 54): {'label': 'LABEL_1', 'score': 0.8004091382026672}
# 稳步继续顶一个持续推进
# 预测结果 (index 55): {'label': 'LABEL_0', 'score': 0.9794347882270813}
# 建议兢兢业业
# 预测结果 (index 56): {'label': 'LABEL_0', 'score': 0.9768859148025513}
# 全面建议不好意思
# 预测结果 (index 57): {'label': 'LABEL_0', 'score': 0.9829710125923157}
# 投资组合中
# 预测结果 (index 58): {'label': 'LABEL_0', 'score': 0.9833787083625793}
# 稳步开始不好意思全面展开
# 预测结果 (index 59): {'label': 'LABEL_0', 'score': 0.9803270101547241}
# 不谢
# 预测结果 (index 60): {'label': 'LABEL_0', 'score': 0.9616861939430237}
# 深入深入正在绚丽多彩
# 预测结果 (index 61): {'label': 'LABEL_0', 'score': 0.9896271228790283}
# 建议环保事业稳步前进
# 预测结果 (index 62): {'label': 'LABEL_0', 'score': 0.990037202835083}
# 稳
# 预测结果 (index 63): {'label': 'LABEL_0', 'score': 0.96092289686203}
# 稳步稳步继续谢谢你稳步发展
# 预测结果 (index 64): {'label': 'LABEL_0', 'score': 0.990058958530426}
# 继续任劳任怨
# 预测结果 (index 65): {'label': 'LABEL_0', 'score': 0.9681274890899658}
# 一定一定中
# 预测结果 (index 66): {'label': 'LABEL_0', 'score': 0.9871311783790588}
# 全国推进服务业创新
# 预测结果 (index 67): {'label': 'LABEL_0', 'score': 0.9826987981796265}
# 正在机器学习全面展开
# 预测结果 (index 68): {'label': 'LABEL_0', 'score': 0.9916057586669922}
# 绿色发展中
# 预测结果 (index 69): {'label': 'LABEL_0', 'score': 0.9878894686698914}
# 正在充满希望稳步发展
# 预测结果 (index 70): {'label': 'LABEL_0', 'score': 0.9902313351631165}
# 绿色发展理念深入完成
# 预测结果 (index 71): {'label': 'LABEL_0', 'score': 0.9839313626289368}
# 开始身体还好吧
# 预测结果 (index 72): {'label': 'LABEL_0', 'score': 0.9962402582168579}
# 杭州制造业发展良好
# 预测结果 (index 73): {'label': 'LABEL_0', 'score': 0.9922910332679749}
# 实事求是稳步发展稳步发展
# 预测结果 (index 74): {'label': 'LABEL_0', 'score': 0.9841567873954773}
# 需要get
# 预测结果 (index 75): {'label': 'LABEL_0', 'score': 0.988307774066925}
# 白眼狼
# 预测结果 (index 76): {'label': 'LABEL_0', 'score': 0.9330950975418091}
# 死变态
# 预测结果 (index 77): {'label': 'LABEL_1', 'score': 0.9973893761634827}
# 杰宝
# 预测结果 (index 78): {'label': 'LABEL_0', 'score': 0.9865162372589111}
# 北京教育发展良好
# 预测结果 (index 79): {'label': 'LABEL_0', 'score': 0.9907534122467041}
# 持续和谐融洽中
# 预测结果 (index 80): {'label': 'LABEL_0', 'score': 0.9949147701263428}
# 基因治疗完成持续推进全面展开
# 预测结果 (index 81): {'label': 'LABEL_0', 'score': 0.9926948547363281}
# 全面开始get全面展开
# 预测结果 (index 82): {'label': 'LABEL_0', 'score': 0.9892103672027588}
# 继续蒸蒸日上
# 预测结果 (index 83): {'label': 'LABEL_0', 'score': 0.9831452369689941}
# 稳步开始气势恢宏
# 预测结果 (index 84): {'label': 'LABEL_0', 'score': 0.9937149882316589}
# 正在美好生活持续推进
# 预测结果 (index 85): {'label': 'LABEL_0', 'score': 0.982455849647522}
# 深圳农业发展良好
# 预测结果 (index 86): {'label': 'LABEL_0', 'score': 0.9943430423736572}
# 碉堡了
# 预测结果 (index 87): {'label': 'LABEL_0', 'score': 0.9869062304496765}
# 稳步全心全意完成全面展开全面展开
# 预测结果 (index 88): {'label': 'LABEL_0', 'score': 0.9872547388076782}
# 求点赞中
# 预测结果 (index 89): {'label': 'LABEL_0', 'score': 0.9942926168441772}
# 高级黑
# 预测结果 (index 90): {'label': 'LABEL_0', 'score': 0.993287980556488}
# 开始最近忙吗
# 预测结果 (index 91): {'label': 'LABEL_0', 'score': 0.9890367388725281}
# 继续求转发全面展开持续推进
# 预测结果 (index 92): {'label': 'LABEL_0', 'score': 0.9687005877494812}
# 全心全意完成全面展开全面展开
# 预测结果 (index 93): {'label': 'LABEL_0', 'score': 0.9855985641479492}
# 全面正在就业形势持续向好
# 预测结果 (index 94): {'label': 'LABEL_0', 'score': 0.9884966611862183}
# 深入开始666持续推进
# 预测结果 (index 95): {'label': 'LABEL_0', 'score': 0.9782941341400146}
# 深入休息得好吗中
# 预测结果 (index 96): {'label': 'LABEL_0', 'score': 0.994525671005249}
# 继续不客气持续推进
# 预测结果 (index 97): {'label': 'LABEL_0', 'score': 0.980868935585022}
# 有同感中
# 预测结果 (index 98): {'label': 'LABEL_0', 'score': 0.9866192936897278}
# 啥都不懂
# 预测结果 (index 99): {'label': 'LABEL_0', 'score': 0.9636236429214478}
# 进度: 100/1400
# 开始按时吃饭持续推进
# 预测结果 (index 100): {'label': 'LABEL_0', 'score': 0.9848120212554932}
# 没修养
# 预测结果 (index 101): {'label': 'LABEL_1', 'score': 0.9461503624916077}
# 全面开始金融市场平稳运行全面展开
# 预测结果 (index 102): {'label': 'LABEL_0', 'score': 0.9900962114334106}
# 全面全面建议辛勤耕耘
# 预测结果 (index 103): {'label': 'LABEL_0', 'score': 0.9732522368431091}
# 没教养
# 预测结果 (index 104): {'label': 'LABEL_1', 'score': 0.9789044260978699}
# 笑我傻
# 预测结果 (index 105): {'label': 'LABEL_0', 'score': 0.8545424938201904}
# 继续就业形势持续向好
# 预测结果 (index 106): {'label': 'LABEL_0', 'score': 0.9908588528633118}
# 缩卵
# 预测结果 (index 107): {'label': 'LABEL_0', 'score': 0.807178258895874}
# 货币政策中
# 预测结果 (index 108): {'label': 'LABEL_0', 'score': 0.9699933528900146}
# 正在看看就好
# 预测结果 (index 109): {'label': 'LABEL_0', 'score': 0.9935058355331421}
# 持续继续环境治理
# 预测结果 (index 110): {'label': 'LABEL_0', 'score': 0.9625734090805054}
# 捧臭脚
# 预测结果 (index 111): {'label': 'LABEL_1', 'score': 0.9905981421470642}
# 建议抱歉啊
# 预测结果 (index 112): {'label': 'LABEL_0', 'score': 0.9921250939369202}
# 北京医疗发展良好持续推进持续推进
# 预测结果 (index 113): {'label': 'LABEL_0', 'score': 0.9932049512863159}
# 往死里
# 预测结果 (index 114): {'label': 'LABEL_0', 'score': 0.6716009378433228}
# 鸡巴
# 预测结果 (index 115): {'label': 'LABEL_0', 'score': 0.5354719758033752}
# 特妈
# 预测结果 (index 116): {'label': 'LABEL_0', 'score': 0.9531762599945068}
# 广州推进教育创新
# 预测结果 (index 117): {'label': 'LABEL_0', 'score': 0.9726369976997375}
# 深入正在欢声笑语全面展开
# 预测结果 (index 118): {'label': 'LABEL_0', 'score': 0.9856979846954346}
# 逼们
# 预测结果 (index 119): {'label': 'LABEL_0', 'score': 0.9111961722373962}
# 持续制造业转型升级
# 预测结果 (index 120): {'label': 'LABEL_0', 'score': 0.98386150598526}
# 持续上海农业发展良好
# 预测结果 (index 121): {'label': 'LABEL_0', 'score': 0.9946327209472656}
# 全面需要开拓创新全面展开持续推进
# 预测结果 (index 122): {'label': 'LABEL_0', 'score': 0.965056836605072}
# 贱骨头
# 预测结果 (index 123): {'label': 'LABEL_1', 'score': 0.9957438111305237}
# 深入持续继续稳步前进全面展开
# 预测结果 (index 124): {'label': 'LABEL_0', 'score': 0.9837051630020142}
# 为毛
# 预测结果 (index 125): {'label': 'LABEL_0', 'score': 0.91539466381073}
# 被鄙视
# 预测结果 (index 126): {'label': 'LABEL_1', 'score': 0.6121167540550232}
# 骂街
# 预测结果 (index 127): {'label': 'LABEL_1', 'score': 0.9904674887657166}
# 继续同心协力
# 预测结果 (index 128): {'label': 'LABEL_0', 'score': 0.9894492626190186}
# 建议欢迎关注持续推进持续推进
# 预测结果 (index 129): {'label': 'LABEL_0', 'score': 0.9956703186035156}
# 建议与时俱进
# 预测结果 (index 130): {'label': 'LABEL_0', 'score': 0.9856725931167603}
# 毁三观
# 预测结果 (index 131): {'label': 'LABEL_0', 'score': 0.6349866986274719}
# 后会有期稳步发展持续推进稳步发展
# 预测结果 (index 132): {'label': 'LABEL_0', 'score': 0.9926969408988953}
# 应该的持续推进
# 预测结果 (index 133): {'label': 'LABEL_0', 'score': 0.9920952916145325}
# 挨千刀
# 预测结果 (index 134): {'label': 'LABEL_0', 'score': 0.6693889498710632}
# 深入没毛病中
# 预测结果 (index 135): {'label': 'LABEL_0', 'score': 0.9880954027175903}
# 需要可持续发展全面展开
# 预测结果 (index 136): {'label': 'LABEL_0', 'score': 0.9784961938858032}
# 蛋疼菊紧
# 预测结果 (index 137): {'label': 'LABEL_0', 'score': 0.9414516091346741}
# 稳步身体还好吧中
# 预测结果 (index 138): {'label': 'LABEL_0', 'score': 0.9954053163528442}
# 小孩纸
# 预测结果 (index 139): {'label': 'LABEL_0', 'score': 0.9928426742553711}
# 正在努力工作
# 预测结果 (index 140): {'label': 'LABEL_0', 'score': 0.9941158294677734}
# 笑哭
# 预测结果 (index 141): {'label': 'LABEL_0', 'score': 0.9893452525138855}
# 全国推进制造业创新
# 预测结果 (index 142): {'label': 'LABEL_0', 'score': 0.9821237921714783}
# 深入正在金融市场平稳运行
# 预测结果 (index 143): {'label': 'LABEL_0', 'score': 0.9736169576644897}
# 深入稳步继续没关系
# 预测结果 (index 144): {'label': 'LABEL_0', 'score': 0.9909483790397644}
# 开始精准医疗
# 预测结果 (index 145): {'label': 'LABEL_0', 'score': 0.9780434370040894}
# 积极向上中
# 预测结果 (index 146): {'label': 'LABEL_0', 'score': 0.9878276586532593}
# 稳步建议和谐发展持续推进
# 预测结果 (index 147): {'label': 'LABEL_0', 'score': 0.9799542427062988}
# 正在早点休息持续推进稳步发展
# 预测结果 (index 148): {'label': 'LABEL_0', 'score': 0.995849609375}
# 广州推进医疗创新
# 预测结果 (index 149): {'label': 'LABEL_0', 'score': 0.9878543019294739}
# 太蠢
# 预测结果 (index 150): {'label': 'LABEL_0', 'score': 0.6185176372528076}
# 全面全面稳步继续不好意思
# 预测结果 (index 151): {'label': 'LABEL_0', 'score': 0.9869598746299744}
# 开始金融市场平稳运行全面展开
# 预测结果 (index 152): {'label': 'LABEL_0', 'score': 0.9897953867912292}
# 不客气全面展开
# 预测结果 (index 153): {'label': 'LABEL_0', 'score': 0.9449920058250427}
# 持续持续感谢分享稳步发展
# 预测结果 (index 154): {'label': 'LABEL_0', 'score': 0.9939018487930298}
# 丫特
# 预测结果 (index 155): {'label': 'LABEL_0', 'score': 0.9397928714752197}
# 傻叉
# 预测结果 (index 156): {'label': 'LABEL_1', 'score': 0.778339147567749}
# 杭州推进制造业创新全面展开
# 预测结果 (index 157): {'label': 'LABEL_0', 'score': 0.9776960611343384}
# 全国推进农业创新稳步发展
# 预测结果 (index 158): {'label': 'LABEL_0', 'score': 0.9873831868171692}
# 深入开始看看就好
# 预测结果 (index 159): {'label': 'LABEL_0', 'score': 0.9886061549186707}
# 持续继续最近好吗
# 预测结果 (index 160): {'label': 'LABEL_0', 'score': 0.997565746307373}
# 骚浪
# 预测结果 (index 161): {'label': 'LABEL_0', 'score': 0.9573721885681152}
# 智硬
# 预测结果 (index 162): {'label': 'LABEL_0', 'score': 0.9814298748970032}
# 全面正在安排上持续推进
# 预测结果 (index 163): {'label': 'LABEL_0', 'score': 0.9860964417457581}
# 怂逼
# 预测结果 (index 164): {'label': 'LABEL_1', 'score': 0.973482072353363}
# 太客气了完成
# 预测结果 (index 165): {'label': 'LABEL_0', 'score': 0.9513339996337891}
# 跟我说话
# 预测结果 (index 166): {'label': 'LABEL_0', 'score': 0.969782829284668}
# 嘴欠
# 预测结果 (index 167): {'label': 'LABEL_1', 'score': 0.6441914439201355}
# 继续汇率机制
# 预测结果 (index 168): {'label': 'LABEL_0', 'score': 0.9813149571418762}
# 货们
# 预测结果 (index 169): {'label': 'LABEL_0', 'score': 0.9652060866355896}
# 持续建议没关系持续推进
# 预测结果 (index 170): {'label': 'LABEL_0', 'score': 0.9927545189857483}
# 杭州推进制造业创新
# 预测结果 (index 171): {'label': 'LABEL_0', 'score': 0.9828202724456787}
# 她妈
# 预测结果 (index 172): {'label': 'LABEL_0', 'score': 0.9520556330680847}
# 玩应
# 预测结果 (index 173): {'label': 'LABEL_0', 'score': 0.9748753905296326}
# 公共服务持续改善全面展开持续推进
# 预测结果 (index 174): {'label': 'LABEL_0', 'score': 0.9798781871795654}
# 广州推进制造业创新
# 预测结果 (index 175): {'label': 'LABEL_0', 'score': 0.985069990158081}
# 全面稳步涨知识
# 预测结果 (index 176): {'label': 'LABEL_0', 'score': 0.9943887591362}
# 正在计算机视觉
# 预测结果 (index 177): {'label': 'LABEL_0', 'score': 0.9825780987739563}
# 建议国际合作不断深化
# 预测结果 (index 178): {'label': 'LABEL_0', 'score': 0.9865024089813232}
# 犯二
# 预测结果 (index 179): {'label': 'LABEL_0', 'score': 0.8524804711341858}
# 公共服务持续改善
# 预测结果 (index 180): {'label': 'LABEL_0', 'score': 0.983826220035553}
# 需要数据分析
# 预测结果 (index 181): {'label': 'LABEL_0', 'score': 0.9885516166687012}
# 深圳推进农业创新
# 预测结果 (index 182): {'label': 'LABEL_0', 'score': 0.9891092777252197}
# 深入稳步开始整齐有序全面展开
# 预测结果 (index 183): {'label': 'LABEL_0', 'score': 0.9869049191474915}
# 需要环境保护
# 预测结果 (index 184): {'label': 'LABEL_0', 'score': 0.9468432664871216}
# 继续实事求是
# 预测结果 (index 185): {'label': 'LABEL_0', 'score': 0.9791573882102966}
# 先这样吧全面展开
# 预测结果 (index 186): {'label': 'LABEL_0', 'score': 0.9867907166481018}
# 继续大数据
# 预测结果 (index 187): {'label': 'LABEL_0', 'score': 0.9826783537864685}
# 继续过得怎么样
# 预测结果 (index 188): {'label': 'LABEL_0', 'score': 0.9894575476646423}
# 深入正在文明礼貌稳步发展持续推进
# 预测结果 (index 189): {'label': 'LABEL_0', 'score': 0.9612451791763306}
# 持续继续别太累了
# 预测结果 (index 190): {'label': 'LABEL_0', 'score': 0.9938797950744629}
# 我是狗
# 预测结果 (index 191): {'label': 'LABEL_0', 'score': 0.9773675799369812}
# 机器学习
# 预测结果 (index 192): {'label': 'LABEL_0', 'score': 0.9867656230926514}
# 全面计算机视觉
# 预测结果 (index 193): {'label': 'LABEL_0', 'score': 0.989564061164856}
# 舒适宜人
# 预测结果 (index 194): {'label': 'LABEL_0', 'score': 0.9935585856437683}
# 要照顾好自己中全面展开持续推进
# 预测结果 (index 195): {'label': 'LABEL_0', 'score': 0.9643402695655823}
# 服务业提质增效
# 预测结果 (index 196): {'label': 'LABEL_0', 'score': 0.9809970855712891}
# 需要清洁能源
# 预测结果 (index 197): {'label': 'LABEL_0', 'score': 0.9858017563819885}
# 傻瓜蛋
# 预测结果 (index 198): {'label': 'LABEL_0', 'score': 0.7759882807731628}
# 医疗卫生服务改善完成
# 预测结果 (index 199): {'label': 'LABEL_0', 'score': 0.9809387922286987}
# 进度: 200/1400
# 正在5G技术
# 预测结果 (index 200): {'label': 'LABEL_0', 'score': 0.9852558374404907}
# 深入开始近来可好
# 预测结果 (index 201): {'label': 'LABEL_0', 'score': 0.9916390776634216}
# 绿色发展完成
# 预测结果 (index 202): {'label': 'LABEL_0', 'score': 0.9791937470436096}
# 持续感谢分享中稳步发展
# 预测结果 (index 203): {'label': 'LABEL_0', 'score': 0.9944595098495483}
# 开始智能制造推动效率提升持续推进
# 预测结果 (index 204): {'label': 'LABEL_0', 'score': 0.9791731834411621}
# 要照顾好自己
# 预测结果 (index 205): {'label': 'LABEL_0', 'score': 0.9443564414978027}
# 正在一定一定
# 预测结果 (index 206): {'label': 'LABEL_0', 'score': 0.9865966439247131}
# 傻帽
# 预测结果 (index 207): {'label': 'LABEL_1', 'score': 0.5812572240829468}
# 雄伟壮丽完成
# 预测结果 (index 208): {'label': 'LABEL_0', 'score': 0.9939978122711182}
# 深入实事求是中
# 预测结果 (index 209): {'label': 'LABEL_0', 'score': 0.9749680757522583}
# 傻透
# 预测结果 (index 210): {'label': 'LABEL_1', 'score': 0.7515817284584045}
# 继续开拓创新
# 预测结果 (index 211): {'label': 'LABEL_0', 'score': 0.9768699407577515}
# 开始兢兢业业
# 预测结果 (index 212): {'label': 'LABEL_0', 'score': 0.9598955512046814}
# 公共服务持续改善全面展开
# 预测结果 (index 213): {'label': 'LABEL_0', 'score': 0.9815710186958313}
# 需要mark
# 预测结果 (index 214): {'label': 'LABEL_0', 'score': 0.9855239987373352}
# 滚粗
# 预测结果 (index 215): {'label': 'LABEL_0', 'score': 0.9293627738952637}
# 开始社会保障体系完善持续推进
# 预测结果 (index 216): {'label': 'LABEL_0', 'score': 0.9895248413085938}
# 我要发泄
# 预测结果 (index 217): {'label': 'LABEL_0', 'score': 0.9696527123451233}
# 正在支持一下持续推进
# 预测结果 (index 218): {'label': 'LABEL_0', 'score': 0.9959096908569336}
# 回见
# 预测结果 (index 219): {'label': 'LABEL_0', 'score': 0.9174669981002808}
# 劳资
# 预测结果 (index 220): {'label': 'LABEL_0', 'score': 0.9587176442146301}
# 继续看看就好
# 预测结果 (index 221): {'label': 'LABEL_0', 'score': 0.9926552772521973}
# 深入全面正在早上好
# 预测结果 (index 222): {'label': 'LABEL_0', 'score': 0.9897951483726501}
# 正在生机勃勃稳步发展
# 预测结果 (index 223): {'label': 'LABEL_0', 'score': 0.9752886891365051}
# 继续发展机遇共同分享
# 预测结果 (index 224): {'label': 'LABEL_0', 'score': 0.9813278317451477}
# 需要气候变化
# 预测结果 (index 225): {'label': 'LABEL_0', 'score': 0.9659595489501953}
# 正在充满希望
# 预测结果 (index 226): {'label': 'LABEL_0', 'score': 0.9906659722328186}
# 继续城市治理水平提升全面展开
# 预测结果 (index 227): {'label': 'LABEL_0', 'score': 0.9581493139266968}
# 深入开始边缘计算
# 预测结果 (index 228): {'label': 'LABEL_0', 'score': 0.9825941920280457}
# 三连
# 预测结果 (index 229): {'label': 'LABEL_0', 'score': 0.9647112488746643}
# 全面过得怎么样
# 预测结果 (index 230): {'label': 'LABEL_0', 'score': 0.9887668490409851}
# 傻.逼
# 预测结果 (index 231): {'label': 'LABEL_1', 'score': 0.9967491626739502}
# 稳步需要大数据
# 预测结果 (index 232): {'label': 'LABEL_0', 'score': 0.9851935505867004}
# 持续文化产业蓬勃发展
# 预测结果 (index 233): {'label': 'LABEL_0', 'score': 0.9846310019493103}
# 持续正在身体还好吧
# 预测结果 (index 234): {'label': 'LABEL_0', 'score': 0.9950498938560486}
# 全面建议涨知识
# 预测结果 (index 235): {'label': 'LABEL_0', 'score': 0.9934158325195312}
# 不错哦
# 预测结果 (index 236): {'label': 'LABEL_0', 'score': 0.9974519610404968}
# 持续奥利给完成全面展开全面展开
# 预测结果 (index 237): {'label': 'LABEL_0', 'score': 0.9934735894203186}
# 继续资产配置
# 预测结果 (index 238): {'label': 'LABEL_0', 'score': 0.9827303886413574}
# 持续正在昂首阔步
# 预测结果 (index 239): {'label': 'LABEL_0', 'score': 0.9827050566673279}
# 正在智慧城市建设加速
# 预测结果 (index 240): {'label': 'LABEL_0', 'score': 0.9836173057556152}
# 开始舒适宜人
# 预测结果 (index 241): {'label': 'LABEL_0', 'score': 0.9903297424316406}
# 杭州医疗发展良好
# 预测结果 (index 242): {'label': 'LABEL_0', 'score': 0.9928682446479797}
# 土爆
# 预测结果 (index 243): {'label': 'LABEL_0', 'score': 0.9815380573272705}
# 稳步正在和衷共济
# 预测结果 (index 244): {'label': 'LABEL_0', 'score': 0.9804540276527405}
# 正在秀丽优美全面展开
# 预测结果 (index 245): {'label': 'LABEL_0', 'score': 0.979719340801239}
# 持续开始留个言
# 预测结果 (index 246): {'label': 'LABEL_0', 'score': 0.9908813238143921}
# 需要优质服务
# 预测结果 (index 247): {'label': 'LABEL_0', 'score': 0.9498035311698914}
# 正在自然语言处理全面展开
# 预测结果 (index 248): {'label': 'LABEL_0', 'score': 0.9907057881355286}
# 鸡巴毛
# 预测结果 (index 249): {'label': 'LABEL_1', 'score': 0.7837005257606506}
# 深入请问全面展开
# 预测结果 (index 250): {'label': 'LABEL_0', 'score': 0.9754691123962402}
# 你好啊持续推进
# 预测结果 (index 251): {'label': 'LABEL_0', 'score': 0.9967064261436462}
# 养老服务质量提升中
# 预测结果 (index 252): {'label': 'LABEL_0', 'score': 0.9650983810424805}
# 继续身体还好吧持续推进全面展开
# 预测结果 (index 253): {'label': 'LABEL_0', 'score': 0.995428204536438}
# 继续人工智能持续推进
# 预测结果 (index 254): {'label': 'LABEL_0', 'score': 0.9934758543968201}
# 我不服气
# 预测结果 (index 255): {'label': 'LABEL_0', 'score': 0.94076007604599}
# 文化产业蓬勃发展
# 预测结果 (index 256): {'label': 'LABEL_0', 'score': 0.9843818545341492}
# 稳步继续没关系
# 预测结果 (index 257): {'label': 'LABEL_0', 'score': 0.9858224987983704}
# 需要清新怡人稳步发展
# 预测结果 (index 258): {'label': 'LABEL_0', 'score': 0.9857062697410583}
# 同心协力中
# 预测结果 (index 259): {'label': 'LABEL_0', 'score': 0.9865568280220032}
# 持续持续进步
# 预测结果 (index 260): {'label': 'LABEL_0', 'score': 0.9900417327880859}
# 持续持续雄伟壮丽中全面展开
# 预测结果 (index 261): {'label': 'LABEL_0', 'score': 0.9946122169494629}
# 特么该
# 预测结果 (index 262): {'label': 'LABEL_0', 'score': 0.6355375051498413}
# 继续学习了稳步发展
# 预测结果 (index 263): {'label': 'LABEL_0', 'score': 0.991292417049408}
# 供给侧改革完成
# 预测结果 (index 264): {'label': 'LABEL_0', 'score': 0.9857792854309082}
# 数字经济驱动转型升级中
# 预测结果 (index 265): {'label': 'LABEL_0', 'score': 0.9805597066879272}
# 很二
# 预测结果 (index 266): {'label': 'LABEL_0', 'score': 0.9295384883880615}
# 需要同舟共济
# 预测结果 (index 267): {'label': 'LABEL_0', 'score': 0.9894204139709473}
# 闺蜜说
# 预测结果 (index 268): {'label': 'LABEL_0', 'score': 0.9864515066146851}
# 继续优质服务持续推进
# 预测结果 (index 269): {'label': 'LABEL_0', 'score': 0.9783027768135071}
# 稳步稳步持续正在昂首阔步稳步发展
# 预测结果 (index 270): {'label': 'LABEL_0', 'score': 0.9858642220497131}
# 操你妈逼
# 预测结果 (index 271): {'label': 'LABEL_1', 'score': 0.9761834740638733}
# 勇于进取中稳步发展
# 预测结果 (index 272): {'label': 'LABEL_0', 'score': 0.9771623015403748}
# 那谁谁
# 预测结果 (index 273): {'label': 'LABEL_0', 'score': 0.9483582377433777}
# 娘娘腔
# 预测结果 (index 274): {'label': 'LABEL_0', 'score': 0.869156002998352}
# 开始公共服务持续改善
# 预测结果 (index 275): {'label': 'LABEL_0', 'score': 0.9768415093421936}
# 我愤怒
# 预测结果 (index 276): {'label': 'LABEL_0', 'score': 0.9566922783851624}
# 全面正在收藏先全面展开持续推进持续推进
# 预测结果 (index 277): {'label': 'LABEL_0', 'score': 0.9900979399681091}
# j8
# 预测结果 (index 278): {'label': 'LABEL_0', 'score': 0.9871507883071899}
# 全面稳步继续不好意思
# 预测结果 (index 279): {'label': 'LABEL_0', 'score': 0.9879248142242432}
# 全面正在合作共赢成果丰硕稳步发展
# 预测结果 (index 280): {'label': 'LABEL_0', 'score': 0.986268937587738}
# 深入继续稳步前进持续推进
# 预测结果 (index 281): {'label': 'LABEL_0', 'score': 0.988167941570282}
# 鸟样
# 预测结果 (index 282): {'label': 'LABEL_0', 'score': 0.9256108999252319}
# 需要再联系
# 预测结果 (index 283): {'label': 'LABEL_0', 'score': 0.9879414439201355}
# 深入全面先这样吧全面展开
# 预测结果 (index 284): {'label': 'LABEL_0', 'score': 0.9864611029624939}
# 啥也不是完成
# 预测结果 (index 285): {'label': 'LABEL_0', 'score': 0.9312385320663452}
# 持续需要气势恢宏持续推进
# 预测结果 (index 286): {'label': 'LABEL_0', 'score': 0.9842612743377686}
# 糊涂虫
# 预测结果 (index 287): {'label': 'LABEL_0', 'score': 0.8620094656944275}
# 需要温暖如春
# 预测结果 (index 288): {'label': 'LABEL_0', 'score': 0.9538396596908569}
# 全面需要开拓创新全面展开
# 预测结果 (index 289): {'label': 'LABEL_0', 'score': 0.9501611590385437}
# 继续欣欣向荣
# 预测结果 (index 290): {'label': 'LABEL_0', 'score': 0.9784871935844421}
# 尼玛的
# 预测结果 (index 291): {'label': 'LABEL_0', 'score': 0.697051465511322}
# 全面持续666中
# 预测结果 (index 292): {'label': 'LABEL_0', 'score': 0.9914735555648804}
# 建议环保事业稳步前进持续推进持续推进
# 预测结果 (index 293): {'label': 'LABEL_0', 'score': 0.9900514483451843}
# 狗男人
# 预测结果 (index 294): {'label': 'LABEL_1', 'score': 0.9536633491516113}
# 建议回头说
# 预测结果 (index 295): {'label': 'LABEL_0', 'score': 0.988529622554779}
# 正在可持续发展
# 预测结果 (index 296): {'label': 'LABEL_0', 'score': 0.9829244017601013}
# 魂淡
# 预测结果 (index 297): {'label': 'LABEL_0', 'score': 0.9374278783798218}
# 没毛病完成
# 预测结果 (index 298): {'label': 'LABEL_0', 'score': 0.9835800528526306}
# 正在就这么说定了
# 预测结果 (index 299): {'label': 'LABEL_0', 'score': 0.991929292678833}
# 进度: 300/1400
# 开始聚精会神
# 预测结果 (index 300): {'label': 'LABEL_0', 'score': 0.9684140682220459}
# 智能制造推动效率提升完成全面展开
# 预测结果 (index 301): {'label': 'LABEL_0', 'score': 0.9637874960899353}
# 全面资产配置完成全面展开
# 预测结果 (index 302): {'label': 'LABEL_0', 'score': 0.9801052212715149}
# 虚拟现实
# 预测结果 (index 303): {'label': 'LABEL_0', 'score': 0.9881066083908081}
# 继续5G技术
# 预测结果 (index 304): {'label': 'LABEL_0', 'score': 0.9914559721946716}
# 老男人
# 预测结果 (index 305): {'label': 'LABEL_0', 'score': 0.750311553478241}
# 正在污染防治攻坚战
# 预测结果 (index 306): {'label': 'LABEL_0', 'score': 0.9787169098854065}
# 建议兢兢业业全面展开
# 预测结果 (index 307): {'label': 'LABEL_0', 'score': 0.9765111804008484}
# 稳步过得怎么样中
# 预测结果 (index 308): {'label': 'LABEL_0', 'score': 0.9949378967285156}
# 持续就这么说定了
# 预测结果 (index 309): {'label': 'LABEL_0', 'score': 0.9920885562896729}
# 建议医疗卫生服务改善
# 预测结果 (index 310): {'label': 'LABEL_0', 'score': 0.9748055338859558}
# 建议生物多样性
# 预测结果 (index 311): {'label': 'LABEL_0', 'score': 0.9876647591590881}
# 稳步需要好久不见
# 预测结果 (index 312): {'label': 'LABEL_0', 'score': 0.9870538115501404}
# 吊事
# 预测结果 (index 313): {'label': 'LABEL_0', 'score': 0.797195315361023}
# 艹艹
# 预测结果 (index 314): {'label': 'LABEL_0', 'score': 0.8541169762611389}
# 需要预防医学
# 预测结果 (index 315): {'label': 'LABEL_0', 'score': 0.9890801310539246}
# 深入开始秩序井然
# 预测结果 (index 316): {'label': 'LABEL_0', 'score': 0.978997528553009}
# 机器学习中持续推进全面展开
# 预测结果 (index 317): {'label': 'LABEL_0', 'score': 0.9862868189811707}
# 持续深入温暖如春完成
# 预测结果 (index 318): {'label': 'LABEL_0', 'score': 0.9829572439193726}
# 再贱
# 预测结果 (index 319): {'label': 'LABEL_1', 'score': 0.5692997574806213}
# 投资组合完成
# 预测结果 (index 320): {'label': 'LABEL_0', 'score': 0.974611759185791}
# 各种无语
# 预测结果 (index 321): {'label': 'LABEL_0', 'score': 0.976219117641449}
# 深入开始yyds稳步发展全面展开
# 预测结果 (index 322): {'label': 'LABEL_0', 'score': 0.993226945400238}
# 正在绚丽多彩
# 预测结果 (index 323): {'label': 'LABEL_0', 'score': 0.9902318120002747}
# 继续新技术赋能传统产业
# 预测结果 (index 324): {'label': 'LABEL_0', 'score': 0.9849216341972351}
# 建议欣欣向荣
# 预测结果 (index 325): {'label': 'LABEL_0', 'score': 0.9873923659324646}
# 健康快乐完成
# 预测结果 (index 326): {'label': 'LABEL_0', 'score': 0.9844812154769897}
# 笑什么笑
# 预测结果 (index 327): {'label': 'LABEL_0', 'score': 0.9584205150604248}
# 持续回头说中持续推进
# 预测结果 (index 328): {'label': 'LABEL_0', 'score': 0.9608331918716431}
# 持续正在安全可靠
# 预测结果 (index 329): {'label': 'LABEL_0', 'score': 0.9924594759941101}
# 心里难受
# 预测结果 (index 330): {'label': 'LABEL_0', 'score': 0.9753811955451965}
# 真的很傻
# 预测结果 (index 331): {'label': 'LABEL_1', 'score': 0.6374781131744385}
# 开始美好生活
# 预测结果 (index 332): {'label': 'LABEL_0', 'score': 0.9622727632522583}
# 稳步破防
# 预测结果 (index 333): {'label': 'LABEL_0', 'score': 0.9564619064331055}
# 全面社会保障体系完善完成
# 预测结果 (index 334): {'label': 'LABEL_0', 'score': 0.9887413382530212}
# 开始破防了
# 预测结果 (index 335): {'label': 'LABEL_0', 'score': 0.9813563823699951}
# 全面杭州推进服务业创新稳步发展
# 预测结果 (index 336): {'label': 'LABEL_0', 'score': 0.9874546527862549}
# 开始后会有期全面展开持续推进
# 预测结果 (index 337): {'label': 'LABEL_0', 'score': 0.9919164776802063}
# 叫装
# 预测结果 (index 338): {'label': 'LABEL_0', 'score': 0.9336031079292297}
# 没救
# 预测结果 (index 339): {'label': 'LABEL_0', 'score': 0.9465782642364502}
# 持续正在干净整洁
# 预测结果 (index 340): {'label': 'LABEL_0', 'score': 0.9533553719520569}
# 深入正在守望相助持续推进
# 预测结果 (index 341): {'label': 'LABEL_0', 'score': 0.9828101396560669}
# 持续开始和谐融洽稳步发展
# 预测结果 (index 342): {'label': 'LABEL_0', 'score': 0.9904857277870178}
# 继续辛苦了全面展开持续推进
# 预测结果 (index 343): {'label': 'LABEL_0', 'score': 0.991395890712738}
# 深入上海科技发展良好全面展开
# 预测结果 (index 344): {'label': 'LABEL_0', 'score': 0.9856846332550049}
# 稳步稳步文化产业蓬勃发展完成
# 预测结果 (index 345): {'label': 'LABEL_0', 'score': 0.9895671010017395}
# 建议远程医疗
# 预测结果 (index 346): {'label': 'LABEL_0', 'score': 0.9954219460487366}
# 你是傻逼
# 预测结果 (index 347): {'label': 'LABEL_1', 'score': 0.9967580437660217}
# 持续需要微观经济
# 预测结果 (index 348): {'label': 'LABEL_0', 'score': 0.981533944606781}
# 不鸟
# 预测结果 (index 349): {'label': 'LABEL_0', 'score': 0.7974369525909424}
# 杭州推进农业创新
# 预测结果 (index 350): {'label': 'LABEL_0', 'score': 0.9879113435745239}
# 真踏马
# 预测结果 (index 351): {'label': 'LABEL_0', 'score': 0.9753403663635254}
# 吃饭了吗中
# 预测结果 (index 352): {'label': 'LABEL_0', 'score': 0.9890974760055542}
# 建议同舟共济全面展开
# 预测结果 (index 353): {'label': 'LABEL_0', 'score': 0.9865603446960449}
# 麻烦你了中
# 预测结果 (index 354): {'label': 'LABEL_0', 'score': 0.9963243007659912}
# 好久不见中全面展开
# 预测结果 (index 355): {'label': 'LABEL_0', 'score': 0.9944891929626465}
# 深入正在智慧城市建设加速
# 预测结果 (index 356): {'label': 'LABEL_0', 'score': 0.9819397330284119}
# 全面正在啥也不是稳步发展
# 预测结果 (index 357): {'label': 'LABEL_0', 'score': 0.9698208570480347}
# 稳步正在充满希望稳步发展
# 预测结果 (index 358): {'label': 'LABEL_0', 'score': 0.9896955490112305}
# 全面继续社会保障体系完善
# 预测结果 (index 359): {'label': 'LABEL_0', 'score': 0.9918636083602905}
# 稳步全面和衷共济完成稳步发展
# 预测结果 (index 360): {'label': 'LABEL_0', 'score': 0.9790464639663696}
# 躺着中枪
# 预测结果 (index 361): {'label': 'LABEL_0', 'score': 0.8628178238868713}
# 建议放心吧
# 预测结果 (index 362): {'label': 'LABEL_0', 'score': 0.9944619536399841}
# 需要期货交易
# 预测结果 (index 363): {'label': 'LABEL_0', 'score': 0.981040894985199}
# 虚拟现实完成持续推进
# 预测结果 (index 364): {'label': 'LABEL_0', 'score': 0.9917274713516235}
# 顶一个
# 预测结果 (index 365): {'label': 'LABEL_0', 'score': 0.985715925693512}
# 稳步持续正在昂首阔步稳步发展
# 预测结果 (index 366): {'label': 'LABEL_0', 'score': 0.9855589866638184}
# 笑我
# 预测结果 (index 367): {'label': 'LABEL_0', 'score': 0.9746808409690857}
# 男默女泪
# 预测结果 (index 368): {'label': 'LABEL_0', 'score': 0.9270554780960083}
# 持续深入继续没毛病
# 预测结果 (index 369): {'label': 'LABEL_0', 'score': 0.9946324825286865}
# 气势恢宏
# 预测结果 (index 370): {'label': 'LABEL_0', 'score': 0.9920349717140198}
# 开始看看就好
# 预测结果 (index 371): {'label': 'LABEL_0', 'score': 0.9879027009010315}
# 持续建议欢迎关注持续推进持续推进
# 预测结果 (index 372): {'label': 'LABEL_0', 'score': 0.994641900062561}
# 精准医疗中
# 预测结果 (index 373): {'label': 'LABEL_0', 'score': 0.9462939500808716}
# 全面躺平稳步发展
# 预测结果 (index 374): {'label': 'LABEL_0', 'score': 0.9668669104576111}
# 很幼稚
# 预测结果 (index 375): {'label': 'LABEL_0', 'score': 0.9620364904403687}
# 持续全面休戚与共完成
# 预测结果 (index 376): {'label': 'LABEL_0', 'score': 0.9591255784034729}
# 白眼儿
# 预测结果 (index 377): {'label': 'LABEL_0', 'score': 0.7488874793052673}
# 建议供给侧改革稳步发展
# 预测结果 (index 378): {'label': 'LABEL_0', 'score': 0.990725576877594}
# 继续辛勤耕耘持续推进
# 预测结果 (index 379): {'label': 'LABEL_0', 'score': 0.988422691822052}
# 没智商
# 预测结果 (index 380): {'label': 'LABEL_1', 'score': 0.9888124465942383}
# 全面成都推进科技创新稳步发展
# 预测结果 (index 381): {'label': 'LABEL_0', 'score': 0.9912533164024353}
# 我就这样
# 预测结果 (index 382): {'label': 'LABEL_0', 'score': 0.9907655715942383}
# 可笑的事
# 预测结果 (index 383): {'label': 'LABEL_0', 'score': 0.8950049877166748}
# 持续开始专心致志
# 预测结果 (index 384): {'label': 'LABEL_0', 'score': 0.9915953278541565}
# 深入混合现实完成
# 预测结果 (index 385): {'label': 'LABEL_0', 'score': 0.9822337031364441}
# 稳步需要好久不见稳步发展
# 预测结果 (index 386): {'label': 'LABEL_0', 'score': 0.9865188002586365}
# 持续点赞
# 预测结果 (index 387): {'label': 'LABEL_0', 'score': 0.9908859729766846}
# 傻得
# 预测结果 (index 388): {'label': 'LABEL_1', 'score': 0.9023287892341614}
# 装13
# 预测结果 (index 389): {'label': 'LABEL_0', 'score': 0.9469362497329712}
# 全面需要早点休息全面展开
# 预测结果 (index 390): {'label': 'LABEL_0', 'score': 0.9878044128417969}
# 深入深入建议身体还好吧
# 预测结果 (index 391): {'label': 'LABEL_0', 'score': 0.9893339276313782}
# 继续兢兢业业
# 预测结果 (index 392): {'label': 'LABEL_0', 'score': 0.972154438495636}
# 没原则
# 预测结果 (index 393): {'label': 'LABEL_0', 'score': 0.8449929356575012}
# 怂到
# 预测结果 (index 394): {'label': 'LABEL_0', 'score': 0.6550840735435486}
# 混子
# 预测结果 (index 395): {'label': 'LABEL_1', 'score': 0.572429358959198}
# 努力工作完成
# 预测结果 (index 396): {'label': 'LABEL_0', 'score': 0.9872393012046814}
# 深入杭州农业发展良好
# 预测结果 (index 397): {'label': 'LABEL_0', 'score': 0.9863503575325012}
# 全面持续优质服务稳步发展
# 预测结果 (index 398): {'label': 'LABEL_0', 'score': 0.9820758104324341}
# 好的呀中全面展开
# 预测结果 (index 399): {'label': 'LABEL_0', 'score': 0.996374785900116}
# 进度: 400/1400
# 正在努力工作全面展开
# 预测结果 (index 400): {'label': 'LABEL_0', 'score': 0.9939644932746887}
# 广州医疗发展良好
# 预测结果 (index 401): {'label': 'LABEL_0', 'score': 0.9941548705101013}
# 蠢过
# 预测结果 (index 402): {'label': 'LABEL_0', 'score': 0.9211492538452148}
# 建议get持续推进
# 预测结果 (index 403): {'label': 'LABEL_0', 'score': 0.9877609014511108}
# 持续正在啥也不是稳步发展
# 预测结果 (index 404): {'label': 'LABEL_0', 'score': 0.9664861559867859}
# 全面秀丽优美中
# 预测结果 (index 405): {'label': 'LABEL_0', 'score': 0.988166093826294}
# 城市更新改造推进
# 预测结果 (index 406): {'label': 'LABEL_0', 'score': 0.980487048625946}
# 开始货币政策
# 预测结果 (index 407): {'label': 'LABEL_0', 'score': 0.9644074440002441}
# 开始太上头稳步发展
# 预测结果 (index 408): {'label': 'LABEL_0', 'score': 0.978502631187439}
# 后会有期中持续推进稳步发展
# 预测结果 (index 409): {'label': 'LABEL_0', 'score': 0.995578944683075}
# 开始好的呀
# 预测结果 (index 410): {'label': 'LABEL_0', 'score': 0.9966185092926025}
# 开始机器学习全面展开
# 预测结果 (index 411): {'label': 'LABEL_0', 'score': 0.9937735795974731}
# 稳步人工智能引领产业变革完成
# 预测结果 (index 412): {'label': 'LABEL_0', 'score': 0.9891603589057922}
# 正在太上头
# 预测结果 (index 413): {'label': 'LABEL_0', 'score': 0.9531028270721436}
# 持续开始智能制造推动效率提升
# 预测结果 (index 414): {'label': 'LABEL_0', 'score': 0.9783372282981873}
# 全面建议辛勤耕耘
# 预测结果 (index 415): {'label': 'LABEL_0', 'score': 0.9781016707420349}
# 小婊子
# 预测结果 (index 416): {'label': 'LABEL_1', 'score': 0.677499532699585}
# 成狗
# 预测结果 (index 417): {'label': 'LABEL_0', 'score': 0.833264172077179}
# 深入上海推进科技创新持续推进
# 预测结果 (index 418): {'label': 'LABEL_0', 'score': 0.9901760220527649}
# 需要充满希望
# 预测结果 (index 419): {'label': 'LABEL_0', 'score': 0.9786754250526428}
# 立牌坊
# 预测结果 (index 420): {'label': 'LABEL_0', 'score': 0.9760900735855103}
# 需要感谢分享
# 预测结果 (index 421): {'label': 'LABEL_0', 'score': 0.9924994111061096}
# 尼玛啊
# 预测结果 (index 422): {'label': 'LABEL_0', 'score': 0.8254982233047485}
# 稳步继续收藏先
# 预测结果 (index 423): {'label': 'LABEL_0', 'score': 0.991327702999115}
# 正在啥也不是
# 预测结果 (index 424): {'label': 'LABEL_0', 'score': 0.9708124399185181}
# 广州推进制造业创新全面展开
# 预测结果 (index 425): {'label': 'LABEL_0', 'score': 0.9813702702522278}
# 和谐融洽完成持续推进
# 预测结果 (index 426): {'label': 'LABEL_0', 'score': 0.9911553859710693}
# 开始数字经济驱动转型升级稳步发展
# 预测结果 (index 427): {'label': 'LABEL_0', 'score': 0.9875470995903015}
# 渣渣男
# 预测结果 (index 428): {'label': 'LABEL_1', 'score': 0.9736332297325134}
# 麻批
# 预测结果 (index 429): {'label': 'LABEL_0', 'score': 0.9618133306503296}
# 屁啦
# 预测结果 (index 430): {'label': 'LABEL_0', 'score': 0.8620859384536743}
# 持续全心全意完成
# 预测结果 (index 431): {'label': 'LABEL_0', 'score': 0.9782918691635132}
# 一样傻
# 预测结果 (index 432): {'label': 'LABEL_0', 'score': 0.6969561576843262}
# 稳步稳步涨知识稳步发展
# 预测结果 (index 433): {'label': 'LABEL_0', 'score': 0.9873614311218262}
# 拽个
# 预测结果 (index 434): {'label': 'LABEL_0', 'score': 0.9407582879066467}
# 深入开始yyds稳步发展
# 预测结果 (index 435): {'label': 'LABEL_0', 'score': 0.9924300312995911}
# 正在前途光明
# 预测结果 (index 436): {'label': 'LABEL_0', 'score': 0.9903132915496826}
# 持续稳步建议不错哦
# 预测结果 (index 437): {'label': 'LABEL_0', 'score': 0.9953652620315552}
# 上海医疗发展良好稳步发展
# 预测结果 (index 438): {'label': 'LABEL_0', 'score': 0.9940062761306763}
# 建议注意身体
# 预测结果 (index 439): {'label': 'LABEL_0', 'score': 0.9905746579170227}
# 努力工作全面展开
# 预测结果 (index 440): {'label': 'LABEL_0', 'score': 0.9772760272026062}
# 豆小瓣
# 预测结果 (index 441): {'label': 'LABEL_0', 'score': 0.9932818412780762}
# 成都推进医疗创新
# 预测结果 (index 442): {'label': 'LABEL_0', 'score': 0.9861897826194763}
# 农业现代化水平提高中
# 预测结果 (index 443): {'label': 'LABEL_0', 'score': 0.988289475440979}
# 成都医疗发展良好
# 预测结果 (index 444): {'label': 'LABEL_0', 'score': 0.9936197400093079}
# 持续有事随时说
# 预测结果 (index 445): {'label': 'LABEL_0', 'score': 0.9933086633682251}
# 正在休戚与共稳步发展
# 预测结果 (index 446): {'label': 'LABEL_0', 'score': 0.9710057377815247}
# 正在早点休息
# 预测结果 (index 447): {'label': 'LABEL_0', 'score': 0.9934387803077698}
# 继续狠狠地稳步发展
# 预测结果 (index 448): {'label': 'LABEL_0', 'score': 0.9818913340568542}
# 稳步一定一定稳步发展稳步发展
# 预测结果 (index 449): {'label': 'LABEL_0', 'score': 0.9881965517997742}
# 当根葱
# 预测结果 (index 450): {'label': 'LABEL_0', 'score': 0.9470041394233704}
# 正在守望相助持续推进持续推进
# 预测结果 (index 451): {'label': 'LABEL_0', 'score': 0.9926878213882446}
# 深入板凳
# 预测结果 (index 452): {'label': 'LABEL_0', 'score': 0.9732837677001953}
# 没素质
# 预测结果 (index 453): {'label': 'LABEL_1', 'score': 0.996067225933075}
# 口可口可
# 预测结果 (index 454): {'label': 'LABEL_0', 'score': 0.9917680025100708}
# 稳步稳步开始和谐融洽
# 预测结果 (index 455): {'label': 'LABEL_0', 'score': 0.9911717772483826}
# 奇葩男
# 预测结果 (index 456): {'label': 'LABEL_0', 'score': 0.528825044631958}
# 科技创新助力经济发展
# 预测结果 (index 457): {'label': 'LABEL_0', 'score': 0.9882377982139587}
# 挫男
# 预测结果 (index 458): {'label': 'LABEL_1', 'score': 0.6593252420425415}
# 稳步秩序井然中
# 预测结果 (index 459): {'label': 'LABEL_0', 'score': 0.9835124611854553}
# 说真
# 预测结果 (index 460): {'label': 'LABEL_0', 'score': 0.9386162757873535}
# 学到了完成
# 预测结果 (index 461): {'label': 'LABEL_0', 'score': 0.9741898775100708}
# 气笑
# 预测结果 (index 462): {'label': 'LABEL_0', 'score': 0.971966028213501}
# 跪添
# 预测结果 (index 463): {'label': 'LABEL_0', 'score': 0.9726182818412781}
# 建议干净整洁稳步发展全面展开
# 预测结果 (index 464): {'label': 'LABEL_0', 'score': 0.9682190418243408}
# 二皮脸
# 预测结果 (index 465): {'label': 'LABEL_0', 'score': 0.9811581969261169}
# 需要默默付出稳步发展
# 预测结果 (index 466): {'label': 'LABEL_0', 'score': 0.9847738742828369}
# 坑啊
# 预测结果 (index 467): {'label': 'LABEL_0', 'score': 0.9652036428451538}
# 抱歉啊稳步发展全面展开全面展开
# 预测结果 (index 468): {'label': 'LABEL_0', 'score': 0.9929854273796082}
# 建议社会保障体系完善全面展开
# 预测结果 (index 469): {'label': 'LABEL_0', 'score': 0.981107234954834}
# 不厚道
# 预测结果 (index 470): {'label': 'LABEL_1', 'score': 0.8214998841285706}
# 需要健康快乐
# 预测结果 (index 471): {'label': 'LABEL_0', 'score': 0.9910632371902466}
# 正在先这样吧
# 预测结果 (index 472): {'label': 'LABEL_0', 'score': 0.9898397922515869}
# 狗屁
# 预测结果 (index 473): {'label': 'LABEL_1', 'score': 0.9920071363449097}
# 逼会
# 预测结果 (index 474): {'label': 'LABEL_0', 'score': 0.861112117767334}
# 继续互帮互助
# 预测结果 (index 475): {'label': 'LABEL_0', 'score': 0.9895008206367493}
# 求关注
# 预测结果 (index 476): {'label': 'LABEL_0', 'score': 0.9900221228599548}
# 计算机视觉中
# 预测结果 (index 477): {'label': 'LABEL_0', 'score': 0.9855841398239136}
# 我勒个去
# 预测结果 (index 478): {'label': 'LABEL_0', 'score': 0.9611374735832214}
# 爽完
# 预测结果 (index 479): {'label': 'LABEL_0', 'score': 0.9809982180595398}
# 建议穿得暖和点
# 预测结果 (index 480): {'label': 'LABEL_0', 'score': 0.9884357452392578}
# 哎哟我去
# 预测结果 (index 481): {'label': 'LABEL_0', 'score': 0.9777361750602722}
# 全面正在欣欣向荣
# 预测结果 (index 482): {'label': 'LABEL_0', 'score': 0.9723161458969116}
# 开始没问题
# 预测结果 (index 483): {'label': 'LABEL_0', 'score': 0.9930770397186279}
# 需要mark持续推进
# 预测结果 (index 484): {'label': 'LABEL_0', 'score': 0.981656014919281}
# 怎么怎么
# 预测结果 (index 485): {'label': 'LABEL_0', 'score': 0.9410191774368286}
# 建议碳中和
# 预测结果 (index 486): {'label': 'LABEL_0', 'score': 0.9912344217300415}
# 我疯
# 预测结果 (index 487): {'label': 'LABEL_0', 'score': 0.9796761274337769}
# 深入建议数据分析
# 预测结果 (index 488): {'label': 'LABEL_0', 'score': 0.9855206608772278}
# 守望相助中
# 预测结果 (index 489): {'label': 'LABEL_0', 'score': 0.9959481358528137}
# 持续支持一下完成稳步发展
# 预测结果 (index 490): {'label': 'LABEL_0', 'score': 0.9924537539482117}
# 二傻
# 预测结果 (index 491): {'label': 'LABEL_0', 'score': 0.952566921710968}
# 开始秩序井然稳步发展
# 预测结果 (index 492): {'label': 'LABEL_0', 'score': 0.9831372499465942}
# 中二少年
# 预测结果 (index 493): {'label': 'LABEL_0', 'score': 0.9917500615119934}
# 狗屎
# 预测结果 (index 494): {'label': 'LABEL_1', 'score': 0.9727579951286316}
# 那姑娘
# 预测结果 (index 495): {'label': 'LABEL_0', 'score': 0.9954782128334045}
# 正在数字经济驱动转型升级持续推进
# 预测结果 (index 496): {'label': 'LABEL_0', 'score': 0.9883999824523926}
# 正在农业现代化水平提高
# 预测结果 (index 497): {'label': 'LABEL_0', 'score': 0.9871315956115723}
# 深入和衷共济
# 预测结果 (index 498): {'label': 'LABEL_0', 'score': 0.9736289381980896}
# 傻咯
# 预测结果 (index 499): {'label': 'LABEL_1', 'score': 0.5141012668609619}
# 进度: 500/1400
# 持续当然可以稳步发展全面展开持续推进
# 预测结果 (index 500): {'label': 'LABEL_0', 'score': 0.9922316074371338}
# 继续优质服务
# 预测结果 (index 501): {'label': 'LABEL_0', 'score': 0.9594409465789795}
# 正在就业形势持续向好
# 预测结果 (index 502): {'label': 'LABEL_0', 'score': 0.9883764386177063}
# 持续正在流行病学
# 预测结果 (index 503): {'label': 'LABEL_0', 'score': 0.9451873898506165}
# 稳步继续狠狠地稳步发展全面展开
# 预测结果 (index 504): {'label': 'LABEL_0', 'score': 0.9816387891769409}
# 深入继续聚精会神
# 预测结果 (index 505): {'label': 'LABEL_0', 'score': 0.9707127213478088}
# 持续一定一定完成
# 预测结果 (index 506): {'label': 'LABEL_0', 'score': 0.9955604076385498}
# 死贱
# 预测结果 (index 507): {'label': 'LABEL_1', 'score': 0.9004721641540527}
# 我能说
# 预测结果 (index 508): {'label': 'LABEL_0', 'score': 0.9182195067405701}
# 稳步求转发
# 预测结果 (index 509): {'label': 'LABEL_0', 'score': 0.9583855867385864}
# 他娘
# 预测结果 (index 510): {'label': 'LABEL_0', 'score': 0.6694673299789429}
# 不客气中
# 预测结果 (index 511): {'label': 'LABEL_0', 'score': 0.9214227795600891}
# 团结协作稳步发展
# 预测结果 (index 512): {'label': 'LABEL_0', 'score': 0.9829906225204468}
# 持续默默付出完成全面展开
# 预测结果 (index 513): {'label': 'LABEL_0', 'score': 0.9840625524520874}
# 深入辛苦了完成稳步发展
# 预测结果 (index 514): {'label': 'LABEL_0', 'score': 0.9911433458328247}
# 需要抱歉啊
# 预测结果 (index 515): {'label': 'LABEL_0', 'score': 0.9904422163963318}
# 建议孜孜不倦
# 预测结果 (index 516): {'label': 'LABEL_0', 'score': 0.982862114906311}
# 稳步继续狠狠地全面展开
# 预测结果 (index 517): {'label': 'LABEL_0', 'score': 0.958696722984314}
# 无聊透顶
# 预测结果 (index 518): {'label': 'LABEL_0', 'score': 0.9281330704689026}
# 吹牛b
# 预测结果 (index 519): {'label': 'LABEL_0', 'score': 0.7091988325119019}
# 开始孜孜不倦全面展开稳步发展
# 预测结果 (index 520): {'label': 'LABEL_0', 'score': 0.9851464629173279}
# 贸易往来日益频繁持续推进
# 预测结果 (index 521): {'label': 'LABEL_0', 'score': 0.9876105785369873}
# 开始和谐融洽
# 预测结果 (index 522): {'label': 'LABEL_0', 'score': 0.9888926148414612}
# 稳步狠狠地
# 预测结果 (index 523): {'label': 'LABEL_0', 'score': 0.916601836681366}
# 深入需要谢谢你
# 预测结果 (index 524): {'label': 'LABEL_0', 'score': 0.9893462061882019}
# 啊啊啊啊
# 预测结果 (index 525): {'label': 'LABEL_0', 'score': 0.9758242964744568}
# 持续全面正在你好啊
# 预测结果 (index 526): {'label': 'LABEL_0', 'score': 0.996746301651001}
# 正在秀丽优美
# 预测结果 (index 527): {'label': 'LABEL_0', 'score': 0.9736368656158447}
# 深入深入全面和衷共济完成
# 预测结果 (index 528): {'label': 'LABEL_0', 'score': 0.971808671951294}
# 混合现实完成
# 预测结果 (index 529): {'label': 'LABEL_0', 'score': 0.9900134801864624}
# 晚安
# 预测结果 (index 530): {'label': 'LABEL_0', 'score': 0.9848886728286743}
# 假正经
# 预测结果 (index 531): {'label': 'LABEL_0', 'score': 0.977139413356781}
# 继续社会保障体系完善稳步发展
# 预测结果 (index 532): {'label': 'LABEL_0', 'score': 0.9903579354286194}
# 捅我
# 预测结果 (index 533): {'label': 'LABEL_0', 'score': 0.6412242650985718}
# 胡逼
# 预测结果 (index 534): {'label': 'LABEL_0', 'score': 0.9379007816314697}
# 妈啊
# 预测结果 (index 535): {'label': 'LABEL_0', 'score': 0.8020630478858948}
# 需要别来无恙
# 预测结果 (index 536): {'label': 'LABEL_0', 'score': 0.9354474544525146}
# 稳步稳步建议优质服务
# 预测结果 (index 537): {'label': 'LABEL_0', 'score': 0.9817979335784912}
# 开始生机勃勃持续推进稳步发展
# 预测结果 (index 538): {'label': 'LABEL_0', 'score': 0.9887985587120056}
# 全面开始学习了
# 预测结果 (index 539): {'label': 'LABEL_0', 'score': 0.9933157563209534}
# 建议最近好吗稳步发展
# 预测结果 (index 540): {'label': 'LABEL_0', 'score': 0.9961126446723938}
# 计算机视觉
# 预测结果 (index 541): {'label': 'LABEL_0', 'score': 0.9873644709587097}
# 全面太上头全面展开
# 预测结果 (index 542): {'label': 'LABEL_0', 'score': 0.9571851491928101}
# 稳步深入开始666
# 预测结果 (index 543): {'label': 'LABEL_0', 'score': 0.9904929995536804}
# 深入深入需要国际合作不断深化持续推进
# 预测结果 (index 544): {'label': 'LABEL_0', 'score': 0.9810405373573303}
# 太搞笑
# 预测结果 (index 545): {'label': 'LABEL_0', 'score': 0.9699309468269348}
# 全面正在下一个
# 预测结果 (index 546): {'label': 'LABEL_0', 'score': 0.9785656332969666}
# 抱歉啊全面展开稳步发展
# 预测结果 (index 547): {'label': 'LABEL_0', 'score': 0.9927574396133423}
# 臭流氓
# 预测结果 (index 548): {'label': 'LABEL_1', 'score': 0.9970682263374329}
# 深入舒适宜人完成稳步发展
# 预测结果 (index 549): {'label': 'LABEL_0', 'score': 0.983356237411499}
# 持续感谢分享中
# 预测结果 (index 550): {'label': 'LABEL_0', 'score': 0.9965046644210815}
# 需要发展机遇共同分享
# 预测结果 (index 551): {'label': 'LABEL_0', 'score': 0.9812931418418884}
# 深入感谢分享完成
# 预测结果 (index 552): {'label': 'LABEL_0', 'score': 0.9945546388626099}
# 开始麻烦你了稳步发展
# 预测结果 (index 553): {'label': 'LABEL_0', 'score': 0.9808818101882935}
# 全面麻烦你了中
# 预测结果 (index 554): {'label': 'LABEL_0', 'score': 0.9968878626823425}
# 特么敢
# 预测结果 (index 555): {'label': 'LABEL_0', 'score': 0.5607092380523682}
# 需要国际合作不断深化持续推进持续推进
# 预测结果 (index 556): {'label': 'LABEL_0', 'score': 0.9890379905700684}
# 深入支持一下
# 预测结果 (index 557): {'label': 'LABEL_0', 'score': 0.9964424967765808}
# 持续继续好家伙
# 预测结果 (index 558): {'label': 'LABEL_0', 'score': 0.9978150129318237}
# 持续深入建议学到了全面展开
# 预测结果 (index 559): {'label': 'LABEL_0', 'score': 0.962539553642273}
# 文化交流更加密切
# 预测结果 (index 560): {'label': 'LABEL_0', 'score': 0.9823166728019714}
# 唧唧歪歪
# 预测结果 (index 561): {'label': 'LABEL_0', 'score': 0.9721121191978455}
# 免疫学
# 预测结果 (index 562): {'label': 'LABEL_0', 'score': 0.9671209454536438}
# 正在交通网络持续优化
# 预测结果 (index 563): {'label': 'LABEL_0', 'score': 0.9915783405303955}
# 深入持续继续宏观经济
# 预测结果 (index 564): {'label': 'LABEL_0', 'score': 0.9802945852279663}
# 全面正在你好啊全面展开
# 预测结果 (index 565): {'label': 'LABEL_0', 'score': 0.9956685304641724}
# 二大爷
# 预测结果 (index 566): {'label': 'LABEL_0', 'score': 0.9696614146232605}
# 稳步稳步欣欣向荣中
# 预测结果 (index 567): {'label': 'LABEL_0', 'score': 0.986472487449646}
# 开始包在我身上
# 预测结果 (index 568): {'label': 'LABEL_0', 'score': 0.9743199348449707}
# 稳妥
# 预测结果 (index 569): {'label': 'LABEL_0', 'score': 0.964970052242279}
# 姐妹儿
# 预测结果 (index 570): {'label': 'LABEL_0', 'score': 0.9962777495384216}
# 需要全心全意稳步发展
# 预测结果 (index 571): {'label': 'LABEL_0', 'score': 0.9835558533668518}
# 需要社会保障体系完善
# 预测结果 (index 572): {'label': 'LABEL_0', 'score': 0.9892585873603821}
# 稳步深入继续实事求是持续推进
# 预测结果 (index 573): {'label': 'LABEL_0', 'score': 0.9837741851806641}
# 持续持续贸易往来日益频繁中
# 预测结果 (index 574): {'label': 'LABEL_0', 'score': 0.989077091217041}
# 文明礼貌完成
# 预测结果 (index 575): {'label': 'LABEL_0', 'score': 0.9013188481330872}
# 需要努力工作
# 预测结果 (index 576): {'label': 'LABEL_0', 'score': 0.9889573454856873}
# 贸易往来日益频繁完成
# 预测结果 (index 577): {'label': 'LABEL_0', 'score': 0.9837265610694885}
# 回骂
# 预测结果 (index 578): {'label': 'LABEL_0', 'score': 0.6195098161697388}
# 持续环保事业稳步前进
# 预测结果 (index 579): {'label': 'LABEL_0', 'score': 0.9927875399589539}
# 逗闷子
# 预测结果 (index 580): {'label': 'LABEL_0', 'score': 0.9706604480743408}
# 么也
# 预测结果 (index 581): {'label': 'LABEL_0', 'score': 0.9585580825805664}
# 持续流行病学完成
# 预测结果 (index 582): {'label': 'LABEL_0', 'score': 0.9759261012077332}
# 建议后会有期稳步发展
# 预测结果 (index 583): {'label': 'LABEL_0', 'score': 0.9963880777359009}
# 持续深入稳步深入开始666
# 预测结果 (index 584): {'label': 'LABEL_0', 'score': 0.9909819960594177}
# 持续持续建议没关系持续推进
# 预测结果 (index 585): {'label': 'LABEL_0', 'score': 0.9939903020858765}
# 继续生态文明建设推进
# 预测结果 (index 586): {'label': 'LABEL_0', 'score': 0.9863096475601196}
# 奇葩女
# 预测结果 (index 587): {'label': 'LABEL_0', 'score': 0.8710365295410156}
# 持续继续不好意思
# 预测结果 (index 588): {'label': 'LABEL_0', 'score': 0.9848452806472778}
# 不知道啊
# 预测结果 (index 589): {'label': 'LABEL_0', 'score': 0.9820674657821655}
# 呆瓜
# 预测结果 (index 590): {'label': 'LABEL_0', 'score': 0.9895932674407959}
# 伪摇滚
# 预测结果 (index 591): {'label': 'LABEL_0', 'score': 0.9739534854888916}
# 财政政策
# 预测结果 (index 592): {'label': 'LABEL_0', 'score': 0.9739117622375488}
# 深入正在合作共赢成果丰硕
# 预测结果 (index 593): {'label': 'LABEL_0', 'score': 0.9835147857666016}
# 持续建议先这样吧
# 预测结果 (index 594): {'label': 'LABEL_0', 'score': 0.9889137148857117}
# 稳步深入持续优质服务
# 预测结果 (index 595): {'label': 'LABEL_0', 'score': 0.974774956703186}
# 建议改天见面持续推进全面展开
# 预测结果 (index 596): {'label': 'LABEL_0', 'score': 0.9888496994972229}
# 贸易往来日益频繁完成稳步发展
# 预测结果 (index 597): {'label': 'LABEL_0', 'score': 0.988370418548584}
# 全面安排上完成
# 预测结果 (index 598): {'label': 'LABEL_0', 'score': 0.9782969951629639}
# 傻妞
# 预测结果 (index 599): {'label': 'LABEL_0', 'score': 0.9867202639579773}
# 进度: 600/1400
# 数字经济驱动转型升级完成
# 预测结果 (index 600): {'label': 'LABEL_0', 'score': 0.9831697940826416}
# 太上头中稳步发展持续推进
# 预测结果 (index 601): {'label': 'LABEL_0', 'score': 0.9865639209747314}
# 继续太上头
# 预测结果 (index 602): {'label': 'LABEL_0', 'score': 0.963897168636322}
# 深入需要孜孜不倦全面展开
# 预测结果 (index 603): {'label': 'LABEL_0', 'score': 0.9626964926719666}
# 稳步深入建议奥利给全面展开
# 预测结果 (index 604): {'label': 'LABEL_0', 'score': 0.9789829254150391}
# 优质服务中
# 预测结果 (index 605): {'label': 'LABEL_0', 'score': 0.9454871416091919}
# 蛋碎
# 预测结果 (index 606): {'label': 'LABEL_0', 'score': 0.9403063058853149}
# 然并卵
# 预测结果 (index 607): {'label': 'LABEL_0', 'score': 0.9153518080711365}
# 开始无语子
# 预测结果 (index 608): {'label': 'LABEL_0', 'score': 0.9886819124221802}
# 制杖
# 预测结果 (index 609): {'label': 'LABEL_0', 'score': 0.9598966836929321}
# 需要与时俱进
# 预测结果 (index 610): {'label': 'LABEL_0', 'score': 0.9722869396209717}
# 建议优质服务
# 预测结果 (index 611): {'label': 'LABEL_0', 'score': 0.96357661485672}
# 欠操
# 预测结果 (index 612): {'label': 'LABEL_0', 'score': 0.92505943775177}
# 没心眼
# 预测结果 (index 613): {'label': 'LABEL_1', 'score': 0.6375667452812195}
# 持续继续辛勤耕耘
# 预测结果 (index 614): {'label': 'LABEL_0', 'score': 0.9930893778800964}
# 持续mark
# 预测结果 (index 615): {'label': 'LABEL_0', 'score': 0.9728065133094788}
# 正在666
# 预测结果 (index 616): {'label': 'LABEL_0', 'score': 0.9643682241439819}
# 素质低
# 预测结果 (index 617): {'label': 'LABEL_1', 'score': 0.9963752627372742}
# 丫是
# 预测结果 (index 618): {'label': 'LABEL_0', 'score': 0.8828644156455994}
# 逼话
# 预测结果 (index 619): {'label': 'LABEL_1', 'score': 0.5045938491821289}
# 全面开始蒸蒸日上全面展开
# 预测结果 (index 620): {'label': 'LABEL_0', 'score': 0.9798035621643066}
# 深入健康快乐持续推进
# 预测结果 (index 621): {'label': 'LABEL_0', 'score': 0.9762383103370667}
# 握草
# 预测结果 (index 622): {'label': 'LABEL_0', 'score': 0.976655125617981}
# 持续稳步继续阳光明媚
# 预测结果 (index 623): {'label': 'LABEL_0', 'score': 0.9889928698539734}
# 谢谢你持续推进
# 预测结果 (index 624): {'label': 'LABEL_0', 'score': 0.9948941469192505}
# 深入求点赞
# 预测结果 (index 625): {'label': 'LABEL_0', 'score': 0.986717939376831}
# 深入任劳任怨中
# 预测结果 (index 626): {'label': 'LABEL_0', 'score': 0.9436082243919373}
# 继续虚拟现实
# 预测结果 (index 627): {'label': 'LABEL_0', 'score': 0.993152379989624}
# 深圳推进教育创新
# 预测结果 (index 628): {'label': 'LABEL_0', 'score': 0.9680224061012268}
# 全面稳步美好生活中
# 预测结果 (index 629): {'label': 'LABEL_0', 'score': 0.97478187084198}
# 深入绝绝子完成全面展开持续推进
# ...
# 进度: 1200/1400
# 肥猪流
# 预测结果 (index 1200): {'label': 'LABEL_0', 'score': 0.7130722403526306}
# 嘴太毒
# 预测结果 (index 1201): {'label': 'LABEL_1', 'score': 0.9907525777816772}
# 深入持续建议回头说
# 预测结果 (index 1202): {'label': 'LABEL_0', 'score': 0.9760562181472778}
# 洗洗睡吧
# 预测结果 (index 1203): {'label': 'LABEL_0', 'score': 0.9539580345153809}
# 深入需要最近忙吗稳步发展
# 预测结果 (index 1204): {'label': 'LABEL_0', 'score': 0.9853982925415039}
# 持续持续继续稳步前进
# 预测结果 (index 1205): {'label': 'LABEL_0', 'score': 0.9926419854164124}
# 需要要照顾好自己
# 预测结果 (index 1206): {'label': 'LABEL_0', 'score': 0.9707640409469604}
# 活该孤独
# 预测结果 (index 1207): {'label': 'LABEL_1', 'score': 0.8918580412864685}
# 软件工程中
# 预测结果 (index 1208): {'label': 'LABEL_0', 'score': 0.9814879894256592}
# 稳步安全可靠完成稳步发展
# 预测结果 (index 1209): {'label': 'LABEL_0', 'score': 0.9913049936294556}
# 持续开始身体还好吧
# 预测结果 (index 1210): {'label': 'LABEL_0', 'score': 0.9963388442993164}
# 需要身体还好吧
# 预测结果 (index 1211): {'label': 'LABEL_0', 'score': 0.9941349625587463}
# 要疯了
# 预测结果 (index 1212): {'label': 'LABEL_0', 'score': 0.9187884330749512}
# 北京推进教育创新
# 预测结果 (index 1213): {'label': 'LABEL_0', 'score': 0.9669645428657532}
# 全心全意完成全面展开
# 预测结果 (index 1214): {'label': 'LABEL_0', 'score': 0.9729657173156738}
# 建议get全面展开全面展开
# 预测结果 (index 1215): {'label': 'LABEL_0', 'score': 0.980953574180603}
# 正在碳中和
# 预测结果 (index 1216): {'label': 'LABEL_0', 'score': 0.9573964476585388}
# 吊丝
# 预测结果 (index 1217): {'label': 'LABEL_0', 'score': 0.9746716618537903}
# 建议认真学习
# 预测结果 (index 1218): {'label': 'LABEL_0', 'score': 0.9945597052574158}
# 深入继续没毛病
# 预测结果 (index 1219): {'label': 'LABEL_0', 'score': 0.9869887828826904}
# 全面深入文明礼貌
# 预测结果 (index 1220): {'label': 'LABEL_0', 'score': 0.9308416247367859}
# 犯傻
# 预测结果 (index 1221): {'label': 'LABEL_1', 'score': 0.8721761107444763}
# 脑残
# 预测结果 (index 1222): {'label': 'LABEL_0', 'score': 0.7522875666618347}
# 抱走
# 预测结果 (index 1223): {'label': 'LABEL_0', 'score': 0.9856904149055481}
# 好蠢
# 预测结果 (index 1224): {'label': 'LABEL_0', 'score': 0.918870747089386}
# 自然语言处理完成
# 预测结果 (index 1225): {'label': 'LABEL_0', 'score': 0.9920225143432617}
# 深入就业形势持续向好
# 预测结果 (index 1226): {'label': 'LABEL_0', 'score': 0.9902614951133728}
# 需要养老服务质量提升
# 预测结果 (index 1227): {'label': 'LABEL_0', 'score': 0.9514228701591492}
# 开始下一个
# 预测结果 (index 1228): {'label': 'LABEL_0', 'score': 0.9669491648674011}
# 持续持续进步全面展开
# 预测结果 (index 1229): {'label': 'LABEL_0', 'score': 0.9839431047439575}
# 真的我
# 预测结果 (index 1230): {'label': 'LABEL_0', 'score': 0.9792675971984863}
# 666中
# 预测结果 (index 1231): {'label': 'LABEL_0', 'score': 0.985895574092865}
# 稳步需要5G应用场景不断拓展
# 预测结果 (index 1232): {'label': 'LABEL_0', 'score': 0.9875558018684387}
# 继续专心致志
# 预测结果 (index 1233): {'label': 'LABEL_0', 'score': 0.9900690913200378}
# 谢谢你完成持续推进
# 预测结果 (index 1234): {'label': 'LABEL_0', 'score': 0.995119571685791}
# 建议稳步前进持续推进
# 预测结果 (index 1235): {'label': 'LABEL_0', 'score': 0.9920313358306885}
# 太上头持续推进
# 预测结果 (index 1236): {'label': 'LABEL_0', 'score': 0.9637386798858643}
# 继续孜孜不倦持续推进
# 预测结果 (index 1237): {'label': 'LABEL_0', 'score': 0.985185444355011}
# 正在没问题稳步发展
# 预测结果 (index 1238): {'label': 'LABEL_0', 'score': 0.992800235748291}
# 清新怡人中全面展开全面展开
# 预测结果 (index 1239): {'label': 'LABEL_0', 'score': 0.9890690445899963}
# 发展机遇共同分享完成全面展开
# 预测结果 (index 1240): {'label': 'LABEL_0', 'score': 0.9638429880142212}
# 持续继续好家伙持续推进
# 预测结果 (index 1241): {'label': 'LABEL_0', 'score': 0.9951968789100647}
# 全面建议信息安全
# 预测结果 (index 1242): {'label': 'LABEL_0', 'score': 0.9719152450561523}
# 稳步稳步前进
# 预测结果 (index 1243): {'label': 'LABEL_0', 'score': 0.9861584305763245}
# 开始不客气
# 预测结果 (index 1244): {'label': 'LABEL_0', 'score': 0.9464065432548523}
# 深入开始绚丽多彩
# 预测结果 (index 1245): {'label': 'LABEL_0', 'score': 0.9934357404708862}
# 正在生机勃勃
# 预测结果 (index 1246): {'label': 'LABEL_0', 'score': 0.9826839566230774}
# 需要物联网
# 预测结果 (index 1247): {'label': 'LABEL_0', 'score': 0.9824512600898743}
# 蓬勃发展完成
# 预测结果 (index 1248): {'label': 'LABEL_0', 'score': 0.9690210819244385}
# 草尼玛
# 预测结果 (index 1249): {'label': 'LABEL_0', 'score': 0.9750290513038635}
# 早点休息中持续推进
# 预测结果 (index 1250): {'label': 'LABEL_0', 'score': 0.9890323281288147}
# 成都推进制造业创新全面展开
# 预测结果 (index 1251): {'label': 'LABEL_0', 'score': 0.9793242812156677}
# 稳步需要默默付出
# 预测结果 (index 1252): {'label': 'LABEL_0', 'score': 0.9680213928222656}
# 深入正在秀丽优美全面展开
# 预测结果 (index 1253): {'label': 'LABEL_0', 'score': 0.9790120720863342}
# 持续正在求关注
# 预测结果 (index 1254): {'label': 'LABEL_0', 'score': 0.9884002208709717}
# 建议稳步前进全面展开
# 预测结果 (index 1255): {'label': 'LABEL_0', 'score': 0.9858910441398621}
# 稳步建议留个言全面展开
# 预测结果 (index 1256): {'label': 'LABEL_0', 'score': 0.9803634285926819}
# 无私奉献中全面展开
# 预测结果 (index 1257): {'label': 'LABEL_0', 'score': 0.9629240036010742}
# 真可怕
# 预测结果 (index 1258): {'label': 'LABEL_0', 'score': 0.787423312664032}
# 正在人工智能引领产业变革
# 预测结果 (index 1259): {'label': 'LABEL_0', 'score': 0.9875091910362244}
# 正在实事求是
# 预测结果 (index 1260): {'label': 'LABEL_0', 'score': 0.9798212051391602}
# 持续建议城市更新改造推进稳步发展
# 预测结果 (index 1261): {'label': 'LABEL_0', 'score': 0.9892991781234741}
# 看看就好
# 预测结果 (index 1262): {'label': 'LABEL_0', 'score': 0.9735533595085144}
# 开始稳步前进全面展开
# 预测结果 (index 1263): {'label': 'LABEL_0', 'score': 0.9895833730697632}
# 深入巍峨壮观
# 预测结果 (index 1264): {'label': 'LABEL_0', 'score': 0.9864051938056946}
# 稳步建议秩序井然
# 预测结果 (index 1265): {'label': 'LABEL_0', 'score': 0.9445080757141113}
# 秩序井然中
# 预测结果 (index 1266): {'label': 'LABEL_0', 'score': 0.959273636341095}
# 深圳教育发展良好
# 预测结果 (index 1267): {'label': 'LABEL_0', 'score': 0.9896745085716248}
# 开始宏观经济
# 预测结果 (index 1268): {'label': 'LABEL_0', 'score': 0.970527708530426}
# 桑心
# 预测结果 (index 1269): {'label': 'LABEL_0', 'score': 0.9847193956375122}
# 瞎得瑟
# 预测结果 (index 1270): {'label': 'LABEL_0', 'score': 0.6473425030708313}
# 扯犊子
# 预测结果 (index 1271): {'label': 'LABEL_1', 'score': 0.5922449827194214}
# 建议按时吃饭
# 预测结果 (index 1272): {'label': 'LABEL_0', 'score': 0.9944345355033875}
# 全面深入正在专心致志
# 预测结果 (index 1273): {'label': 'LABEL_0', 'score': 0.9889524579048157}
# 需要创新发展全面展开
# 预测结果 (index 1274): {'label': 'LABEL_0', 'score': 0.9535388350486755}
# 稳步需要按时吃饭
# 预测结果 (index 1275): {'label': 'LABEL_0', 'score': 0.9882040023803711}
# 真他妈
# 预测结果 (index 1276): {'label': 'LABEL_0', 'score': 0.6490011215209961}
# 北京制造业发展良好
# 预测结果 (index 1277): {'label': 'LABEL_0', 'score': 0.9929271340370178}
# 撩闲
# 预测结果 (index 1278): {'label': 'LABEL_0', 'score': 0.8880043029785156}
# 哭哭
# 预测结果 (index 1279): {'label': 'LABEL_0', 'score': 0.9912372827529907}
# 生态文明建设推进中稳步发展
# 预测结果 (index 1280): {'label': 'LABEL_0', 'score': 0.9903656244277954}
# 稳步后会有期稳步发展持续推进稳步发展
# 预测结果 (index 1281): {'label': 'LABEL_0', 'score': 0.989544689655304}
# 板凳持续推进全面展开
# 预测结果 (index 1282): {'label': 'LABEL_0', 'score': 0.9869852662086487}
# 建议学到了全面展开稳步发展
# 预测结果 (index 1283): {'label': 'LABEL_0', 'score': 0.9789665937423706}
# 你老板
# 预测结果 (index 1284): {'label': 'LABEL_0', 'score': 0.903014063835144}
# 开始交通网络持续优化
# 预测结果 (index 1285): {'label': 'LABEL_0', 'score': 0.9903905391693115}
# 深入通货膨胀中
# 预测结果 (index 1286): {'label': 'LABEL_0', 'score': 0.9756819605827332}
# 全国科技发展良好
# 预测结果 (index 1287): {'label': 'LABEL_0', 'score': 0.9944217801094055}
# 建议发展机遇共同分享持续推进
# 预测结果 (index 1288): {'label': 'LABEL_0', 'score': 0.9835101366043091}
# 和谐融洽稳步发展
# 预测结果 (index 1289): {'label': 'LABEL_0', 'score': 0.9905840158462524}
# 继续货币政策
# 预测结果 (index 1290): {'label': 'LABEL_0', 'score': 0.9551589488983154}
# 休息得好吗全面展开
# 预测结果 (index 1291): {'label': 'LABEL_0', 'score': 0.9931710958480835}
# 老骂
# 预测结果 (index 1292): {'label': 'LABEL_1', 'score': 0.8817898631095886}
# 继续病理学
# 预测结果 (index 1293): {'label': 'LABEL_0', 'score': 0.9847601056098938}
# 全面秀丽优美中稳步发展
# 预测结果 (index 1294): {'label': 'LABEL_0', 'score': 0.98713219165802}
# 环境保护完成
# 预测结果 (index 1295): {'label': 'LABEL_0', 'score': 0.9720116257667542}
# 真渣
# 预测结果 (index 1296): {'label': 'LABEL_1', 'score': 0.6959683895111084}
# 计算机视觉完成
# 预测结果 (index 1297): {'label': 'LABEL_0', 'score': 0.985806405544281}
# 需要当然可以
# 预测结果 (index 1298): {'label': 'LABEL_0', 'score': 0.992671012878418}
# 健康快乐
# 预测结果 (index 1299): {'label': 'LABEL_0', 'score': 0.9774993062019348}
# 进度: 1300/1400
# 需要求关注
# 预测结果 (index 1300): {'label': 'LABEL_0', 'score': 0.9841968417167664}
# 广州制造业发展良好
# 预测结果 (index 1301): {'label': 'LABEL_0', 'score': 0.9924492835998535}
# 全面就业形势持续向好稳步发展
# 预测结果 (index 1302): {'label': 'LABEL_0', 'score': 0.9931776523590088}
# 继续有同感持续推进全面展开
# 预测结果 (index 1303): {'label': 'LABEL_0', 'score': 0.9856187701225281}
# 浪费表情
# 预测结果 (index 1304): {'label': 'LABEL_0', 'score': 0.9487038254737854}
# 稳步需要云计算
# 预测结果 (index 1305): {'label': 'LABEL_0', 'score': 0.9849246144294739}
# 人工智能中
# 预测结果 (index 1306): {'label': 'LABEL_0', 'score': 0.9858222603797913}
# 开始下次聊
# 预测结果 (index 1307): {'label': 'LABEL_0', 'score': 0.946082592010498}
# 生气你
# 预测结果 (index 1308): {'label': 'LABEL_0', 'score': 0.9248189330101013}
# 昂首阔步中稳步发展
# 预测结果 (index 1309): {'label': 'LABEL_0', 'score': 0.9783905148506165}
# 开拓创新完成
# 预测结果 (index 1310): {'label': 'LABEL_0', 'score': 0.9748194813728333}
# 抖机灵
# 预测结果 (index 1311): {'label': 'LABEL_0', 'score': 0.9844534993171692}
# 需要勇于进取
# 预测结果 (index 1312): {'label': 'LABEL_0', 'score': 0.9687967896461487}
# 需要国际合作不断深化
# 预测结果 (index 1313): {'label': 'LABEL_0', 'score': 0.9851021766662598}
# 全面深入正在蒸蒸日上持续推进
# 预测结果 (index 1314): {'label': 'LABEL_0', 'score': 0.979215145111084}
# 持续城市治理水平提升稳步发展
# 预测结果 (index 1315): {'label': 'LABEL_0', 'score': 0.9782880544662476}
# 稳步建议休戚与共
# 预测结果 (index 1316): {'label': 'LABEL_0', 'score': 0.9816176295280457}
# 建议前途光明
# 预测结果 (index 1317): {'label': 'LABEL_0', 'score': 0.9932376146316528}
# 蠢女人
# 预测结果 (index 1318): {'label': 'LABEL_1', 'score': 0.9889829754829407}
# 破鞋
# 预测结果 (index 1319): {'label': 'LABEL_0', 'score': 0.7682196497917175}
# 广州推进科技创新
# 预测结果 (index 1320): {'label': 'LABEL_0', 'score': 0.9885740280151367}
# 太上头中稳步发展稳步发展稳步发展
# 预测结果 (index 1321): {'label': 'LABEL_0', 'score': 0.9893990755081177}
# 就这么说定了中
# 预测结果 (index 1322): {'label': 'LABEL_0', 'score': 0.9938919544219971}
# 我是骗子
# 预测结果 (index 1323): {'label': 'LABEL_1', 'score': 0.996724545955658}
# 真活该
# 预测结果 (index 1324): {'label': 'LABEL_1', 'score': 0.9662737250328064}
# 你看你
# 预测结果 (index 1325): {'label': 'LABEL_0', 'score': 0.9655223488807678}
# 建议辛勤耕耘持续推进
# 预测结果 (index 1326): {'label': 'LABEL_0', 'score': 0.9883463978767395}
# 需要休戚与共
# 预测结果 (index 1327): {'label': 'LABEL_0', 'score': 0.9600332975387573}
# 贱样
# 预测结果 (index 1328): {'label': 'LABEL_1', 'score': 0.5367605686187744}
# 全面正在好家伙
# 预测结果 (index 1329): {'label': 'LABEL_0', 'score': 0.9961942434310913}
# 有事随时说中
# 预测结果 (index 1330): {'label': 'LABEL_0', 'score': 0.9914325475692749}
# 乃们
# 预测结果 (index 1331): {'label': 'LABEL_0', 'score': 0.9777241349220276}
# 开始整齐有序持续推进
# 预测结果 (index 1332): {'label': 'LABEL_0', 'score': 0.9935989379882812}
# 前途光明完成
# 预测结果 (index 1333): {'label': 'LABEL_0', 'score': 0.9857871532440186}
# 持续深入开始看看就好持续推进
# 预测结果 (index 1334): {'label': 'LABEL_0', 'score': 0.994471549987793}
# 想操
# 预测结果 (index 1335): {'label': 'LABEL_0', 'score': 0.9450785517692566}
# 磨磨唧唧
# 预测结果 (index 1336): {'label': 'LABEL_0', 'score': 0.9708825945854187}
# 继续辛苦了全面展开持续推进持续推进
# 预测结果 (index 1337): {'label': 'LABEL_0', 'score': 0.9912838935852051}
# 开始巍峨壮观
# 预测结果 (index 1338): {'label': 'LABEL_0', 'score': 0.991544246673584}
# 好的呀全面展开
# 预测结果 (index 1339): {'label': 'LABEL_0', 'score': 0.9966236352920532}
# 蓝盆友
# 预测结果 (index 1340): {'label': 'LABEL_0', 'score': 0.9978840947151184}
# 全面要照顾好自己中全面展开
# 预测结果 (index 1341): {'label': 'LABEL_0', 'score': 0.9274921417236328}
# 深入成都服务业发展良好全面展开
# 预测结果 (index 1342): {'label': 'LABEL_0', 'score': 0.9804178476333618}
# 深圳推进教育创新稳步发展稳步发展
# 预测结果 (index 1343): {'label': 'LABEL_0', 'score': 0.9869591593742371}
# 我会说
# 预测结果 (index 1344): {'label': 'LABEL_0', 'score': 0.9511721730232239}
# 建议和谐融洽稳步发展持续推进
# 预测结果 (index 1345): {'label': 'LABEL_0', 'score': 0.9895824193954468}
# 全面稳步好家伙
# 预测结果 (index 1346): {'label': 'LABEL_0', 'score': 0.9909934401512146}
# 继续谢谢你
# 预测结果 (index 1347): {'label': 'LABEL_0', 'score': 0.9951049089431763}
# 笑疯
# 预测结果 (index 1348): {'label': 'LABEL_0', 'score': 0.9837227463722229}
# 深入继续环保事业稳步前进
# 预测结果 (index 1349): {'label': 'LABEL_0', 'score': 0.9920622110366821}
# 稳步正在创新发展持续推进
# 预测结果 (index 1350): {'label': 'LABEL_0', 'score': 0.9782798886299133}
# 稳步深入开始孜孜不倦
# 预测结果 (index 1351): {'label': 'LABEL_0', 'score': 0.9792813062667847}
# 你懂
# 预测结果 (index 1352): {'label': 'LABEL_0', 'score': 0.9766925573348999}
# 没底线
# 预测结果 (index 1353): {'label': 'LABEL_1', 'score': 0.7638246417045593}
# 全面需要雄伟壮丽
# 预测结果 (index 1354): {'label': 'LABEL_0', 'score': 0.9929485321044922}
# 开始国际合作不断深化
# 预测结果 (index 1355): {'label': 'LABEL_0', 'score': 0.9862022995948792}
# 需要昂首阔步
# 预测结果 (index 1356): {'label': 'LABEL_0', 'score': 0.9502665400505066}
# 全面正在互帮互助
# 预测结果 (index 1357): {'label': 'LABEL_0', 'score': 0.9883104562759399}
# 蓬勃发展中
# 预测结果 (index 1358): {'label': 'LABEL_0', 'score': 0.9811721444129944}
# 你有病
# 预测结果 (index 1359): {'label': 'LABEL_0', 'score': 0.7838758826255798}
# 特么会
# 预测结果 (index 1360): {'label': 'LABEL_0', 'score': 0.8095510601997375}
# 持续全面持续继续辛勤耕耘持续推进持续推进持续推进全面展开稳步发展
# 预测结果 (index 1361): {'label': 'LABEL_0', 'score': 0.989336371421814}
# 继续学习了
# 预测结果 (index 1362): {'label': 'LABEL_0', 'score': 0.9933491349220276}
# 神精病
# 预测结果 (index 1363): {'label': 'LABEL_0', 'score': 0.928027331829071}
# 全面建议精准医疗
# 预测结果 (index 1364): {'label': 'LABEL_0', 'score': 0.9807575941085815}
# 全面全面666中
# 预测结果 (index 1365): {'label': 'LABEL_0', 'score': 0.9878559708595276}
# 坚持不懈完成稳步发展
# 预测结果 (index 1366): {'label': 'LABEL_0', 'score': 0.9885572195053101}
# 渣男
# 预测结果 (index 1367): {'label': 'LABEL_1', 'score': 0.9704698920249939}
# 开始好久不见
# 预测结果 (index 1368): {'label': 'LABEL_0', 'score': 0.996171772480011}
# 稳步全面美好生活完成稳步发展
# 预测结果 (index 1369): {'label': 'LABEL_0', 'score': 0.9823079109191895}
# 稳步建议学习进展如何
# 预测结果 (index 1370): {'label': 'LABEL_0', 'score': 0.9888578653335571}
# 哎呦我去
# 预测结果 (index 1371): {'label': 'LABEL_0', 'score': 0.9888701438903809}
# 操蛋
# 预测结果 (index 1372): {'label': 'LABEL_1', 'score': 0.5858925580978394}
# 绝绝子全面展开
# 预测结果 (index 1373): {'label': 'LABEL_0', 'score': 0.986535370349884}
# 草蛋
# 预测结果 (index 1374): {'label': 'LABEL_0', 'score': 0.9654449224472046}
# 稳步持续正在昂首阔步
# 预测结果 (index 1375): {'label': 'LABEL_0', 'score': 0.9870952367782593}
# 全面开始全心全意稳步发展
# 预测结果 (index 1376): {'label': 'LABEL_0', 'score': 0.9866963028907776}
# 不会做人
# 预测结果 (index 1377): {'label': 'LABEL_0', 'score': 0.6891863346099854}
# 繁荣昌盛全面展开
# 预测结果 (index 1378): {'label': 'LABEL_0', 'score': 0.9822056889533997}
# 正在学习进展如何
# 预测结果 (index 1379): {'label': 'LABEL_0', 'score': 0.9920690059661865}
# 需要生机勃勃全面展开稳步发展
# 预测结果 (index 1380): {'label': 'LABEL_0', 'score': 0.9779271483421326}
# 开始近来可好
# 预测结果 (index 1381): {'label': 'LABEL_0', 'score': 0.993835985660553}
# 叽叽歪歪
# 预测结果 (index 1382): {'label': 'LABEL_0', 'score': 0.9804524183273315}
# 需要财政政策
# 预测结果 (index 1383): {'label': 'LABEL_0', 'score': 0.9777586460113525}
# 深入继续同心协力
# 预测结果 (index 1384): {'label': 'LABEL_0', 'score': 0.983130931854248}
# 深入持续感谢分享中
# 预测结果 (index 1385): {'label': 'LABEL_0', 'score': 0.9964634776115417}
# 顶一个稳步发展
# 预测结果 (index 1386): {'label': 'LABEL_0', 'score': 0.9749739766120911}
# 闲得蛋疼
# 预测结果 (index 1387): {'label': 'LABEL_0', 'score': 0.9787203073501587}
# 真丑
# 预测结果 (index 1388): {'label': 'LABEL_0', 'score': 0.9298021197319031}
# 搞破鞋
# 预测结果 (index 1389): {'label': 'LABEL_1', 'score': 0.6971016526222229}
# 作大死
# 预测结果 (index 1390): {'label': 'LABEL_0', 'score': 0.6578128337860107}
# 持续稳全面展开稳步发展
# 预测结果 (index 1391): {'label': 'LABEL_0', 'score': 0.9819130897521973}
# 生物多样性完成
# 预测结果 (index 1392): {'label': 'LABEL_0', 'score': 0.9879882335662842}
# 深入别太累了持续推进
# 预测结果 (index 1393): {'label': 'LABEL_0', 'score': 0.9776795506477356}
# 开始感激不尽全面展开
# 预测结果 (index 1394): {'label': 'LABEL_0', 'score': 0.9930383563041687}
# 持续开始谢谢你稳步发展
# 预测结果 (index 1395): {'label': 'LABEL_0', 'score': 0.9936333894729614}
# 深圳教育发展良好
# 预测结果 (index 1396): {'label': 'LABEL_0', 'score': 0.9896745085716248}
# 社会保障体系完善全面展开
# 预测结果 (index 1397): {'label': 'LABEL_0', 'score': 0.9823333621025085}
# 稳步继续没关系稳步发展
# 预测结果 (index 1398): {'label': 'LABEL_0', 'score': 0.9923372864723206}
# 很拽
# 预测结果 (index 1399): {'label': 'LABEL_0', 'score': 0.9820751547813416}
#
# === 评估结果 ===
#
# 分类报告:
#               precision    recall  f1-score   support
#
#            0       0.78      1.00      0.88      1021
#            1       0.99      0.25      0.40       379
#
#     accuracy                           0.80      1400
#    macro avg       0.89      0.62      0.64      1400
# weighted avg       0.84      0.80      0.75      1400
#
#
# 混淆矩阵:
# [[1020    1]
#  [ 284   95]]
#
# 模型性能统计:
# 总样本数: 1400
# 准确率: 0.7964
#
# 错误预测分析:
# 评估结果已保存到 model_evaluation_results.csv
