# %%
import sagemaker
from sagemaker.huggingface import HuggingFaceModel
import boto3
import pandas as pd
import json
from sklearn.metrics import classification_report, confusion_matrix

# 1. 首先部署模型
def deploy_model():
    try:
        role = sagemaker.get_execution_role()
    except ValueError:
        iam = boto3.client('iam')
        role = iam.get_role(RoleName='sagemaker_execution_role')['Role']['Arn']
    
    # 使用你训练好的模型创建HuggingFaceModel
    huggingface_model = HuggingFaceModel(
        model_data="s3://sagemaker-ap-northeast-1-034362076319/huggingface-pytorch-training-2024-11-08-15-54-35-976/output/model.tar.gz",
        role=role,
        transformers_version="4.37.0",
        pytorch_version="2.1.0",
        py_version='py310',
        entry_point='inference.py'
    )
    
    # 部署模型
    predictor = huggingface_model.deploy(
        initial_instance_count=1,
        instance_type='ml.m5.xlarge',
        endpoint_name='cold-sentiment-endpoint-3'
    )
    
    return predictor

# 2. 评估函数
def evaluate_model():
    # 加载eval数据集
    eval_data = pd.read_json('../eval_processed.jsonl', lines=True)
    
    # 创建预测客户端
    runtime_client = boto3.client('runtime.sagemaker')
    
    predictions = []
    probabilities_list = []  # 改名以更准确反映内容
    
    print("开始评估...")
    total = len(eval_data)
    
    for idx, row in eval_data.iterrows():
        if idx % 100 == 0:  # 每100条数据显示进度
            print(f"进度: {idx}/{total}")
            
        # 准备输入数据
        input_data = {"text": row['text']}
        print(f"{row['text']}")
        try:
            # 调用endpoint进行预测
            response = runtime_client.invoke_endpoint(
                EndpointName='cold-sentiment-endpoint-3',
                ContentType='application/json',
                Body=json.dumps(input_data)
            )
            
            # 解析结果
            result = json.loads(response['Body'].read().decode())
            print(f"预测结果 (index {idx}): {result['prediction']}--{row['label']}")

            predictions.append(result['prediction'])
            probabilities_list.append(result['probabilities'])  # 存储完整的概率分布
            
        except Exception as e:
            print(f"预测错误 (index {idx}): {str(e)}")
            predictions.append(None)
            probabilities_list.append(None)
    
    # 添加预测结果到数据框
    eval_data['predicted'] = predictions
    eval_data['probabilities'] = probabilities_list  # 存储完整的概率分布
    # 计算最高概率作为置信度
    eval_data['confidence'] = eval_data['probabilities'].apply(
        lambda x: max(x) if x is not None else None
    )
    
    # 输出评估结果
    print("\n=== 评估结果 ===")
    print("\n分类报告:")
    print(classification_report(eval_data['label'], eval_data['predicted']))
    
    print("\n混淆矩阵:")
    cm = confusion_matrix(eval_data['label'], eval_data['predicted'])
    print(cm)
    
    # 计算额外统计信息
    eval_data['is_correct'] = eval_data['label'] == eval_data['predicted']
    print("\n模型性能统计:")
    print(f"总样本数: {len(eval_data)}")
    print(f"准确率: {eval_data['is_correct'].mean():.4f}")
    print(f"平均置信度: {eval_data['confidence'].mean():.4f}")
    
    # 错误分析
    print("\n错误预测分析:")
    errors = eval_data[~eval_data['is_correct']].sort_values('confidence', ascending=False)
    print("\n高置信度错误案例:")
    for _, row in errors.head().iterrows():
        print(f"\n文本: {row['text']}")
        print(f"真实标签: {row['label']}")
        print(f"预测标签: {row['predicted']}")
        print(f"置信度: {row['confidence']:.4f}")
    
    # 保存评估结果
    eval_data.to_csv('model_evaluation_results-3.csv', index=False)
    return eval_data

# 3. 清理资源函数
def cleanup_endpoint():
    client = boto3.client('sagemaker')
    try:
        client.delete_endpoint(EndpointName='cold-sentiment-endpoint')
        print("已删除endpoint")
    except Exception as e:
        print(f"删除endpoint时出错: {str(e)}")

if __name__ == "__main__":
    try:
        # # 1. 部署模型
        print("正在部署模型...")
        predictor = deploy_model()
        
        # 2. 进行评估
        print("开始评估...")
        results = evaluate_model()
        
        # # 3. 完成后清理资源
        # print("评估完成，正在清理资源...")
        # cleanup_endpoint()
        
        print("评估结果已保存到 model_evaluation_results-3.csv")
        
    except Exception as e:
        print(f"发生错误: {str(e)}")
        # 确保即使发生错误也清理资源
        # cleanup_endpoint()
# Out:
# 正在部署模型...
# -------!开始评估...
# 开始评估...
# 进度: 0/2856
# Rehabilitation training enhances functional levels. Rehabilitation training: rehabilitation training; functional levels: functional levels
# 预测结果 (index 0): 0--0
# 永远做你们的贴心小棉袄
# 预测结果 (index 1): 0--0
# 评论厨子做的菜好不好吃我还要先会做饭吗？
# 预测结果 (index 2): 1--1
# 我真的很想帮你治疗，但我是一名家庭医生，而你是一个孤儿。啊
# 预测结果 (index 3): 0--1
# 客户服务热情贴心提升形象
# 预测结果 (index 4): 0--0
# 太仔细看看我这巴掌真适合你那大脸
# 预测结果 (index 5): 1--1
# 记得-下点-调料-，-这样-你家-人-吃-起来-才-会-有-味道
# 预测结果 (index 6): 0--1
# 我真的很想帮你治疗，但我是一名家庭医生，而你是一个孤儿。了
# 预测结果 (index 7): 0--1
# 就是嫉妒我户口本可翻页（说他是孤儿）
# 预测结果 (index 8): 1--1
# 我真的很想帮你治疗，但但我是一名家庭医生，而你是一个孤儿。
# 预测结果 (index 9): 0--1
# 好坏淫
# 预测结果 (index 10): 1--1
# 医学研究应关注不同人群的健康需求和差异
# 预测结果 (index 11): 0--0
# 好特爱
# 预测结果 (index 12): 0--1
# 被分手吧
# 预测结果 (index 13): 1--1
# 二。大爷
# 预测结果 (index 14): 1--1
# 傻啊
# 预测结果 (index 15): 1--1
# 特别怂货
# 预测结果 (index 16): 1--1
# 艰不拆吧
# 预测结果 (index 17): 1--1
# 就是嫉我户口本可以翻页（说他是孤儿）
# 预测结果 (index 18): 1--1
# 你.看上去.好.眼熟.像.我.昨天.扔出去.的.那袋.垃圾
# 预测结果 (index 19): 1--1
# 记得|下点|调料|，|这样|你家|人|吃|起来|才|会|有|味道
# 预测结果 (index 20): 0--1
# 我们#要#向前#看#,#不错#过些#歪#瓜劣#枣#怎么#知道#什么#是#好#的#。
# 预测结果 (index 21): 1--1
# 祝你们不孕不育，儿孙满堂。啊
# 预测结果 (index 22): 0--1
# 二|大爷
# 预测结果 (index 23): 1--1
# 特别瞎搞
# 预测结果 (index 24): 1--1
# 注意饮食卫生
# 预测结果 (index 25): 0--0
# 傻逼年年有，今今年大丰收
# 预测结果 (index 26): 1--1
# 社会发展更加和谐
# 预测结果 (index 27): 0--0
# 你美的像只鸡🐔
# 预测结果 (index 28): 1--1
# 非常别人站着赚钱， 你躺着。
# 预测结果 (index 29): 1--1
# 内镜检查可直接观察消化道、呼吸道等内部情况，如胃镜、肠镜、支气管镜等
# 预测结果 (index 30): 0--0
# 别人站着赚钱， 你躺着。啊
# 预测结果 (index 31): 1--1
# 好你屌
# 预测结果 (index 32): 1--1
# 挺~逗
# 预测结果 (index 33): 1--1
# 傻逼年年有，今年大丰收吧
# 预测结果 (index 34): 1--1
# 就是嫉妒我户口本可可以翻页（说他是孤儿）
# 预测结果 (index 35): 1--1
# 没没皮没脸
# 预测结果 (index 36): 1--1
# 关注行业趋势，提前做好准备
# 预测结果 (index 37): 0--0
# 活该单身
# 预测结果 (index 38): 1--1
# Humanization of medical nursing services focuses on patients' feelings. Medical nursing services humanization: medical nursing services humanization; patients' feelings: patients' feelings
# 预测结果 (index 39): 0--0
# 你 想 多 了
# 预测结果 (index 40): 1--1
# 非常我的天呐,你一定是吃了放在肮脏的桌子上的发霉的绿色面包,才会眨着美丽的大眼睛说出长沙臭豆腐一样臭的话!
# 预测结果 (index 41): 1--1
# 我#笑#了
# 预测结果 (index 42): 1--1
# 恶心的🐎🐎给恶心开门、恶心到家了……
# 预测结果 (index 43): 1--1
# 太疯了吧
# 预测结果 (index 44): 1--1
# 你想多了呢
# 预测结果 (index 45): 1--1
# 真想~把~你~的~头~扭~下来~放在~洗衣机~里~搅~一~搅~，~刚好~能~洗~一缸~衣服~，~虽然~有点~臭~，~但~节约~水资源~刻不容缓~。
# 预测结果 (index 46): 1--1
# 俗不可耐
# 预测结果 (index 47): 1--1
# 非常你再骂？信不信👴把你脑袋拧下来当夜壶？！
# 预测结果 (index 48): 1--1
# 积极参与项目设计，发挥创意才能
# 预测结果 (index 49): 0--0
# 免疫治疗激发人体免疫
# 预测结果 (index 50): 0--0
# 《商务邀请函回复时间要求》：明确商务邀请函回复时间要求，提高回复效率
# 预测结果 (index 51): 0--0
# 真艰不拆
# 预测结果 (index 52): 1--1
# 作不死
# 预测结果 (index 53): 1--1
# 你+再+骂+？+信不信+👴+把+你+脑袋+拧下来+当+夜壶+？+！
# 预测结果 (index 54): 1--1
# 尘归尘 土归土 把你骨灰扬了都不配做PM2.5
# 预测结果 (index 55): 1--1
# 装比
# 预测结果 (index 56): 1--1
# 太没人理
# 预测结果 (index 57): 1--1
# 别人站着赚钱， 你躺着。
# 预测结果 (index 58): 1--1
# 牛逼牛
# 预测结果 (index 59): 1--1
# 保持良好心态有益健康
# 预测结果 (index 60): 0--0
# 砍死他
# 预测结果 (index 61): 1--1
# 好家家伙，你自己拍全家福挺孤单吧
# 预测结果 (index 62): 1--1
# 感恩那些默默付出的人
# 预测结果 (index 63): 0--0
# 挺槽
# 预测结果 (index 64): 1--1
# 特别你再骂？信不信👴把你脑袋拧下来当夜壶？！
# 预测结果 (index 65): 1--1
# 文化交流日益频繁
# 预测结果 (index 66): 0--0
# 他很棒，好吗
# 预测结果 (index 67): 0--0
# 我有空的时候会去逛商场，购买自己喜欢的物品
# 预测结果 (index 68): 0--0
# Innovative humanistic care of medical nursing reflects nursing warmth. Medical nursing humanistic care innovation: medical nursing humanistic care innovation; nursing warmth: nursing warmth
# 预测结果 (index 69): 0--0
# 龟孙子的
# 预测结果 (index 70): 1--1
# 医院提升医院医疗技术创新能力和水平的激励机制建设，激发医务人员的创新积极性
# 预测结果 (index 71): 0--0
# 我喷
# 预测结果 (index 72): 1--1
# 教育改革更加深化
# 预测结果 (index 73): 0--0
# 太就是嫉妒我户口本可以翻页（说他是孤儿）
# 预测结果 (index 74): 1--1
# 记得下点调料，这样家人吃起来才会有味道
# 预测结果 (index 75): 0--1
# 制药企业加强药品研发项目风险管理策略优化活动，不断完善风险管理策略
# 预测结果 (index 76): 0--0
# 自嗨吧
# 预测结果 (index 77): 1--1
# 你的智商跟冬天黑龙江的温度一样。。
# 预测结果 (index 78): 1--1
# 特别制杖
# 预测结果 (index 79): 0--1
# 真想把你的头扭下来来放在洗衣机里搅一搅，刚好能洗一缸衣服，虽然有点臭，但节约水资源刻不容缓。
# 预测结果 (index 80): 0--1
# 大.尾巴.狼
# 预测结果 (index 81): 1--1
# 他会在业余时间学习摄影，记录生活中的美好瞬间
# 预测结果 (index 82): 0--0
# 真牛逼逼
# 预测结果 (index 83): 1--1
# 贱b吧
# 预测结果 (index 84): 1--1
# 瞎搞吧
# 预测结果 (index 85): 1--1
# 熊样
# 预测结果 (index 86): 1--1
# 我的天呐,你一定是吃了放在肮脏的桌子的发霉的绿色面包,才会眨着美丽的大眼睛说出长沙臭豆腐一样臭的话!
# 预测结果 (index 87): 1--1
# 会议讨论深入热烈达成共识
# 预测结果 (index 88): 0--0
# 挺_逗
# 预测结果 (index 89): 1--1
# 白眼狼
# 预测结果 (index 90): 1--1
# 医疗护理服务模式创新满足患者需求
# 预测结果 (index 91): 0--0
# 舞蹈晚会绚丽多姿展现艺术风采
# 预测结果 (index 92): 0--0
# 老狗呢
# 预测结果 (index 93): 1--1
# 我 的 天呐 , 你 一定 是 吃 了 放在 肮脏 的 桌子 上 的 发霉 的 绿色 面包 , 才 会 眨 着 美丽 的 大 眼睛 说出 长沙 臭豆腐 一样 臭 的话 !
# 预测结果 (index 94): 1--1
# sha逼年年有，今年大丰收
# 预测结果 (index 95): 1--1
# 如果.长.的.丑.也.算.残疾.的话.，.那.你.就.不用.工作.了.。
# 预测结果 (index 96): 1--1
# 疯 了 吧
# 预测结果 (index 97): 1--1
# 双向转诊方便患者就医
# 预测结果 (index 98): 0--0
# 恶心*的*妈妈*给*恶心*开门*、*恶心*到家*了*…*…
# 预测结果 (index 99): 1--1
# 进度: 100/2856
# 医疗护理安全文化创新提高安全意识
# 预测结果 (index 100): 0--0
# 你上辈子一定是个塑料袋 那么会装
# 预测结果 (index 101): 1--1
# 想去给你烧香 才发现你还没死啊
# 预测结果 (index 102): 1--1
# 你是我见过的容量最大的铅笔盒了，装那么多笔你不累吗？呢
# 预测结果 (index 103): 0--1
# 好diao
# 预测结果 (index 104): 1--1
# 你怎么不在了啊是专门装哑巴上街卖艺了吗可惜你无才无艺二胡捧你手机就断线建议没异能还是不要哑巴恰烂钱
# 预测结果 (index 105): 1--1
# 你再骂？信不信👴把你脑袋拧下来当夜壶？！啊
# 预测结果 (index 106): 1--1
# 音乐会表演精彩绝伦奏响美妙旋律
# 预测结果 (index 107): 0--0
# 男屌丝
# 预测结果 (index 108): 1--1
# 狗狗……
# 预测结果 (index 109): 1--1
# 呦！这是谁裤裤裆门没拉，怎么把你漏出来了？
# 预测结果 (index 110): 1--1
# 瞧不起的
# 预测结果 (index 111): 1--1
# 我明白，他也是
# 预测结果 (index 112): 0--0
# 不错哦，对吧
# 预测结果 (index 113): 0--0
# 真牛#逼
# 预测结果 (index 114): 1--1
# 龟+孙子
# 预测结果 (index 115): 1--1
# 太想去给你烧香 才发现你还没死
# 预测结果 (index 116): 1--1
# 怎么不说话了 屎吃太多堵住了？的
# 预测结果 (index 117): 1--1
# 参加学术交流会议，拓展学术视野
# 预测结果 (index 118): 0--0
# 基于证据的医疗决策
# 预测结果 (index 119): 0--0
# 舞蹈表演优美动人舞者魅力无限
# 预测结果 (index 120): 0--0
# 对应分析可以展示两个分类变量之间的关系
# 预测结果 (index 121): 0--0
# gay的
# 预测结果 (index 122): 1--1
# 感恩老师的教诲与指导
# 预测结果 (index 123): 0--0
# 我的天呐,你一定是吃吃了放在肮脏的桌子上的发霉的绿色面包,才会眨着美丽的大眼睛说出长沙臭豆腐一样臭的话!
# 预测结果 (index 124): 1--1
# 不作不死啊
# 预测结果 (index 125): 1--1
# 欢乐的海滩度假放松身心
# 预测结果 (index 126): 0--0
# 特别装比
# 预测结果 (index 127): 1--1
# 好挺逗
# 预测结果 (index 128): 1--1
# 《市场拓展效果评估》：评估市场拓展效果，及时调整拓展策略
# 预测结果 (index 129): 0--0
# 爱阅读
# 预测结果 (index 130): 0--0
# 我的天呐,你一定是吃了放在肮脏的桌子上的发霉的绿色面包,才会眨着美丽的大眼睛说出长沙臭豆豆腐一样臭的话!
# 预测结果 (index 131): 1--1
# 不错哦，是吗
# 预测结果 (index 132): 0--0
# 砍死~他
# 预测结果 (index 133): 1--1
# 二-大爷
# 预测结果 (index 134): 1--1
# 真你的智商跟冬天黑龙江的温度一样。
# 预测结果 (index 135): 1--1
# 牛皮哄哄
# 预测结果 (index 136): 1--1
# 妹妹腮红够不够，不够姐姐巴掌凑
# 预测结果 (index 137): 1--1
# 真高端黑
# 预测结果 (index 138): 1--1
# 真龟孙子
# 预测结果 (index 139): 1--1
# 医学研究应关注人工智能在医学中的应用
# 预测结果 (index 140): 0--0
# 感谢您的耐心等待
# 预测结果 (index 141): 0--0
# 行孝道
# 预测结果 (index 142): 0--0
# 欢乐的笑容如阳光般灿烂
# 预测结果 (index 143): 0--0
# 积极参与项目拓展，开拓市场空间
# 预测结果 (index 144): 0--0
# 太制杖
# 预测结果 (index 145): 1--1
# diao
# 预测结果 (index 146): 1--1
# 你是我见过的容量最大的铅笔盒了，装那么多笔你不累吗？啊
# 预测结果 (index 147): 0--1
# 特别gay
# 预测结果 (index 148): 1--1
# 医疗护理风险管理降低护理风险
# 预测结果 (index 149): 0--0
# 读完很感动.非常棒
# 预测结果 (index 150): 0--0
# 龟_孙子
# 预测结果 (index 151): 1--1
# 记得#下点#调料#，#这样#你家#人#吃#起来#才#会#有#味道
# 预测结果 (index 152): 0--1
# 是这世间的黑暗，造就就了你不懂礼数的浅薄。
# 预测结果 (index 153): 1--1
# 呦！这是谁裤裆门没拉怎么把你漏出来了？
# 预测结果 (index 154): 1--1
# 我们会努力提升品质
# 预测结果 (index 155): 0--0
# 感恩生活中的每一份感动
# 预测结果 (index 156): 0--0
# 心存感激.收获幸福
# 预测结果 (index 157): 0--0
# 真贱b
# 预测结果 (index 158): 1--1
# 会议交流充分深入达成目标
# 预测结果 (index 159): 0--0
# 苍蝇走你脸上都崴脚
# 预测结果 (index 160): 1--1
# jianb
# 预测结果 (index 161): 1--1
# 拼搏奋进
# 预测结果 (index 162): 0--0
# 恶心的mama给恶心开门、恶心到家了……
# 预测结果 (index 163): 1--1
# 我主动学习新技术新方法，提高工作效率
# 预测结果 (index 164): 0--0
# 付出终有回报.感恩前行
# 预测结果 (index 165): 0--0
# 你。的。智商。跟。冬天。黑龙江。的。温度。一样。。
# 预测结果 (index 166): 1--1
# 装b
# 预测结果 (index 167): 1--1
# 怂货
# 预测结果 (index 168): 1--1
# 欢乐的新年庆祝活动充满希望与祝福迎接新的一年带来新的开始与机遇
# 预测结果 (index 169): 0--0
# 科技创新能力显著提升
# 预测结果 (index 170): 0--0
# 我的天呐,你一定是吃了放在肮脏的桌子上的发霉的绿色面包,才会眨着美丽的大眼睛说出长沙臭豆腐一样臭的话!
# 预测结果 (index 171): 1--1
# 怎么不说话了 屎吃太多堵住了？？
# 预测结果 (index 172): 1--1
# 恶心、脱发等
# 预测结果 (index 173): 1--0
# 如果。长。的。丑。也。算。残疾。的话。，。那。你。就。不用。工作。了。。
# 预测结果 (index 174): 1--1
# 真想 把 你 的 头 扭 下来 放在 洗衣机 里 搅 一 搅 ， 刚好 能 洗 一缸 衣服 ， 虽然 有点 臭 ， 但 节约 水资源 刻不容缓 。
# 预测结果 (index 175): 0--1
# 没人理了
# 预测结果 (index 176): 1--1
# 你看上去好眼熟像我昨天扔出去的那袋垃圾吧
# 预测结果 (index 177): 1--1
# 你这种人永远买不到自己合合适的鞋 因为你码没了
# 预测结果 (index 178): 1--1
# 恶心-的-妈妈-给-恶心-开门-、-恶心-到家-了-…-…
# 预测结果 (index 179): 1--1
# 牛+x
# 预测结果 (index 180): 1--1
# 你是我见过的容量最大的铅笔盒了，装那么多笔你不不累吗？
# 预测结果 (index 181): 0--1
# 我的的天呐,你一定是吃了放在肮脏的桌子上的发霉的绿色面包,才会眨着美丽的大眼睛说出长沙臭豆腐一样臭的话!
# 预测结果 (index 182): 1--1
# 多傻
# 预测结果 (index 183): 1--1
# 欢乐的水上乐园之旅清凉一夏
# 预测结果 (index 184): 0--0
# 自嗨了
# 预测结果 (index 185): 1--1
# 爱骂人
# 预测结果 (index 186): 1--1
# 真想把你的头扭下来放在洗衣机里搅一搅，刚好能洗一缸衣服，虽然有点臭，但节约水资源刻刻不容缓。
# 预测结果 (index 187): 0--1
# 挺操了
# 预测结果 (index 188): 1--1
# 大尾巴狼啊
# 预测结果 (index 189): 1--1
# 艺术工作坊激发创意参与者体验艺术创作乐趣
# 预测结果 (index 190): 0--0
# 我.的.天呐.,.你.一定.是.吃.了.放在.肮脏.的.桌子.上.的.发霉.的.绿色.面包.,.才.会.眨.着.美丽.的.大.眼睛.说出.长沙.臭豆腐.一样.臭.的话.!
# 预测结果 (index 191): 1--1
# 特别.牛
# 预测结果 (index 192): 1--1
# 真没人理
# 预测结果 (index 193): 1--1
# 我们共同创建企业文化，增强企业核心竞争力
# 预测结果 (index 194): 0--0
# 尼妈
# 预测结果 (index 195): 1--1
# 没人爱
# 预测结果 (index 196): 1--1
# 重情义
# 预测结果 (index 197): 0--0
# 激动心难平
# 预测结果 (index 198): 0--0
# 太牛x
# 预测结果 (index 199): 1--1
# 进度: 200/2856
# 傻年年有，今年大丰收
# 预测结果 (index 200): 1--1
# 是-这-世间-的-黑暗-，-造就-了-你-不-懂-礼数-的-浅薄-。
# 预测结果 (index 201): 1--1
# 疯.了.吧
# 预测结果 (index 202): 1--1
# 天不错，对不对
# 预测结果 (index 203): 0--0
# 我同意，好不好
# 预测结果 (index 204): 0--0
# 见解很独到.让人耳目一新
# 预测结果 (index 205): 0--0
# 得了吧
# 预测结果 (index 206): 1--1
# 真爱得瑟
# 预测结果 (index 207): 1--1
# 坨翔
# 预测结果 (index 208): 1--1
# 很正常啊
# 预测结果 (index 209): 0--1
# 姑娘*啊
# 预测结果 (index 210): 1--1
# 你-这种-人-永远-买不到-自己-合适-的-鞋- -因为-你码-没-了
# 预测结果 (index 211): 1--1
# 瞧不起
# 预测结果 (index 212): 1--1
# 医院加强医院绩效管理，提高医院运营效益
# 预测结果 (index 213): 0--0
# 医院开展医疗扶贫工作，助力健康中国建设
# 预测结果 (index 214): 0--0
# 有点二
# 预测结果 (index 215): 1--1
# 你看你
# 预测结果 (index 216): 1--1
# 你这张脸可成了全球驰名品牌商标了。🤣
# 预测结果 (index 217): 0--1
# 医疗护理风险管理创新降低护理风险
# 预测结果 (index 218): 0--0
# 太自找虐
# 预测结果 (index 219): 1--1
# 特别#牛
# 预测结果 (index 220): 1--1
# 非常真想把你的头扭下来放在洗衣机里搅一搅，刚好能洗一缸衣服，虽然有点臭，但节约水资源刻不容缓。
# 预测结果 (index 221): 0--1
# 真牛牛逼
# 预测结果 (index 222): 1--1
# 非常爱得瑟
# 预测结果 (index 223): 1--1
# 文化节庆活动欢乐祥和弘扬传统文化
# 预测结果 (index 224): 0--0
# 感谢您提供的专业意见
# 预测结果 (index 225): 0--0
# 好自找虐
# 预测结果 (index 226): 1--1
# 恶心死
# 预测结果 (index 227): 1--1
# 傻逼今天上厕所，拉了一坨屎，嘿，简直就像照镜子，这屎可真像你。
# 预测结果 (index 228): 1--1
# 《营销活动方案》：策划营销活动，提高品牌知名度和产品销量
# 预测结果 (index 229): 0--0
# Pharmaceutics focuses on drug formulation development. Pharmaceutics: pharmaceutics; drug formulation: drug formulation
# 预测结果 (index 230): 0--0
# 怂货了
# 预测结果 (index 231): 1--1
# 老老狗
# 预测结果 (index 232): 1--1
# Pathology diagnosis provides a basis for disease treatment. Pathology: pathology; disease treatment: disease treatment
# 预测结果 (index 233): 0--0
# 老年医学关注老年健康
# 预测结果 (index 234): 0--0
# 我真的的很想帮你治疗，但我是一名家庭医生，而你是一个孤儿。
# 预测结果 (index 235): 0--1
# 我们会一起去河边钓鱼，享受宁静的时光，感受大自然的美好，放松自己的身心，缓解压力和疲劳，增进家人之间的感情和互动，增强自己的健康意识和自然观念，培养自己的户外活动兴趣和爱好
# 预测结果 (index 236): 0--0
# 生态环境更加优美
# 预测结果 (index 237): 0--0
# 傻.逼.年.年.有.，.今年.大丰收
# 预测结果 (index 238): 1--1
# 会议讨论深入热烈达成共识
# 预测结果 (index 239): 0--0
# 好爱得瑟
# 预测结果 (index 240): 1--1
# 玛蛋
# 预测结果 (index 241): 1--1
# 你这种人永远买不到自己合适的 因为你码没了
# 预测结果 (index 242): 1--1
# 她每天都会喝一杯茶，放松心情，享受宁静的时光
# 预测结果 (index 243): 0--0
# 医疗安全文化建设提高安全意识
# 预测结果 (index 244): 0--0
# 傻孩纸
# 预测结果 (index 245): 1--1
# 真牛~逼
# 预测结果 (index 246): 1--1
# 你是我见过的容量最大的铅笔了，装那么多笔你不累吗？
# 预测结果 (index 247): 0--1
# 真想.把.你.的.头.扭.下来.放在.洗衣机.里.搅.一.搅.，.刚好.能.洗.一缸.衣服.，.虽然.有点.臭.，.但.节约.水资源.刻不容缓.。
# 预测结果 (index 248): 1--1
# 非常我笑了
# 预测结果 (index 249): 0--1
# 我们要向前看,不错过些歪瓜劣枣怎么知道什么是好的。啊
# 预测结果 (index 250): 1--1
# 特发性血小板减少性紫癜是一种因血小板免疫性破坏，导致外周血中血小板减少的出血性疾病
# 预测结果 (index 251): 0--0
# 你妹呀
# 预测结果 (index 252): 1--1
# 企业战略清晰明确引领企业发展
# 预测结果 (index 253): 0--0
# 特别牛x
# 预测结果 (index 254): 1--1
# 疯。了。吧
# 预测结果 (index 255): 1--1
# 诗歌朗诵情感真挚传递文学力量
# 预测结果 (index 256): 0--0
# 商务谈判策略得当争取最大利益
# 预测结果 (index 257): 0--0
# 我们要向前看,不错过些歪瓜劣枣枣怎么知道什么是好的。
# 预测结果 (index 258): 1--1
# 医学研究需要加强对儿童疾病的研究和预防
# 预测结果 (index 259): 0--0
# 你想多
# 预测结果 (index 260): 1--1
# 别人.站.着.赚钱.，. .你.躺.着.。
# 预测结果 (index 261): 1--1
# 如长的丑也算残疾的话，那你就不用工作了。
# 预测结果 (index 262): 1--1
# 苍蝇#走#在#你#脸上#都#崴#脚
# 预测结果 (index 263): 1--1
# 真瞎搞
# 预测结果 (index 264): 1--1
# 狗#…#…
# 预测结果 (index 265): 1--1
# 看段子
# 预测结果 (index 266): 1--1
# 那个女生啊
# 预测结果 (index 267): 1--1
# 《项目启动仪式流程设计》：设计项目启动仪式流程，营造良好氛围
# 预测结果 (index 268): 0--0
# 其实我是
# 预测结果 (index 269): 0--1
# 傻屄年年有，今年大丰收
# 预测结果 (index 270): 1--1
# 总结很到位.感谢分享
# 预测结果 (index 271): 0--0
# 你看上去好眼熟像我昨天扔出去的那袋垃圾了
# 预测结果 (index 272): 1--1
# Medical nursing reform promotes the improvement of the nursing system. Medical nursing reform: medical nursing reform; nursing system improvement: nursing system improvement
# 预测结果 (index 273): 0--0
# 犬……
# 预测结果 (index 274): 1--1
# 特别是这世间的黑暗，造就了你不懂礼数的浅薄。
# 预测结果 (index 275): 1--1
# 我的天呐,你一定是吃了放在肮脏的桌子上的发霉的绿色面包,才会眨着美丽的大眼睛说出长沙臭豆腐一样臭的话!吧
# 预测结果 (index 276): 1--1
# 为什么不理我 是想让我变成狗不理吗
# 预测结果 (index 277): 1--1
# 主动去锻炼
# 预测结果 (index 278): 0--0
# 那个女生生
# 预测结果 (index 279): 1--1
# 特烦
# 预测结果 (index 280): 1--1
# 是这世间的黑暗造就了你不懂礼数的浅薄。
# 预测结果 (index 281): 1--1
# 字字温情.写得很棒
# 预测结果 (index 282): 0--0
# 姑娘+啊
# 预测结果 (index 283): 1--1
# 科技创新更加活跃
# 预测结果 (index 284): 0--0
# 混淆矩阵可以直观地显示模型的分类结果
# 预测结果 (index 285): 0--0
# 你你的智商跟冬天黑龙江的温度一样。
# 预测结果 (index 286): 1--1
# 摄影作品展示美轮美奂记录精彩世界
# 预测结果 (index 287): 0--0
# 很作
# 预测结果 (index 288): 1--1
# 我的天呐,你一定是吃了放在肮脏的桌子上的发霉的绿色面包,才会眨着美丽的大眼睛说出长沙臭豆腐一样臭的话!啊
# 预测结果 (index 289): 1--1
# 太装比
# 预测结果 (index 290): 1--1
# 姑娘啊呢
# 预测结果 (index 291): 1--1
# 情感真挚.写得很棒
# 预测结果 (index 292): 0--0
# 没#人理
# 预测结果 (index 293): 1--1
# 你看上去好眼熟像我昨天扔出去的那袋垃圾呢
# 预测结果 (index 294): 1--1
# 真想_把_你_的_头_扭_下来_放在_洗衣机_里_搅_一_搅_，_刚好_能_洗_一缸_衣服_，_虽然_有点_臭_，_但_节约_水资源_刻不容缓_。
# 预测结果 (index 295): 1--1
# 嘤嘤嘤
# 预测结果 (index 296): 1--1
# 你多了
# 预测结果 (index 297): 1--1
# 妈淡
# 预测结果 (index 298): 1--1
# 挺cao
# 预测结果 (index 299): 1--1
# 进度: 300/2856
# 狗……吧
# 预测结果 (index 300): 1--1
# 《人力资源规划》：满足企业发展需求，合理配置人才
# 预测结果 (index 301): 0--0
# 你的存在最美好
# 预测结果 (index 302): 0--0
# 好呦！这是谁裤裆门没拉，怎么把你漏出来了？
# 预测结果 (index 303): 1--1
# 挺嘈
# 预测结果 (index 304): 1--1
# 产品优势突出显著提升竞争力
# 预测结果 (index 305): 0--0
# 我+的+天呐+,+你+一定+是+吃+了+放在+肮脏+的+桌子+上+的+发霉+的+绿色+面包+,+才+会+眨+着+美丽+的+大+眼睛+说出+长沙+臭豆腐+一样+臭+的话+!
# 预测结果 (index 306): 1--1
# 瞎激动
# 预测结果 (index 307): 1--1
# 我们会及时跟进您的需求
# 预测结果 (index 308): 0--0
# 姑娘-啊
# 预测结果 (index 309): 1--1
# 医院提升急诊急救能力，为患者生命护航
# 预测结果 (index 310): 0--0
# 同事们一起参加团队建设活动，增强团队的合作和信任，提高团队的效率和绩效，展现团队的风采和实力，锻炼自己的团队合作能力和领导能力，培养自己的职业素养和团队精神
# 预测结果 (index 311): 0--0
# 记得 下点 调料 ， 这样 你家 人 吃 起来 才 会 有 味道
# 预测结果 (index 312): 0--1
# 欢乐的美食之旅满足味蕾
# 预测结果 (index 313): 0--0
# 创新发展更加深入
# 预测结果 (index 314): 0--0
# 呦 ！ 这 是 谁 裤裆 门 没拉 ， 怎么 把 你 漏出来 了 ？
# 预测结果 (index 315): 1--1
# 艺术论坛思想碰撞探讨艺术前沿
# 预测结果 (index 316): 0--0
# 感人肺腑的分享
# 预测结果 (index 317): 0--0
# 苍蝇_走_在_你_脸上_都_崴_脚
# 预测结果 (index 318): 1--1
# 龟孙子啊
# 预测结果 (index 319): 1--1
# 特别牛牛
# 预测结果 (index 320): 1--1
# 太坏了
# 预测结果 (index 321): 1--1
# 真苍蝇走在你脸上都崴脚
# 预测结果 (index 322): 1--1
# 内些
# 预测结果 (index 323): 1--1
# 认真总结工作失误，避免再次犯错
# 预测结果 (index 324): 0--0
# 爱得瑟的
# 预测结果 (index 325): 1--1
# 真发骚
# 预测结果 (index 326): 1--1
# 我笑了
# 预测结果 (index 327): 0--1
# 我很好，是吗
# 预测结果 (index 328): 0--0
# 逻辑很连贯.收获很多
# 预测结果 (index 329): 0--0
# 大尾巴狼的
# 预测结果 (index 330): 1--1
# 特别我笑了
# 预测结果 (index 331): 0--1
# 真想-把-你-的-头-扭-下来-放在-洗衣机-里-搅-一-搅-，-刚好-能-洗-一缸-衣服-，-虽然-有点-臭-，-但-节约-水资源-刻不容缓-。
# 预测结果 (index 332): 1--1
# 见解很有价值.收获很多
# 预测结果 (index 333): 0--0
# 出翔
# 预测结果 (index 334): 1--1
# 表子
# 预测结果 (index 335): 1--1
# 智商低
# 预测结果 (index 336): 1--1
# 挺操啊
# 预测结果 (index 337): 1--1
# 谢谢你们的悉心教导
# 预测结果 (index 338): 0--0
# 你这种人永远买不到自己合适的鞋 因为你码没了啊
# 预测结果 (index 339): 1--1
# 是这世间的黑暗，造就了了你不懂礼数的浅薄。
# 预测结果 (index 340): 1--1
# 非常砍死他
# 预测结果 (index 341): 1--1
# 好别人站着赚钱， 你躺着。
# 预测结果 (index 342): 1--1
# 《员工培训体系建设》：建设员工培训体系，提高员工素质
# 预测结果 (index 343): 0--0
# 瓜兮兮
# 预测结果 (index 344): 1--1
# 傻*逼*年*年*有*，*今年*大丰收
# 预测结果 (index 345): 1--1
# 煞逼年年有，今年大丰收
# 预测结果 (index 346): 1--1
# 屌人
# 预测结果 (index 347): 1--1
# 请您稍等片刻
# 预测结果 (index 348): 0--0
# 字字温情.写得很棒
# 预测结果 (index 349): 0--0
# 《采购成本控制方法》：介绍采购成本控制方法，降低采购成本
# 预测结果 (index 350): 0--0
# 你~是~我~见~过~的~容量~最大~的~铅笔盒~了~，~装~那么~多笔~你~不累~吗~？
# 预测结果 (index 351): 1--1
# 好家伙伙，你自己拍全家福挺孤单吧
# 预测结果 (index 352): 1--1
# 非常你是我见过的容量最大的铅笔盒了，装那么多笔你不累吗？
# 预测结果 (index 353): 0--1
# 太你想多了
# 预测结果 (index 354): 1--1
# 我讨厌你
# 预测结果 (index 355): 1--1
# 望山川
# 预测结果 (index 356): 0--0
# 太祝你们不孕不育，儿孙满堂。
# 预测结果 (index 357): 0--1
# 如果长长的丑也算残疾的话，那你就不用工作了。
# 预测结果 (index 358): 1--1
# 商业合作互利共赢共同成长
# 预测结果 (index 359): 0--0
# 非常好家伙，你自己拍全家福挺孤单吧
# 预测结果 (index 360): 0--1
# 真牛屄
# 预测结果 (index 361): 1--1
# 苍蝇走在你脸上都崴脚脚
# 预测结果 (index 362): 1--1
# 子不教父之过，你们骂人我的错。
# 预测结果 (index 363): 1--1
# 商务合作平等和谐共同进步
# 预测结果 (index 364): 0--0
# 太是这世间的黑暗，造就了你不懂礼数的浅薄。
# 预测结果 (index 365): 1--1
# 二大爷了
# 预测结果 (index 366): 1--1
# 好家伙.，.你.自己.拍.全家福.挺.孤单.吧
# 预测结果 (index 367): 0--1
# 怎么不说话了 4吃太多堵住了？
# 预测结果 (index 368): 1--1
# 医疗护理政策创新引导护理行业发展方向
# 预测结果 (index 369): 0--0
# 那个-女生
# 预测结果 (index 370): 1--1
# 特别自找虐
# 预测结果 (index 371): 1--1
# 恶心|的|妈妈|给|恶心|开门|、|恶心|到家|了|…|…
# 预测结果 (index 372): 1--1
# 你的智商跟冬天黑龙江的的温度一样。
# 预测结果 (index 373): 1--1
# 感谢您的精心建议
# 预测结果 (index 374): 0--0
# 励志用汗水与努力书写人生的辉煌篇章留下美好的印记实现人生的理想与追求
# 预测结果 (index 375): 0--0
# 那个女生吧
# 预测结果 (index 376): 1--1
# 文化事业更加繁荣
# 预测结果 (index 377): 0--0
# 病例对照研究可用于探索疾病与危险因素之间的关联
# 预测结果 (index 378): 0--0
# 音乐会表演精彩绝伦奏响美妙旋律
# 预测结果 (index 379): 0--0
# 傻呵呵
# 预测结果 (index 380): 1--1
# 干啥
# 预测结果 (index 381): 1--1
# 恶心心的妈妈给恶心开门、恶心到家了……
# 预测结果 (index 382): 1--1
# 我们会珍惜每个改进的机会
# 预测结果 (index 383): 0--0
# 我-的-天呐-,-你-一定-是-吃-了-放在-肮脏-的-桌子-上-的-发霉-的-绿色-面包-,-才-会-眨-着-美丽-的-大-眼睛-说出-长沙-臭豆腐-一样-臭-的话-!
# 预测结果 (index 384): 1--1
# 特别牛
# 预测结果 (index 385): 1--1
# 对特定人群进行癌症筛查可早期发现病变，如乳腺癌筛查、宫颈癌筛查
# 预测结果 (index 386): 0--0
# 总结很有价值.学到很多
# 预测结果 (index 387): 0--0
# 哭哭
# 预测结果 (index 388): 1--1
# 非常他特
# 预测结果 (index 389): 1--1
# 抢救危重患者
# 预测结果 (index 390): 0--0
# 好家伙，你自己拍全家福挺孤单吧
# 预测结果 (index 391): 1--1
# 好你再骂？信不信👴把你脑袋拧下来当夜壶？！
# 预测结果 (index 392): 1--1
# 挺逗呢
# 预测结果 (index 393): 1--1
# 苍蝇走在你脸上都崴脚了
# 预测结果 (index 394): 1--1
# 你想多了了
# 预测结果 (index 395): 1--1
# 骂大街
# 预测结果 (index 396): 1--1
# 挺。逗
# 预测结果 (index 397): 1--1
# 我笑了了
# 预测结果 (index 398): 0--1
# 如果说存在即合理，可我却想不出你存在的理由
# 预测结果 (index 399): 0--1
# 进度: 400/2856
# 你是虾吧？毕竟跟虾一样没有脑子
# 预测结果 (index 400): 1--1
# 你走的那天风很大，火化的时候还诈尸，一直喊没死，最后用铁链绑着烧完的。火很旺，家属很坚强一个哭的都没有，甚至有一个忍不住笑出声。路上灵车翻了骨灰盒摔了，刚要捧点灰来了一辆洒水车，众人只好把混着泥巴的骨灰，随便捧点埋了，不久之后坟头拆迁，上面开了家迪厅，每天重复播放今天是个好日子。
# 预测结果 (index 401): 0--1
# 注孤啊
# 预测结果 (index 402): 1--1
# 想和你过简单温馨的生活
# 预测结果 (index 403): 0--0
# 胰岛素治疗是控制糖尿病患者高血糖的重要手段，尤其是 1 型糖尿病患者
# 预测结果 (index 404): 0--0
# 你_脖子_上顶_的_是_肿瘤_吧
# 预测结果 (index 405): 1--1
# 医疗服务水平不断提高
# 预测结果 (index 406): 0--0
# 太没皮没脸
# 预测结果 (index 407): 1--1
# 煞笔年年有，今年大丰收
# 预测结果 (index 408): 1--1
# 很傻
# 预测结果 (index 409): 1--1
# 特别坏淫
# 预测结果 (index 410): 1--1
# 你脖子子上顶的是肿瘤吧
# 预测结果 (index 411): 1--1
# 怂货的
# 预测结果 (index 412): 1--1
# janb
# 预测结果 (index 413): 0--1
# 天不错，是吗
# 预测结果 (index 414): 0--0
# 《销售渠道拓展策略》：制定销售渠道拓展策略，提高产品销量
# 预测结果 (index 415): 0--0
# 我们要向前看,不错过些歪瓜劣枣怎么知道什么是好的。的
# 预测结果 (index 416): 1--1
# 医疗护理服务创新均等化实现公平护理
# 预测结果 (index 417): 0--0
# 二大爷呢
# 预测结果 (index 418): 1--1
# 妈炸
# 预测结果 (index 419): 1--1
# 合理饮食对于预防多种疾病至关重要，包括均衡摄入各类营养素
# 预测结果 (index 420): 0--0
# 非常diao
# 预测结果 (index 421): 1--1
# 没人理呢
# 预测结果 (index 422): 1--1
# 没皮没
# 预测结果 (index 423): 1--1
# 你屌了
# 预测结果 (index 424): 1--1
# 是#这#世间#的#黑暗#，#造就#了#你#不#懂#礼数#的#浅薄#。
# 预测结果 (index 425): 1--1
# 装比吧
# 预测结果 (index 426): 1--1
# 判别分析可以根据已知的分类信息对新样本进行分类
# 预测结果 (index 427): 0--0
# 网络上你重拳出击，现实中你蹬着三轮卖鸡
# 预测结果 (index 428): 1--1
# 我们要向前看,不错过些歪瓜劣枣怎么知道什么是好的。了
# 预测结果 (index 429): 1--1
# 眼瞎
# 预测结果 (index 430): 1--1
# 如果长的丑也算残疾的话话，那你就不用工作了。
# 预测结果 (index 431): 1--1
# 某男
# 预测结果 (index 432): 1--1
# 我很好，好不好
# 预测结果 (index 433): 0--0
# 你屌啊
# 预测结果 (index 434): 1--1
# 瞎吹牛
# 预测结果 (index 435): 1--1
# 产品性能稳定优越满足需求
# 预测结果 (index 436): 0--0
# 你-是-我-见-过-的-容量-最大-的-铅笔盒-了-，-装-那么-多笔-你-不累-吗-？
# 预测结果 (index 437): 1--1
# 大尾巴狼
# 预测结果 (index 438): 1--1
# 你的关心最温暖
# 预测结果 (index 439): 0--0
# 特别我的天呐,你一定是吃了放在肮脏的桌子上的发霉的绿色面包,才会眨着美丽的大眼睛说出长沙臭豆腐一样臭的话!
# 预测结果 (index 440): 1--1
# 只希望你吃饭有人喂 走路有人推 夜夜缠绵于病却长命百岁 不能生育却儿孙满堂 寿比昙花福如母猪
# 预测结果 (index 441): 0--1
# 大-尾巴-狼
# 预测结果 (index 442): 1--1
# 被 分手
# 预测结果 (index 443): 1--1
# 真想把你的头扭下来放在洗衣机里里搅一搅，刚好能洗一缸衣服，虽然有点臭，但节约水资源刻不容缓。
# 预测结果 (index 444): 0--1
# 精虫上脑
# 预测结果 (index 445): 1--1
# 别人站着赚钱， 你躺着。了
# 预测结果 (index 446): 1--1
# 提供基层医疗服务
# 预测结果 (index 447): 0--0
# 好疯了吧
# 预测结果 (index 448): 1--1
# 高端黑吧
# 预测结果 (index 449): 1--1
# 医疗护理服务均等化实现公平护理
# 预测结果 (index 450): 0--0
# 老师们关爱学生成长发展，引导学生进步
# 预测结果 (index 451): 0--0
# 逼能
# 预测结果 (index 452): 1--1
# 诗歌活动诗意盎然弘扬文学艺术
# 预测结果 (index 453): 0--0
# 合作前景美好广阔充满希望
# 预测结果 (index 454): 0--0
# 感谢命运的每一次安排
# 预测结果 (index 455): 0--0
# 真牛+逼
# 预测结果 (index 456): 1--1
# 真牛*逼
# 预测结果 (index 457): 1--1
# 产品品质优良可靠赢得口碑
# 预测结果 (index 458): 0--0
# 你*再*骂*？*信不信*👴*把*你*脑袋*拧下来*当*夜壶*？*！
# 预测结果 (index 459): 1--1
# 你 看上去 好 眼熟 像 我 昨天 扔出去 的 那袋 垃圾
# 预测结果 (index 460): 1--1
# 开心露笑容
# 预测结果 (index 461): 0--0
# 就是嫉妒我户口本可以翻页（说他是孤儿）了
# 预测结果 (index 462): 1--1
# 特别疯了吧
# 预测结果 (index 463): 1--1
# 太坏淫
# 预测结果 (index 464): 1--1
# 制药企业提升企业数字化转型水平，提高企业运营效率和管理水平
# 预测结果 (index 465): 0--0
# 好不作不死
# 预测结果 (index 466): 1--1
# 非常装比
# 预测结果 (index 467): 1--1
# 制定工作目标计划，努力达成目标
# 预测结果 (index 468): 0--0
# 疯+了+吧
# 预测结果 (index 469): 1--1
# 真想把你的头扭下来放在洗衣机里搅一搅，刚好能洗一缸衣服，，虽然有点臭，但节约水资源刻不容缓。
# 预测结果 (index 470): 1--1
# 客户服务贴心周到提升满意度
# 预测结果 (index 471): 0--0
# 傻笔年年有，今年大丰收
# 预测结果 (index 472): 1--1
# 生态文明理念深入
# 预测结果 (index 473): 0--0
# 特别傻逼年年有，今年大丰收
# 预测结果 (index 474): 1--1
# 瞧瞧不起
# 预测结果 (index 475): 1--1
# 我的天呐,你一定是吃了放在肮脏的桌子上的发霉的绿色面包,才会眨着美丽的大眼睛说出长沙臭腐一样臭的话!
# 预测结果 (index 476): 1--1
# 积极参与团队活动，增强团队合作精神
# 预测结果 (index 477): 0--0
# 抗精神病药物可控制精神分裂症患者的幻觉、妄想等症状
# 预测结果 (index 478): 0--0
# 真想把你的头扭下来放在洗衣机里搅一搅，刚好能洗一缸衣服，虽然有点臭，但节约水资源刻不容缓。
# 预测结果 (index 479): 0--1
# 别人_站_着_赚钱_，_ _你_躺_着_。
# 预测结果 (index 480): 1--1
# 分析很深入.学到很多
# 预测结果 (index 481): 0--0
# 瞧我这记性，又把你当人看了
# 预测结果 (index 482): 1--1
# 好家伙你自己拍全家福挺孤单吧
# 预测结果 (index 483): 0--1
# 思想龌龊
# 预测结果 (index 484): 1--1
# 太如果长的丑也算残疾的话，那你就不用工作了。
# 预测结果 (index 485): 1--1
# 恶心的妈妈给恶心门、恶心到家了……
# 预测结果 (index 486): 1--1
# 太diao
# 预测结果 (index 487): 1--1
# 合作意向积极主动共同推进
# 预测结果 (index 488): 0--0
# 诗歌朗诵情感真挚传递文学力量
# 预测结果 (index 489): 0--0
# 被分手
# 预测结果 (index 490): 1--1
# 是这世间的黑暗，造就了你不懂礼数的浅薄。呢
# 预测结果 (index 491): 1--1
# 傻不傻
# 预测结果 (index 492): 1--1
# 产品品质顶级可靠赢得口碑
# 预测结果 (index 493): 0--0
# 医院开展义诊活动，服务社区百姓
# 预测结果 (index 494): 0--0
# 太挺逗
# 预测结果 (index 495): 1--1
# 没水准
# 预测结果 (index 496): 1--1
# 太狗……
# 预测结果 (index 497): 1--1
# 真狗……
# 预测结果 (index 498): 1--1
# 二_大爷
# 预测结果 (index 499): 1--1
# 进度: 500/2856
# 哭啊
# 预测结果 (index 500): 1--1
# 宽待人
# 预测结果 (index 501): 0--0
# 贱样
# 预测结果 (index 502): 1--1
# 医疗服务均等化实现公平医疗
# 预测结果 (index 503): 0--0
# 你有几个妈啊这么豪横
# 预测结果 (index 504): 1--1
# 自_嗨
# 预测结果 (index 505): 1--1
# 字里行间都是爱.感谢
# 预测结果 (index 506): 0--0
# 死胖子
# 预测结果 (index 507): 1--1
# 龟孙子吧
# 预测结果 (index 508): 1--1
# 医疗护理临床实践创新服务患者健康
# 预测结果 (index 509): 0--0
# 我|的|天呐|,|你|一定|是|吃|了|放在|肮脏|的|桌子|上|的|发霉|的|绿色|面包|,|才|会|眨|着|美丽|的|大|眼睛|说出|长沙|臭豆腐|一样|臭|的话|!
# 预测结果 (index 510): 1--1
# 是这世间的黑暗，造就了你不不懂礼数的浅薄。
# 预测结果 (index 511): 1--1
# 就是~嫉妒~我~户口本~可以~翻页~（~说~他~是~孤儿~）
# 预测结果 (index 512): 1--1
# 就是*嫉妒*我*户口本*可以*翻页*（*说*他*是*孤儿*）
# 预测结果 (index 513): 1--1
# 团队合作紧密协作共同进步
# 预测结果 (index 514): 0--0
# 瞎搞了
# 预测结果 (index 515): 1--1
# 会议决策科学合理高效执行
# 预测结果 (index 516): 0--0
# 我_的_天呐_,_你_一定_是_吃_了_放在_肮脏_的_桌子_上_的_发霉_的_绿色_面包_,_才_会_眨_着_美丽_的_大_眼睛_说出_长沙_臭豆腐_一样_臭_的话_!
# 预测结果 (index 517): 1--1
# 生态文明建设深化
# 预测结果 (index 518): 0--0
# 医疗护理临床实践创新服务患者健康
# 预测结果 (index 519): 0--0
# 龟~孙子
# 预测结果 (index 520): 1--1
# 感谢一路相伴的温暖
# 预测结果 (index 521): 0--0
# 二~大爷
# 预测结果 (index 522): 1--1
# 坚持梦想.绽放自我
# 预测结果 (index 523): 0--0
# 别怂
# 预测结果 (index 524): 1--1
# 花朵绽娇艳
# 预测结果 (index 525): 0--0
# 财务运营稳健高效确保发展
# 预测结果 (index 526): 0--0
# 龟.孙子
# 预测结果 (index 527): 1--1
# 总结很精准.感谢分享
# 预测结果 (index 528): 0--0
# 太发骚
# 预测结果 (index 529): 1--1
# 缺心眼
# 预测结果 (index 530): 1--1
# 神经病
# 预测结果 (index 531): 1--1
# 温暖人心的文字.很棒
# 预测结果 (index 532): 0--0
# 产业发展更加优质
# 预测结果 (index 533): 0--0
# 会议认真听
# 预测结果 (index 534): 0--0
# 装比呢
# 预测结果 (index 535): 1--1
# 践b
# 预测结果 (index 536): 1--1
# 制药企业加强原材料质量管理，确保药品源头安全
# 预测结果 (index 537): 0--0
# 非常老狗
# 预测结果 (index 538): 1--1
# Cardiology focuses on heart health. Cardiology: cardiology; heart health: heart health
# 预测结果 (index 539): 0--0
# 特别他特
# 预测结果 (index 540): 1--1
# 他特了
# 预测结果 (index 541): 1--1
# qtmd
# 预测结果 (index 542): 1--1
# 感恩之心
# 预测结果 (index 543): 0--0
# 乃们
# 预测结果 (index 544): 1--1
# 挺#逗
# 预测结果 (index 545): 1--1
# 如果长的丑也算残疾的话，那你就不用工作了。。
# 预测结果 (index 546): 1--1
# 感动至深的分享
# 预测结果 (index 547): 0--0
# 保障人群健康
# 预测结果 (index 548): 0--0
# 发骚
# 预测结果 (index 549): 1--1
# 解释得非常清楚.受益良多
# 预测结果 (index 550): 0--0
# 你是我见过的容量最最大的铅笔盒了，装那么多笔你不累吗？
# 预测结果 (index 551): 0--1
# 我~真的~很~想~帮~你~治疗~，~但~我~是~一名~家庭医生~，~而~你~是~一个~孤儿~。
# 预测结果 (index 552): 0--1
# 龟*孙子
# 预测结果 (index 553): 1--1
# 牛顿用苹果发现了万有引力 你就是被苹果砸得死无全尸也 还是什么都发现不了
# 预测结果 (index 554): 1--1
# Medical environment management creates a comfortable medical environment. Medical environment management: medical environment management; comfortable medical environment: comfortable medical environment
# 预测结果 (index 555): 0--0
# 好你想多了
# 预测结果 (index 556): 1--1
# 没皮没脸啊
# 预测结果 (index 557): 1--1
# 关我屁事
# 预测结果 (index 558): 1--1
# 祝你们不孕孕不育，儿孙满堂。
# 预测结果 (index 559): 0--1
# 好大尾巴狼
# 预测结果 (index 560): 1--1
# 你的长相很提神的说！🙊(～￣▽￣)～
# 预测结果 (index 561): 0--1
# 最近猪肉涨价了，你是不是也以为自己跟着水涨船高了？
# 预测结果 (index 562): 0--1
# 傻逼年年有有，今年大丰收
# 预测结果 (index 563): 1--1
# 傻叼
# 预测结果 (index 564): 1--1
# 蛋逼
# 预测结果 (index 565): 1--1
# 真你看上去好眼熟像我昨天扔出去的那袋垃圾
# 预测结果 (index 566): 1--1
# 艺术讲座内容丰富传授艺术知识
# 预测结果 (index 567): 0--0
# 特爱啊
# 预测结果 (index 568): 0--1
# 怂货啊
# 预测结果 (index 569): 1--1
# 跪添
# 预测结果 (index 570): 1--1
# 同学们积极参加科技创新活动，培养创新精神
# 预测结果 (index 571): 0--0
# 你是我见过的容量最大的铅盒了，装那么多笔你不累吗？
# 预测结果 (index 572): 0--1
# 非常我们要向前看,不错过些歪瓜劣枣怎么知道什么是好的。
# 预测结果 (index 573): 1--1
# 欠干
# 预测结果 (index 574): 1--1
# 疯#了#吧
# 预测结果 (index 575): 1--1
# 好他特
# 预测结果 (index 576): 1--1
# 好龟孙子
# 预测结果 (index 577): 1--1
# 特别就是嫉妒我户口本可以翻页（说他是孤儿）
# 预测结果 (index 578): 1--1
# 请问您需要具体的时间表吗?
# 预测结果 (index 579): 0--0
# 特爱装
# 预测结果 (index 580): 1--1
# 有人笑我
# 预测结果 (index 581): 0--1
# 真牛逼啊
# 预测结果 (index 582): 1--1
# 被分手啊
# 预测结果 (index 583): 1--1
# 特么算
# 预测结果 (index 584): 1--1
# 傻#逼#年#年#有#，#今年#大丰收
# 预测结果 (index 585): 1--1
# 特别没皮没脸
# 预测结果 (index 586): 1--1
# 恶心的老母老母给恶心开门、恶心到家了……
# 预测结果 (index 587): 1--1
# 仔细#看看#我#这#巴掌#真#适合#你#那大#脸
# 预测结果 (index 588): 1--1
# 爱谁谁
# 预测结果 (index 589): 1--1
# 特别真想把你的头扭下来放在洗衣机里搅一搅，刚好能洗一缸衣服，虽然有点臭，但节约水资源刻不容缓。
# 预测结果 (index 590): 0--1
# 没人理啊
# 预测结果 (index 591): 1--1
# 砍死他了
# 预测结果 (index 592): 1--1
# 真牛x
# 预测结果 (index 593): 1--1
# 《合作协议履行监督》：加强合作协议履行监督，确保双方权益
# 预测结果 (index 594): 0--0
# 恶意满满
# 预测结果 (index 595): 1--1
# 市场拓展积极进取开拓市场
# 预测结果 (index 596): 0--0
# 作业按时交
# 预测结果 (index 597): 0--0
# 太真想把你的头扭下来放在洗衣机里搅一搅，刚好能洗一缸衣服，虽然有点臭，但节约水资源刻不容缓。
# 预测结果 (index 598): 1--1
# 别站着赚钱， 你躺着。
# 预测结果 (index 599): 1--1
# 进度: 600/2856
# 怎么不说话了 shi吃太多堵住了？
# 预测结果 (index 600): 1--1
# 笑死
# 预测结果 (index 601): 1--1
# 好装比
# 预测结果 (index 602): 1--1
# 感恩每一个努力的日子
# 预测结果 (index 603): 0--0
# 自找~虐
# 预测结果 (index 604): 1--1
# 我们人多有钱就足够了，哪像你们，穷的出殡都得集资
# 预测结果 (index 605): 1--1
# 高端黑了
# 预测结果 (index 606): 1--1
# 摄影作品展示美轮美奂记录精彩世界
# 预测结果 (index 607): 0--0
# 大*尾巴*狼
# 预测结果 (index 608): 1--1
# 如果|长|的|丑|也|算|残疾|的话|，|那|你|就|不用|工作|了|。
# 预测结果 (index 609): 1--1
# 欢乐的甜品时光甜蜜无比
# 预测结果 (index 610): 0--0
# 你*看上去*好*眼熟*像*我*昨天*扔出去*的*那袋*垃圾
# 预测结果 (index 611): 1--1
# 制药企业遵守法律法规，规范市场经营行为
# 预测结果 (index 612): 0--0
# 太特烦
# 预测结果 (index 613): 1--1
# 人站着赚钱， 你躺着。
# 预测结果 (index 614): 1--1
# 不作-不-死
# 预测结果 (index 615): 1--1
# 文化节庆活动欢乐祥和弘扬传统文化
# 预测结果 (index 616): 0--0
# 那个+女生
# 预测结果 (index 617): 1--1
# 感动人心的分享
# 预测结果 (index 618): 0--0
# 你长得这么丑长得倒挺美的
# 预测结果 (index 619): 1--1
# 怎么不说话了 屎吃太多堵住了？呢
# 预测结果 (index 620): 1--1
# 麻辣隔壁
# 预测结果 (index 621): 1--1
# 欢乐的亲子绘画活动充满创意与温馨
# 预测结果 (index 622): 0--0
# 傻+逼+年+年+有+，+今年+大丰收
# 预测结果 (index 623): 1--1
# 你 屌
# 预测结果 (index 624): 1--1
# 特别瞧不起
# 预测结果 (index 625): 1--1
# 医疗护理感染控制预防医院感染
# 预测结果 (index 626): 0--0
# 太爱得瑟
# 预测结果 (index 627): 1--1
# 姑娘啊啊
# 预测结果 (index 628): 1--1
# 特别牛了
# 预测结果 (index 629): 1--1
# 有你真好
# 预测结果 (index 630): 0--0
# 挺-逗
# 预测结果 (index 631): 1--1
# 努力的人最出彩
# 预测结果 (index 632): 0--0
# 创新发展更加深入
# 预测结果 (index 633): 0--0
# 牛-x
# 预测结果 (index 634): 1--1
# 教育改革更加深化
# 预测结果 (index 635): 0--0
# 听溪流
# 预测结果 (index 636): 0--0
# 别人+站+着+赚钱+，+ +你+躺+着+。
# 预测结果 (index 637): 1--1
# 《市场调研报告分析》：深入分析市场调研结果，为决策提供有力支持
# 预测结果 (index 638): 0--0
# 非常特爱
# 预测结果 (index 639): 0--1
# 我笑了的
# 预测结果 (index 640): 0--1
# 怎么不说话了 屎吃太多堵住了？啊
# 预测结果 (index 641): 1--1
# 植绿树
# 预测结果 (index 642): 0--0
# 你#再#骂#？#信不信#👴#把#你#脑袋#拧下来#当#夜壶#？#！
# 预测结果 (index 643): 1--1
# 医学研究需要加强对睡眠障碍的研究和治疗
# 预测结果 (index 644): 0--0
# 感恩每一个温馨的家庭时刻
# 预测结果 (index 645): 0--0
# 励志在奋斗中不断超越自我实现人生价值追求卓越与完美
# 预测结果 (index 646): 0--0
# 好家伙，你自己拍全福挺孤单吧
# 预测结果 (index 647): 1--1
# 请问您对这个计划满意吗?
# 预测结果 (index 648): 0--0
# 太大尾巴狼
# 预测结果 (index 649): 1--1
# 你的的智商跟冬天黑龙江的温度一样。
# 预测结果 (index 650): 1--1
# 艰不拆
# 预测结果 (index 651): 1--1
# 注孤
# 预测结果 (index 652): 1--1
# Electronic medical records facilitate medical recording. Electronic medical records: electronic medical records; medical recording: medical recording
# 预测结果 (index 653): 0--0
# 太怎么不说话了 屎吃太多堵住了？
# 预测结果 (index 654): 1--1
# 制杖的
# 预测结果 (index 655): 1--1
# 狗*…*…
# 预测结果 (index 656): 1--1
# 放心不仅你单身，你的cp也不会成真。
# 预测结果 (index 657): 0--1
# 狗血
# 预测结果 (index 658): 1--1
# 真想。把。你。的。头。扭。下来。放在。洗衣机。里。搅。一。搅。，。刚好。能。洗。一缸。衣服。，。虽然。有点。臭。，。但。节约。水资源。刻不容缓。。
# 预测结果 (index 659): 1--1
# 太二大爷
# 预测结果 (index 660): 1--1
# 滚粗
# 预测结果 (index 661): 1--1
# 黑出翔
# 预测结果 (index 662): 1--1
# 真你想多了
# 预测结果 (index 663): 1--1
# 怎么不说话了 屎太多堵住了？
# 预测结果 (index 664): 1--1
# 挺逗
# 预测结果 (index 665): 1--1
# 老gou
# 预测结果 (index 666): 1--1
# 真牛_逼
# 预测结果 (index 667): 1--1
# 市场调研深入广泛掌握信息
# 预测结果 (index 668): 0--0
# 蜜汁自信
# 预测结果 (index 669): 0--1
# 你.想.多.了
# 预测结果 (index 670): 1--1
# 没皮没脸
# 预测结果 (index 671): 1--1
# 我们期待继续合作
# 预测结果 (index 672): 0--0
# 挺c
# 预测结果 (index 673): 1--1
# 特没
# 预测结果 (index 674): 1--1
# 太你再骂？信不信👴把你脑袋拧下来当夜壶？！
# 预测结果 (index 675): 1--1
# 你_这种_人_永远_买不到_自己_合适_的_鞋_ _因为_你码_没_了
# 预测结果 (index 676): 1--1
# 励志在逆境中崛起
# 预测结果 (index 677): 0--0
# 好我笑了
# 预测结果 (index 678): 0--1
# 真不作不死
# 预测结果 (index 679): 1--1
# 好家伙#，#你#自己#拍#全家福#挺#孤单#吧
# 预测结果 (index 680): 0--1
# 非常你屌
# 预测结果 (index 681): 1--1
# 怂怂
# 预测结果 (index 682): 1--1
# 你的智商跟冬天黑龙江的温度一样。呢
# 预测结果 (index 683): 1--1
# 是这世间的黑暗，造就了你不懂礼数的浅薄。了
# 预测结果 (index 684): 1--1
# Medical nursing quality evaluation ensures nursing service quality. Medical nursing quality evaluation: medical nursing quality evaluation; nursing service quality: nursing service quality
# 预测结果 (index 685): 0--0
# 物理治疗有效果
# 预测结果 (index 686): 0--0
# 非常挺操
# 预测结果 (index 687): 0--1
# 娘们
# 预测结果 (index 688): 1--1
# 商务合作平等和谐共同进步
# 预测结果 (index 689): 0--0
# 分析很细致.获益良多
# 预测结果 (index 690): 0--0
# 姑娘_啊
# 预测结果 (index 691): 1--1
# 我笑了吧
# 预测结果 (index 692): 0--1
# 他热衷于学习书法，锻炼自己的耐心和专注力
# 预测结果 (index 693): 0--0
# 感谢您的包容和理解
# 预测结果 (index 694): 0--0
# 我真的很想帮你治疗，但我是一名家庭医生，而你是个孤儿。
# 预测结果 (index 695): 0--1
# 真想去给你烧香 才发现你还没死
# 预测结果 (index 696): 1--1
# blx
# 预测结果 (index 697): 1--1
# 我们要向前看,不错过些歪瓜劣枣怎么知道什么是好的。吧
# 预测结果 (index 698): 1--1
# 美术展览作品精美彰显艺术魅力
# 预测结果 (index 699): 0--0
# 进度: 700/2856
# 高端|黑
# 预测结果 (index 700): 1--1
# 你|再|骂|？|信不信|👴|把|你|脑袋|拧下来|当|夜壶|？|！
# 预测结果 (index 701): 1--1
# diao
# 预测结果 (index 702): 1--1
# 伦理审查委员会负责确保研究符合伦理规范
# 预测结果 (index 703): 0--0
# 想.去.给.你.烧香. .才.发现.你.还.没.死
# 预测结果 (index 704): 1--1
# 我们+要+向前+看+,+不错+过些+歪+瓜劣+枣+怎么+知道+什么+是+好+的+。
# 预测结果 (index 705): 1--1
# 感恩生活中的每一份惊喜
# 预测结果 (index 706): 0--0
# 预防接种降低疾病风险
# 预测结果 (index 707): 0--0
# 最可悲
# 预测结果 (index 708): 1--1
# 特烦的
# 预测结果 (index 709): 1--1
# 长期随访研究可以观察疾病的慢性进展和治疗的长期效果
# 预测结果 (index 710): 0--0
# 你*屌
# 预测结果 (index 711): 1--1
# 特烦
# 预测结果 (index 712): 1--1
# 科技创新更加深入
# 预测结果 (index 713): 0--0
# 深圳禁止食狗肉了，原来是在保护你和你全家啊😃
# 预测结果 (index 714): 1--1
# 低情商
# 预测结果 (index 715): 1--1
# 会议组织精细高效确保成功
# 预测结果 (index 716): 0--0
# 专业水准很高.佩服
# 预测结果 (index 717): 0--0
# 好家伙，你自己拍全家福挺孤单吧了
# 预测结果 (index 718): 1--1
# 请问您对服务还有什么建议?
# 预测结果 (index 719): 0--0
# 按时吃晚餐
# 预测结果 (index 720): 0--0
# 真牛比
# 预测结果 (index 721): 1--1
# 事儿逼
# 预测结果 (index 722): 1--1
# 你-看上去-好-眼熟-像-我-昨天-扔出去-的-那袋-垃圾
# 预测结果 (index 723): 1--1
# 非常特烦
# 预测结果 (index 724): 1--1
# 傻_逼_年_年_有_，_今年_大丰收
# 预测结果 (index 725): 1--1
# 坏淫了
# 预测结果 (index 726): 1--1
# 真牛逼了
# 预测结果 (index 727): 1--1
# 你_屌
# 预测结果 (index 728): 1--1
# 我|真的|很|想|帮|你|治疗|，|但|我|是|一名|家庭医生|，|而|你|是|一个|孤儿|。
# 预测结果 (index 729): 0--1
# 恶心_的_妈妈_给_恶心_开门_、_恶心_到家_了_…_…
# 预测结果 (index 730): 1--1
# 关注行业未来发展，提前布局规划
# 预测结果 (index 731): 0--0
# 想去给你烧香 才发现还没死
# 预测结果 (index 732): 1--1
# 你再骂？信不信👴把你袋拧下来当夜壶？！
# 预测结果 (index 733): 1--1
# 《企业战略规划调整》：根据市场变化调整企业战略规划，确保企业持续发展
# 预测结果 (index 734): 0--0
# gay啊
# 预测结果 (index 735): 1--1
# 瞎搞
# 预测结果 (index 736): 1--1
# 牛x呢
# 预测结果 (index 737): 1--1
# 你是上帝失手扔下来的垃圾桶吗？
# 预测结果 (index 738): 1--1
# 你再骂？信不信👴把你脑袋拧下来当夜壶？！
# 预测结果 (index 739): 1--1
# 《员工手册》：规范员工行为，保障员工权益
# 预测结果 (index 740): 0--0
# 孤儿弟弟攒点钱看看你的脑膜炎，多活几天看看美丽的世界好不好
# 预测结果 (index 741): 0--1
# 真想把你的头扭下来放在洗衣机里搅一搅，刚好能洗一缸衣服，虽然有点臭，但节约水资源刻不容缓。呢
# 预测结果 (index 742): 1--1
# 傻逼年年，今年大丰收
# 预测结果 (index 743): 1--1
# 非常呦！这是谁裤裆门没拉，怎么把你漏出来了？
# 预测结果 (index 744): 1--1
# 挺 逗
# 预测结果 (index 745): 1--1
# 结果部分要客观呈现数据，避免主观评价
# 预测结果 (index 746): 0--0
# 永远爱我的家人
# 预测结果 (index 747): 0--0
# 傻得可以
# 预测结果 (index 748): 1--1
# 大尾巴
# 预测结果 (index 749): 1--1
# 你的智商跟冬天黑龙江的温度一样。的
# 预测结果 (index 750): 1--1
# 记得下点调料，这样你家人吃起来才会有味道了
# 预测结果 (index 751): 0--1
# 医疗护理应急救援创新保障公共安全
# 预测结果 (index 752): 0--0
# 制定职业发展计划，逐步实现目标
# 预测结果 (index 753): 0--0
# 贱+b
# 预测结果 (index 754): 1--1
# 怎么+不+说话+了+ +屎+吃+太+多+堵住+了+？
# 预测结果 (index 755): 1--1
# 还嘴
# 预测结果 (index 756): 1--1
# 记得+下点+调料+，+这样+你家+人+吃+起来+才+会+有+味道
# 预测结果 (index 757): 0--1
# 大 尾巴 狼
# 预测结果 (index 758): 1--1
# 想和你做一辈子的知己
# 预测结果 (index 759): 0--0
# 二*大爷
# 预测结果 (index 760): 1--1
# 城市功能更加完备
# 预测结果 (index 761): 0--0
# 挺逗了
# 预测结果 (index 762): 1--1
# 感恩每一个充满爱的日子
# 预测结果 (index 763): 0--0
# 呦！这是谁裤裆门没拉，怎么把你漏出来来了？
# 预测结果 (index 764): 1--1
# diao呢
# 预测结果 (index 765): 1--1
# 感恩每一个关心我们的人
# 预测结果 (index 766): 0--0
# 你是我的好老师
# 预测结果 (index 767): 0--0
# 天冷了，记得给你棺材加床被子别冻着
# 预测结果 (index 768): 1--1
# 你的痴商跟冬天黑龙江的温度一样。
# 预测结果 (index 769): 1--1
# 记得下下点调料，这样你家人吃起来才会有味道
# 预测结果 (index 770): 0--1
# 真想把你的头扭下来放在洗衣机里搅一搅，刚好能洗一缸衣服，虽然有点臭，但节约水资源刻不容缓。。
# 预测结果 (index 771): 0--1
# 说别
# 预测结果 (index 772): 1--1
# 脑袋进水
# 预测结果 (index 773): 1--1
# 真想把你的头扭下来放在洗衣机里搅一搅，刚好能洗一缸衣服，虽虽然有点臭，但节约水资源刻不容缓。
# 预测结果 (index 774): 0--1
# 特别我们要向前看,不错过些歪瓜劣枣怎么知道什么是好的。
# 预测结果 (index 775): 1--1
# 如果长的丑也算残疾的话，那就不用工作了。
# 预测结果 (index 776): 1--1
# 太特别牛
# 预测结果 (index 777): 1--1
# 你是我的助手
# 预测结果 (index 778): 0--0
# 你看上去好眼熟像我昨天扔出去的那袋垃垃圾
# 预测结果 (index 779): 1--1
# 医院加强医院科研管理，提高科研成果转化能力
# 预测结果 (index 780): 0--0
# 真自嗨
# 预测结果 (index 781): 1--1
# 我_笑_了
# 预测结果 (index 782): 1--1
# 医疗护理教育培养专业护理人才
# 预测结果 (index 783): 0--0
# 人品差
# 预测结果 (index 784): 1--1
# 特别牛的
# 预测结果 (index 785): 1--1
# 你是我见过的容量最大的铅笔盒了，装那么多笔你你不累吗？
# 预测结果 (index 786): 0--1
# 没*人理
# 预测结果 (index 787): 1--1
# 他会在假期里去徒步旅行，挑战自己的体力和耐力，欣赏自然风光
# 预测结果 (index 788): 0--0
# 坑爹货
# 预测结果 (index 789): 1--1
# 你脖子上顶的是肿瘤吧呢
# 预测结果 (index 790): 1--1
# 好我真的很想帮你治疗，但我是一名家庭医生，而你是一个孤儿。
# 预测结果 (index 791): 0--1
# 牛x吧
# 预测结果 (index 792): 1--1
# Remote medical consultation realizes cross-regional medical services. Remote medical consultation: remote medical consultation; cross-regional medical services: cross-regional medical services
# 预测结果 (index 793): 0--0
# 医疗护理服务流程创新优化提高效率
# 预测结果 (index 794): 0--0
# 你.的.智商.跟.冬天.黑龙江.的.温度.一样.。
# 预测结果 (index 795): 1--1
# 我很好，也棒
# 预测结果 (index 796): 0--0
# 她每周都会去做美容护理，让自己更加美丽自信
# 预测结果 (index 797): 0--0
# 不作_不_死
# 预测结果 (index 798): 1--1
# 瞧不起了
# 预测结果 (index 799): 1--1
# 进度: 800/2856
# 保持希望.勇敢向前
# 预测结果 (index 800): 0--0
# 你*这种*人*永远*买不到*自己*合适*的*鞋* *因为*你码*没*了
# 预测结果 (index 801): 1--1
# 狗……了
# 预测结果 (index 802): 1--1
# 医疗服务更加优质
# 预测结果 (index 803): 0--0
# 你~这种~人~永远~买不到~自己~合适~的~鞋~ ~因为~你码~没~了
# 预测结果 (index 804): 1--1
# 真想把你的头扭下来放在洗衣机里搅一搅，刚好能洗一缸衣服，虽然有点臭，，但节约水资源刻不容缓。
# 预测结果 (index 805): 0--1
# 仔细看看我这巴掌真适合你那大脸
# 预测结果 (index 806): 1--1
# gay呢
# 预测结果 (index 807): 1--1
# 欢乐的庆祝活动热闹非凡
# 预测结果 (index 808): 0--0
# 真牛逼吧
# 预测结果 (index 809): 1--1
# 机器学习算法可以用于疾病的预测和分类
# 预测结果 (index 810): 0--0
# 砍死他的
# 预测结果 (index 811): 1--1
# 财务运营健康有序确保发展
# 预测结果 (index 812): 0--0
# 二 大爷
# 预测结果 (index 813): 1--1
# 苍蝇~走~在~你~脸上~都~崴~脚
# 预测结果 (index 814): 1--1
# 我的天呐,你一定是吃了放在肮脏的桌子上的发霉的绿色面包,才会眨着美丽的大眼睛说出长沙臭豆腐一样臭的话!呢
# 预测结果 (index 815): 1--1
# 恶心的妈妈给恶心开门、恶心到家了……
# 预测结果 (index 816): 1--1
# 医疗护理继续教育创新提升护理人员水平
# 预测结果 (index 817): 0--0
# 自找。虐
# 预测结果 (index 818): 1--1
# 大尾尾巴狼
# 预测结果 (index 819): 1--1
# 好仔细看看我这巴掌真适合你那大脸
# 预测结果 (index 820): 0--1
# 发骚啊
# 预测结果 (index 821): 1--1
# 欢乐的歌唱传递幸福
# 预测结果 (index 822): 0--0
# 认真总结工作经验，不断提升自己
# 预测结果 (index 823): 0--0
# 市场拓展努力进取开拓市场
# 预测结果 (index 824): 0--0
# 贱~b
# 预测结果 (index 825): 1--1
# 分析很专业.学习了
# 预测结果 (index 826): 0--0
# 读来让人心暖.感动
# 预测结果 (index 827): 0--0
# 别闹
# 预测结果 (index 828): 1--1
# 你。这种。人。永远。买不到。自己。合适。的。鞋。 。因为。你码。没。了
# 预测结果 (index 829): 1--1
# 不自知的东西，照了镜子也没有用。——钱钟书
# 预测结果 (index 830): 0--1
# 他勇敢面对工作挑战，展现个人能力
# 预测结果 (index 831): 0--0
# 幽门螺杆菌感染引起的胃病需采用四联疗法进行根治
# 预测结果 (index 832): 0--0
# 仔细看看我这巴掌真适合你那大脸了
# 预测结果 (index 833): 1--1
# 真你脖子上顶的是肿瘤吧
# 预测结果 (index 834): 1--1
# 如果*长*的*丑*也*算*残疾*的话*，*那*你*就*不用*工作*了*。
# 预测结果 (index 835): 1--1
# 使用合适的统计软件对数据进行分析，如 SPSS
# 预测结果 (index 836): 0--0
# 蠢比
# 预测结果 (index 837): 1--1
# 你再骂？信不信👴把你脑袋拧下来当夜壶？？！
# 预测结果 (index 838): 1--1
# 医疗器械的研发和应用需要符合安全标准和临床需求
# 预测结果 (index 839): 0--0
# 苍蝇-走-在-你-脸上-都-崴-脚
# 预测结果 (index 840): 1--1
# 太别人站着赚钱， 你躺着。
# 预测结果 (index 841): 1--1
# Medical team collaboration improves medical service quality. Medical team collaboration: medical team collaboration; medical service quality: medical service quality
# 预测结果 (index 842): 0--0
# 特别没人理
# 预测结果 (index 843): 1--1
# 特别不作不死
# 预测结果 (index 844): 1--1
# 产品优势鲜明卓越提升竞争力
# 预测结果 (index 845): 0--0
# 二.大爷
# 预测结果 (index 846): 1--1
# 挺糙
# 预测结果 (index 847): 1--1
# 太你脖子上顶的是肿瘤吧
# 预测结果 (index 848): 1--1
# 真牛笔
# 预测结果 (index 849): 1--1
# 太记得下点调料，这样你家人吃起来才会有味道
# 预测结果 (index 850): 0--1
# 就是-嫉妒-我-户口本-可以-翻页-（-说-他-是-孤儿-）
# 预测结果 (index 851): 1--1
# 那个 女生
# 预测结果 (index 852): 1--1
# 被分手的
# 预测结果 (index 853): 1--1
# 是是这世间的黑暗，造就了你不懂礼数的浅薄。
# 预测结果 (index 854): 1--1
# 真恶心的妈妈给恶心开门、恶心到家了……
# 预测结果 (index 855): 1--1
# 字字珠玑.情真意切
# 预测结果 (index 856): 0--0
# 每天想见到你的笑容
# 预测结果 (index 857): 0--0
# 宫颈炎可根据病原体类型选择合适的抗生素或物理治疗
# 预测结果 (index 858): 0--0
# 顾小北
# 预测结果 (index 859): 1--1
# 自找虐了
# 预测结果 (index 860): 1--1
# 自找虐吧
# 预测结果 (index 861): 1--1
# 怂货吧
# 预测结果 (index 862): 1--1
# 发骚了
# 预测结果 (index 863): 1--1
# 我草
# 预测结果 (index 864): 1--1
# 傻逼年年有，今年大丰收啊
# 预测结果 (index 865): 1--1
# 赏百花
# 预测结果 (index 866): 0--0
# 她努力提高领导能力，带领团队前进
# 预测结果 (index 867): 0--0
# 想|去|给|你|烧香| |才|发现|你|还|没|死
# 预测结果 (index 868): 1--1
# 请问您觉得这个思路如何?
# 预测结果 (index 869): 0--0
# 仔细看看我这巴掌真适合你那大脸的
# 预测结果 (index 870): 1--1
# 我永远支持你
# 预测结果 (index 871): 0--0
# 牛_x
# 预测结果 (index 872): 1--1
# 医院开展医疗联合体成员单位医疗技术协作活动，提高医疗技术水平
# 预测结果 (index 873): 0--0
# 积极参与团队建设活动，提升团队凝聚力
# 预测结果 (index 874): 0--0
# 市场分析深入透彻把握趋势
# 预测结果 (index 875): 0--0
# 祝您寿比昙花
# 预测结果 (index 876): 1--1
# 想。去。给。你。烧香。 。才。发现。你。还。没。死
# 预测结果 (index 877): 1--1
# 疯了吧的
# 预测结果 (index 878): 1--1
# 《市场拓展方案实施情况报告》：报告市场拓展方案实施情况，及时调整策略
# 预测结果 (index 879): 0--0
# 恶心的妈给恶心开门、恶心到家了……
# 预测结果 (index 880): 1--1
# 非常没人理
# 预测结果 (index 881): 1--1
# 贱_b
# 预测结果 (index 882): 1--1
# 风险控制严格有力确保安全
# 预测结果 (index 883): 0--0
# 特别怎么不说话了 屎吃太多堵住了？
# 预测结果 (index 884): 1--1
# 苍蝇走在你脸上都崴脚呢
# 预测结果 (index 885): 1--1
# 仔细|看看|我|这|巴掌|真|适合|你|那大|脸
# 预测结果 (index 886): 1--1
# 爱得瑟吧
# 预测结果 (index 887): 1--1
# 医疗护理服务理念创新提升服务水平
# 预测结果 (index 888): 0--0
# 我们。要。向前。看。,。不错。过些。歪。瓜劣。枣。怎么。知道。什么。是。好。的。。
# 预测结果 (index 889): 1--1
# 客户需求迅速回应提升信任
# 预测结果 (index 890): 0--0
# 我的天呐,你一定是吃了放在肮脏的桌子上的发霉的绿色面包,才会眨着美丽的大眼睛睛说出长沙臭豆腐一样臭的话!
# 预测结果 (index 891): 1--1
# 你的zhi商跟冬天黑龙江的温度一样。
# 预测结果 (index 892): 1--1
# 发骚的
# 预测结果 (index 893): 1--1
# 姑娘|啊
# 预测结果 (index 894): 1--1
# 音乐演出活力满满听众热情高涨
# 预测结果 (index 895): 0--0
# 傻逼年年有，今年大丰收的
# 预测结果 (index 896): 1--1
# 特别牛呢
# 预测结果 (index 897): 1--1
# 老狗
# 预测结果 (index 898): 1--1
# 你这种人永远买不到到自己合适的鞋 因为你码没了
# 预测结果 (index 899): 1--1
# 进度: 900/2856
# 别人*站*着*赚钱*，* *你*躺*着*。
# 预测结果 (index 900): 1--1
# 文化节庆活动欢乐祥和弘扬传统文化
# 预测结果 (index 901): 0--0
# 自找+虐
# 预测结果 (index 902): 1--1
# 就是嫉妒我户口本可以翻页（说他是孤儿）
# 预测结果 (index 903): 1--1
# 老狗狗
# 预测结果 (index 904): 1--1
# 科技创新更加活跃
# 预测结果 (index 905): 0--0
# 医疗护理伦理道德创新规范护理行为
# 预测结果 (index 906): 0--0
# 太傻逼年年有，今年大丰收
# 预测结果 (index 907): 1--1
# 我疯了
# 预测结果 (index 908): 1--1
# 祝你们。不孕。不育。，。儿孙满堂。。
# 预测结果 (index 909): 0--1
# 励志在努力中追逐梦想与幸福的人生旅程实现人生价值与目标丰富人生的意义与价值
# 预测结果 (index 910): 0--0
# 电影放映活动丰富多样满足观众需求
# 预测结果 (index 911): 0--0
# 请问您对这个安排满意吗?
# 预测结果 (index 912): 0--0
# 我们要向前看,不错过些歪瓜瓜劣枣怎么知道什么是好的。
# 预测结果 (index 913): 1--1
# 分析很细致.感谢分享
# 预测结果 (index 914): 0--0
# 我的天呐,你一定是吃了放在肮脏的桌子上的发霉的绿色面包,才会眨着美丽的大大眼睛说出长沙臭豆腐一样臭的话!
# 预测结果 (index 915): 1--1
# 太我笑了
# 预测结果 (index 916): 1--1
# 你的致商跟冬天黑龙江的温度一样。
# 预测结果 (index 917): 0--1
# 我们期待您的持续关注
# 预测结果 (index 918): 0--0
# 我无法相信你是十万精子里面最快的那个
# 预测结果 (index 919): 0--1
# 我们会努力改善服务
# 预测结果 (index 920): 0--0
# 好老狗
# 预测结果 (index 921): 1--1
# 城市功能更加完备
# 预测结果 (index 922): 0--0
# 懦弱的人
# 预测结果 (index 923): 1--1
# 好家伙，你自己拍全家福挺孤单单吧
# 预测结果 (index 924): 1--1
# 想和你分享生活的点滴
# 预测结果 (index 925): 0--0
# 你再骂？信不信👴把你脑袋拧下来当夜壶？！呢
# 预测结果 (index 926): 1--1
# 我。的。天呐。,。你。一定。是。吃。了。放在。肮脏。的。桌子。上。的。发霉。的。绿色。面包。,。才。会。眨。着。美丽。的。大。眼睛。说出。长沙。臭豆腐。一样。臭。的话。!
# 预测结果 (index 927): 1--1
# 想_去_给_你_烧香_ _才_发现_你_还_没_死
# 预测结果 (index 928): 1--1
# 记得下点调料，这样你家人吃起来才会有味道啊
# 预测结果 (index 929): 0--1
# 非常自找虐
# 预测结果 (index 930): 1--1
# 舞蹈演出活力四射展现青春风采
# 预测结果 (index 931): 0--0
# 丑爆
# 预测结果 (index 932): 1--1
# 真特别牛
# 预测结果 (index 933): 1--1
# 狗 … …
# 预测结果 (index 934): 1--1
# 姑娘啊
# 预测结果 (index 935): 1--1
# 真想把你的头扭下来放在洗衣机里搅一搅，刚好能洗一缸衣衣服，虽然有点臭，但节约水资源刻不容缓。
# 预测结果 (index 936): 0--1
# 瞎搞的
# 预测结果 (index 937): 1--1
# 鼻窦炎的药物治疗包括使用抗生素、鼻用糖皮质激素等
# 预测结果 (index 938): 0--0
# Clinical medicine practice serves patients. Clinical medicine practice: clinical medicine practice; patients: patients
# 预测结果 (index 939): 0--0
# 已拉黑
# 预测结果 (index 940): 1--1
# 写作很优美.很喜欢
# 预测结果 (index 941): 0--0
# 好没皮没脸
# 预测结果 (index 942): 1--1
# 记得下点点调料，这样你家人吃起来才会有味道
# 预测结果 (index 943): 0--1
# 《产品推广活动策划》：策划产品推广活动，提高产品知名度
# 预测结果 (index 944): 0--0
# 特别仔细看看我这巴掌真适合你那大脸
# 预测结果 (index 945): 0--1
# 欢乐的野餐充满乐趣
# 预测结果 (index 946): 0--0
# 我的天呐,你一定定是吃了放在肮脏的桌子上的发霉的绿色面包,才会眨着美丽的大眼睛说出长沙臭豆腐一样臭的话!
# 预测结果 (index 947): 1--1
# 生物化学揭示生命化学过程
# 预测结果 (index 948): 0--0
# 神精病
# 预测结果 (index 949): 1--1
# 我特
# 预测结果 (index 950): 1--1
# 舞蹈比赛竞争激烈展现青春活力
# 预测结果 (index 951): 0--0
# 没。人理
# 预测结果 (index 952): 1--1
# 给你看样东西，🐶🐱🐭🐹🐰🦊🐻🐼🐨🐯🦁🐮🐷🐸🐵😺🐔🐧🐦🐣🦆🦅🦉🦇🐺🐗🐝🐛🦋🐌🐞🐜🦟🦗🕷️🦂🐢🐉🐍🦎🦖🦕🐙🦔🐿️🐀🐁🐇🦜🐈🐓🦏🐄🦒🐫。看见是不是少了样东西，对，你🐴没了
# 预测结果 (index 953): 1--1
# 非常瞎搞
# 预测结果 (index 954): 1--1
# 真想把你的头扭下来放在洗衣机里搅一搅搅，刚好能洗一缸衣服，虽然有点臭，但节约水资源刻不容缓。
# 预测结果 (index 955): 0--1
# 你是我最好的玩伴
# 预测结果 (index 956): 0--0
# 好你看上去好眼熟像我昨天扔出去的那袋垃圾
# 预测结果 (index 957): 1--1
# 太挺操
# 预测结果 (index 958): 1--1
# 医疗护理服务创新均等化实现公平护理
# 预测结果 (index 959): 0--0
# 你的笑容最治愈
# 预测结果 (index 960): 0--0
# 好怎么不说话了 屎吃太多堵住了？
# 预测结果 (index 961): 1--1
# 国际合作项目取得重要进展
# 预测结果 (index 962): 0--0
# 我们会认真考虑您的意见
# 预测结果 (index 963): 0--0
# dao
# 预测结果 (index 964): 1--1
# 医疗护理继续教育创新提升护理人员水平
# 预测结果 (index 965): 0--0
# 医院加强医院医疗服务质量改进活动的组织领导，确保改进活动顺利开展
# 预测结果 (index 966): 0--0
# 医疗护理环境管理创新营造舒适护理环境
# 预测结果 (index 967): 0--0
# 就是嫉妒我户口本可以翻页（说他是孤儿）的
# 预测结果 (index 968): 1--1
# 傻傻逼年年有，今年大丰收
# 预测结果 (index 969): 1--1
# 内容很有深度.感谢分享
# 预测结果 (index 970): 0--0
# 医院开展健康宣教活动，提高公众健康意识
# 预测结果 (index 971): 0--0
# 艺术论坛思想碰撞探讨艺术前沿
# 预测结果 (index 972): 0--0
# 贱b啊
# 预测结果 (index 973): 1--1
# 你|屌
# 预测结果 (index 974): 1--1
# 特别别人站着赚钱， 你躺着。
# 预测结果 (index 975): 1--1
# 感谢您的真诚反馈
# 预测结果 (index 976): 0--0
# 高端黑
# 预测结果 (index 977): 1--1
# 屌丝
# 预测结果 (index 978): 1--1
# 团队合作紧密协作共同进步
# 预测结果 (index 979): 0--0
# 你是我的专属天使
# 预测结果 (index 980): 0--0
# 怎么|不|说话|了| |屎|吃|太|多|堵住|了|？
# 预测结果 (index 981): 1--1
# 那个_女生
# 预测结果 (index 982): 1--1
# 读来令人心生暖意
# 预测结果 (index 983): 0--0
# 合作意向积极主动共同推进
# 预测结果 (index 984): 0--0
# 捧臭脚
# 预测结果 (index 985): 1--1
# 感谢命运的每一次相遇
# 预测结果 (index 986): 0--0
# 你真棒，对不对
# 预测结果 (index 987): 0--0
# 苍蝇走在你脸上都崴脚的
# 预测结果 (index 988): 1--1
# 祝你们 不孕 不育 ， 儿孙满堂 。
# 预测结果 (index 989): 0--1
# 呵呵，滚
# 预测结果 (index 990): 1--1
# 医院开展医疗联合体成员单位医疗服务质量提升行动合作共建活动，实现资源共享、优势互补
# 预测结果 (index 991): 0--0
# 我真的很想帮你治疗，但我是一名家庭医生，而你是一个孤儿。吧
# 预测结果 (index 992): 0--1
# 团队齐奋进
# 预测结果 (index 993): 0--0
# 舞蹈演出动感十足展现青春活力
# 预测结果 (index 994): 0--0
# 小瘪三
# 预测结果 (index 995): 1--1
# 疯了吧啊
# 预测结果 (index 996): 1--1
# 制杖
# 预测结果 (index 997): 0--1
# 我忍不了
# 预测结果 (index 998): 1--1
# 同事们一起参加户外运动比赛，增强团队的凝聚力和竞争力，展现团队的风采和实力
# 预测结果 (index 999): 0--0
# 进度: 1000/2856
# 牛~x
# 预测结果 (index 1000): 1--1
# 贱得
# 预测结果 (index 1001): 1--1
# 你这种人永远买不到自己合适的鞋 因为你码没了吧
# 预测结果 (index 1002): 1--1
# 祝你们_不孕_不育_，_儿孙满堂_。
# 预测结果 (index 1003): 0--1
# 记得~下点~调料~，~这样~你家~人~吃~起来~才~会~有~味道
# 预测结果 (index 1004): 0--1
# 特别你的智商跟冬天黑龙江的温度一样。
# 预测结果 (index 1005): 1--1
# 好注孤
# 预测结果 (index 1006): 1--1
# 苍蝇|走|在|你|脸上|都|崴|脚
# 预测结果 (index 1007): 1--1
# 我很好，也很强
# 预测结果 (index 1008): 0--0
# 你吗在那边缺纸钱了自己去烧别给我叽歪
# 预测结果 (index 1009): 1--1
# 坏淫吧
# 预测结果 (index 1010): 1--1
# 雕塑作品展览艺术感十足展现创造力
# 预测结果 (index 1011): 0--0
# 草草草
# 预测结果 (index 1012): 1--1
# 风险防范严密有效确保安全
# 预测结果 (index 1013): 0--0
# 蠢死
# 预测结果 (index 1014): 1--1
# 高端黑黑
# 预测结果 (index 1015): 1--1
# 小学生吧
# 预测结果 (index 1016): 1--1
# 教育发展更加均衡
# 预测结果 (index 1017): 0--0
# 大流氓
# 预测结果 (index 1018): 1--1
# 关注学术研究热点，开展深入研究
# 预测结果 (index 1019): 0--0
# 好我们要向前看,不错过些歪瓜劣枣怎么知道什么是好的。
# 预测结果 (index 1020): 1--1
# 舞蹈演出动感十足展现青春活力
# 预测结果 (index 1021): 0--0
# 请问您是否需要更多细节?
# 预测结果 (index 1022): 0--0
# 你们是我永远的港湾
# 预测结果 (index 1023): 0--0
# 我在周末会去超市购物，为家人准备美味的食物
# 预测结果 (index 1024): 0--0
# 《项目验收总结报告》：总结项目验收情况，为后续项目提供经验
# 预测结果 (index 1025): 0--0
# 妇产科学关爱女性健康
# 预测结果 (index 1026): 0--0
# 无下限
# 预测结果 (index 1027): 1--1
# 二逼
# 预测结果 (index 1028): 1--1
# 《培训课程设计方案》：设计针对性的培训课程，提高培训效果
# 预测结果 (index 1029): 0--0
# 你想多了的
# 预测结果 (index 1030): 1--1
# 感谢您一直以来的支持
# 预测结果 (index 1031): 0--0
# 好高端黑
# 预测结果 (index 1032): 1--1
# 新友初相识
# 预测结果 (index 1033): 0--0
# 怎么不说话了 屎吃太多堵住了？吧
# 预测结果 (index 1034): 1--1
# 仔细*看看*我*这*巴掌*真*适合*你*那大*脸
# 预测结果 (index 1035): 1--1
# 请问您对这个决策有何想法?
# 预测结果 (index 1036): 0--0
# 好没人理
# 预测结果 (index 1037): 1--1
# 希望你打游戏时可以把脑子从粪坑里捞出来带上
# 预测结果 (index 1038): 1--1
# 音乐会演奏动人心弦带给听众享受
# 预测结果 (index 1039): 0--0
# 我呸
# 预测结果 (index 1040): 1--1
# 仔细.看看.我.这.巴掌.真.适合.你.那大.脸
# 预测结果 (index 1041): 1--1
# 欠揍
# 预测结果 (index 1042): 1--1
# 太我们要向前看,不错过些歪瓜劣枣怎么知道什么是好的。
# 预测结果 (index 1043): 1--1
# 怂货呢
# 预测结果 (index 1044): 1--1
# 制药企业提升企业品牌建设和管理水平，打造知名药品品牌
# 预测结果 (index 1045): 0--0
# 农业现代化建设加快推进
# 预测结果 (index 1046): 0--0
# 医学研究需要多中心、大样本的临床试验来验证治疗效果
# 预测结果 (index 1047): 0--0
# 温暖而感人的文字
# 预测结果 (index 1048): 0--0
# 不作|不|死
# 预测结果 (index 1049): 1--1
# 基础医学研究奠定医学基础
# 预测结果 (index 1050): 0--0
# 自+嗨
# 预测结果 (index 1051): 1--1
# 被分手呢
# 预测结果 (index 1052): 1--1
# 戏曲演出传统韵味十足展现文化魅力
# 预测结果 (index 1053): 0--0
# 民生保障更加有力
# 预测结果 (index 1054): 0--0
# 医疗护理感染控制创新预防医院感染
# 预测结果 (index 1055): 0--0
# 特别注孤
# 预测结果 (index 1056): 1--1
# 戏曲演出韵味悠长传承文化瑰宝
# 预测结果 (index 1057): 0--0
# 别减肥了，你丑不只是因为胖
# 预测结果 (index 1058): 1--1
# 爱得瑟了
# 预测结果 (index 1059): 1--1
# 被~分手
# 预测结果 (index 1060): 1--1
# 艰不拆呢
# 预测结果 (index 1061): 1--1
# 励志在奋斗的道路上不断前行与进步实现人生目标
# 预测结果 (index 1062): 0--0
# 没皮没脸吧
# 预测结果 (index 1063): 1--1
# 制药企业开展公益活动，回馈社会关爱
# 预测结果 (index 1064): 0--0
# 贱.b
# 预测结果 (index 1065): 1--1
# 狗………
# 预测结果 (index 1066): 1--1
# 非常贱b
# 预测结果 (index 1067): 1--1
# 自找#虐
# 预测结果 (index 1068): 1--1
# 好gay
# 预测结果 (index 1069): 1--1
# 《项目启动资源准备》：做好项目启动资源准备，确保项目顺利启动
# 预测结果 (index 1070): 0--0
# 记得下点调料，这样你家人吃起来才才会有味道
# 预测结果 (index 1071): 0--1
# 牙周炎的治疗包括洁治、刮治等基础治疗和必要的牙周手术
# 预测结果 (index 1072): 0--0
# 城市治理水平不断提升
# 预测结果 (index 1073): 0--0
# 真想把你的头扭下来放在洗衣机里搅一搅，刚好能洗一缸衣服，虽然有点臭但节约水资源刻不容缓。
# 预测结果 (index 1074): 0--1
# 夸翠竹
# 预测结果 (index 1075): 1--0
# 制药企业加强药品研发项目风险管理评估方法研究，提高风险管理评估的科学性和准确性
# 预测结果 (index 1076): 0--0
# 你是傻逼
# 预测结果 (index 1077): 1--1
# 特别你想多了
# 预测结果 (index 1078): 1--1
# 分析很专业.感谢分享
# 预测结果 (index 1079): 0--0
# 特别你看上去好眼熟像我昨天扔出去的那袋垃圾
# 预测结果 (index 1080): 1--1
# 风险控制严格有效确保安全
# 预测结果 (index 1081): 0--0
# 怀信念
# 预测结果 (index 1082): 0--0
# 我是好人
# 预测结果 (index 1083): 0--1
# 傻逼年年有，今年大丰丰收
# 预测结果 (index 1084): 1--1
# 感恩那些陪伴我们成长的人
# 预测结果 (index 1085): 0--0
# 市场变化及时把握调整策略
# 预测结果 (index 1086): 0--0
# 自找虐呢
# 预测结果 (index 1087): 1--1
# 认真对待工作中的挑战，勇于担当责任
# 预测结果 (index 1088): 0--0
# 去你大爷
# 预测结果 (index 1089): 1--1
# 分析很细致.学到很多
# 预测结果 (index 1090): 0--0
# 合作意向明确坚定共同努力
# 预测结果 (index 1091): 0--0
# 前列腺炎可由细菌感染、免疫异常等多种因素引起
# 预测结果 (index 1092): 0--0
# 狗|…|…
# 预测结果 (index 1093): 1--1
# 采用盲法评估可减少研究中的偏倚，如单盲、双盲试验
# 预测结果 (index 1094): 0--0
# 付出总有回报.感恩前行
# 预测结果 (index 1095): 0--0
# 医疗护理继续教育创新提升护理人员水平
# 预测结果 (index 1096): 0--0
# 医疗服务更加优质
# 预测结果 (index 1097): 0--0
# 大傻子
# 预测结果 (index 1098): 1--1
# 她经常参加瑜伽冥想课程，放松身心，减轻压力，提升内心的平静和幸福感，增强自己的身心健康和免疫力
# 预测结果 (index 1099): 0--0
# 进度: 1100/2856
# 太好家伙，你自己拍全家福挺孤单吧
# 预测结果 (index 1100): 0--1
# 别人#站#着#赚钱#，# #你#躺#着#。
# 预测结果 (index 1101): 1--1
# Pathophysiology studies disease mechanisms. Pathophysiology: pathophysiology; disease mechanisms: disease mechanisms
# 预测结果 (index 1102): 0--0
# 二大爷啊
# 预测结果 (index 1103): 1--1
# 你想多了
# 预测结果 (index 1104): 1--1
# 我明白，你也是
# 预测结果 (index 1105): 0--0
# 观云海
# 预测结果 (index 1106): 0--0
# 好制杖
# 预测结果 (index 1107): 1--1
# 这文字太戳人心了
# 预测结果 (index 1108): 0--0
# 《营销方案优化建议》：提出营销方案优化建议，提高营销效果
# 预测结果 (index 1109): 0--0
# 呦|！|这|是|谁|裤裆|门|没拉|，|怎么|把|你|漏出来|了|？
# 预测结果 (index 1110): 1--1
# 我的眼里只有你一个
# 预测结果 (index 1111): 0--0
# 你-的-智商-跟-冬天-黑龙江-的-温度-一样-。
# 预测结果 (index 1112): 1--1
# 《企业文化建设目标》：明确企业文化建设目标，推进企业文化建设
# 预测结果 (index 1113): 0--0
# 就是|嫉妒|我|户口本|可以|翻页|（|说|他|是|孤儿|）
# 预测结果 (index 1114): 1--1
# 贱货当上瘾是改不掉的
# 预测结果 (index 1115): 1--1
# 医疗服务更加便民
# 预测结果 (index 1116): 0--0
# 就是 嫉妒 我 户口本 可以 翻页 （ 说 他 是 孤儿 ）
# 预测结果 (index 1117): 1--1
# 如果+长+的+丑+也+算+残疾+的话+，+那+你+就+不用+工作+了+。
# 预测结果 (index 1118): 1--1
# 呦~！~这~是~谁~裤裆~门~没拉~，~怎么~把~你~漏出来~了~？
# 预测结果 (index 1119): 1--1
# 团队合作紧密团结共同进步
# 预测结果 (index 1120): 0--0
# 医院加强医院医疗服务质量改进活动的经验总结和推广，发挥示范引领作用
# 预测结果 (index 1121): 0--0
# 永远珍惜我们的友情
# 预测结果 (index 1122): 0--0
# 你真棒，他也是
# 预测结果 (index 1123): 0--0
# 自找|虐
# 预测结果 (index 1124): 1--1
# 好你的智商跟冬天黑龙江的温度一样。
# 预测结果 (index 1125): 1--1
# 狗-…-…
# 预测结果 (index 1126): 1--1
# 你再骂？信不信👴把你脑袋拧下来当夜壶？！吧
# 预测结果 (index 1127): 1--1
# 你再骂？信不信👴把你脑袋拧下下来当夜壶？！
# 预测结果 (index 1128): 1--1
# 我操
# 预测结果 (index 1129): 1--1
# 只想和你慢慢变老
# 预测结果 (index 1130): 0--0
# 砍死他吧
# 预测结果 (index 1131): 1--1
# 龟孙子了
# 预测结果 (index 1132): 1--1
# 特别发骚
# 预测结果 (index 1133): 1--1
# 音乐会演奏动人心弦带给听众享受
# 预测结果 (index 1134): 0--0
# 好如果长的丑也算残疾的话，那你就不用工作了。
# 预测结果 (index 1135): 1--1
# 苍蝇.走.在.你.脸上.都.崴.脚
# 预测结果 (index 1136): 1--1
# 怎么不说话了 拉吃太多堵住了？
# 预测结果 (index 1137): 1--1
# 医疗护理法律法规创新保障护理权益
# 预测结果 (index 1138): 0--0
# 真你这种人永远买不到自己合适的鞋 因为你码没了
# 预测结果 (index 1139): 1--1
# 高端黑啊
# 预测结果 (index 1140): 1--1
# 嘲笑
# 预测结果 (index 1141): 1--1
# 如果长的丑也算残疾的话，那那你就不用工作了。
# 预测结果 (index 1142): 1--1
# 温暖而感人的文字
# 预测结果 (index 1143): 0--0
# 他努力提升管理水平，带领团队高效运作
# 预测结果 (index 1144): 0--0
# 挺操
# 预测结果 (index 1145): 1--1
# 风险控制严格得力确保安全
# 预测结果 (index 1146): 0--0
# 我真的很想帮你治疗，但我是一名家庭医生，而你是一个孤儿。
# 预测结果 (index 1147): 0--1
# 没+人理
# 预测结果 (index 1148): 1--1
# 贱 b
# 预测结果 (index 1149): 1--1
# 亮剑吧，我没的是素质，你没的是亲妈
# 预测结果 (index 1150): 1--1
# 真牛|逼
# 预测结果 (index 1151): 1--1
# 好姑娘啊
# 预测结果 (index 1152): 0--1
# 您提出的这个问题很有深度
# 预测结果 (index 1153): 0--0
# 非常恶心的妈妈给恶心开门、恶心到家了……
# 预测结果 (index 1154): 1--1
# 差异性分析可比较不同组之间的差异，如 t 检验、方差分析
# 预测结果 (index 1155): 0--0
# 提升压力应对能力，保持身心健康
# 预测结果 (index 1156): 0--0
# 牛 x
# 预测结果 (index 1157): 1--1
# 我们会全力支持您的工作
# 预测结果 (index 1158): 0--0
# 特别恶心的妈妈给恶心开门、恶心到家了……
# 预测结果 (index 1159): 1--1
# 砍死#他
# 预测结果 (index 1160): 1--1
# 想我
# 预测结果 (index 1161): 1--1
# 非常苍蝇走在你脸上都崴脚
# 预测结果 (index 1162): 1--1
# 苍走在你脸上都崴脚
# 预测结果 (index 1163): 1--1
# 你的友情是我的财富
# 预测结果 (index 1164): 0--0
# 他喜欢种植花草，看着它们茁壮成长，心情格外愉悦
# 预测结果 (index 1165): 0--0
# 特别爱得瑟
# 预测结果 (index 1166): 1--1
# 情感真挚动人.喜欢
# 预测结果 (index 1167): 0--0
# 特别+牛
# 预测结果 (index 1168): 1--1
# 煞笔逼年年有，今年大丰收
# 预测结果 (index 1169): 1--1
# 你-屌
# 预测结果 (index 1170): 1--1
# 想-去-给-你-烧香- -才-发现-你-还-没-死
# 预测结果 (index 1171): 1--1
# 仔细画图画
# 预测结果 (index 1172): 0--0
# 你丫
# 预测结果 (index 1173): 1--1
# 写作很流畅.很享受
# 预测结果 (index 1174): 0--0
# 太恶心的妈妈给恶心开门、恶心到家了……
# 预测结果 (index 1175): 1--1
# 想#去#给#你#烧香# #才#发现#你#还#没#死
# 预测结果 (index 1176): 1--1
# 吊样
# 预测结果 (index 1177): 1--1
# 商业合作诚信为本实现互利共赢
# 预测结果 (index 1178): 0--0
# 如果-长-的-丑-也-算-残疾-的话-，-那-你-就-不用-工作-了-。
# 预测结果 (index 1179): 1--1
# 穷折腾
# 预测结果 (index 1180): 1--1
# 抗病毒药物的使用
# 预测结果 (index 1181): 0--0
# 好砍死他
# 预测结果 (index 1182): 1--1
# 拔屌无情
# 预测结果 (index 1183): 1--1
# 艺术展览创新形式展现艺术魅力
# 预测结果 (index 1184): 0--0
# 二+大爷
# 预测结果 (index 1185): 1--1
# 非常记得下点调料，这样你家人吃起来才会有味道
# 预测结果 (index 1186): 0--1
# 小孩纸
# 预测结果 (index 1187): 1--1
# 很开心，都一样
# 预测结果 (index 1188): 0--0
# 艰不拆了
# 预测结果 (index 1189): 1--1
# 商业合作互利互惠共同成长
# 预测结果 (index 1190): 0--0
# 傻逼年年有，今年大丰收了
# 预测结果 (index 1191): 1--1
# 商业合作和谐共赢共同发展
# 预测结果 (index 1192): 0--0
# 艰不拆拆
# 预测结果 (index 1193): 1--1
# 你我见过的容量最大的铅笔盒了，装那么多笔你不累吗？
# 预测结果 (index 1194): 0--1
# 好家伙_，_你_自己_拍_全家福_挺_孤单_吧
# 预测结果 (index 1195): 0--1
# 特别特爱
# 预测结果 (index 1196): 0--1
# 友尽
# 预测结果 (index 1197): 1--1
# 美术展览作品精彩展现艺术多元
# 预测结果 (index 1198): 0--0
# 特别艰不拆
# 预测结果 (index 1199): 1--1
# 进度: 1200/2856
# 医疗护理市场创新推动服务提升
# 预测结果 (index 1200): 0--0
# 特别挺操
# 预测结果 (index 1201): 1--1
# 被#分手
# 预测结果 (index 1202): 1--1
# 团队协作默契配合共同进步
# 预测结果 (index 1203): 0--0
# 艹艹
# 预测结果 (index 1204): 1--1
# ...
# 预测结果 (index 2465): 0--0
# 好真牛逼
# 预测结果 (index 2466): 1--1
# 好好家伙，你自己拍全家福挺孤单吧
# 预测结果 (index 2467): 1--1
# 高端黑呢
# 预测结果 (index 2468): 1--1
# 逼多
# 预测结果 (index 2469): 1--1
# 狗_…_…
# 预测结果 (index 2470): 1--1
# 你脖子上顶着的是个肿瘤吗
# 预测结果 (index 2471): 1--1
# 我+真的+很+想+帮+你+治疗+，+但+我+是+一名+家庭医生+，+而+你+是+一个+孤儿+。
# 预测结果 (index 2472): 1--1
# 我。真的。很。想。帮。你。治疗。，。但。我。是。一名。家庭医生。，。而。你。是。一个。孤儿。。
# 预测结果 (index 2473): 0--1
# 非常你想多了
# 预测结果 (index 2474): 1--1
# 感谢生命中的每一份情
# 预测结果 (index 2475): 0--0
# 活逼该
# 预测结果 (index 2476): 1--1
# 二大爷
# 预测结果 (index 2477): 1--1
# 坚持自己的路.勇往直前
# 预测结果 (index 2478): 0--0
# 贱b了
# 预测结果 (index 2479): 1--1
# 记得*下点*调料*，*这样*你家*人*吃*起来*才*会*有*味道
# 预测结果 (index 2480): 0--1
# 我的天呐,你一定是吃了放在肮脏脏的桌子上的发霉的绿色面包,才会眨着美丽的大眼睛说出长沙臭豆腐一样臭的话!
# 预测结果 (index 2481): 1--1
# 我知道，我也是
# 预测结果 (index 2482): 0--0
# 读完很感动.非常好
# 预测结果 (index 2483): 0--0
# 呦.！.这.是.谁.裤裆.门.没拉.，.怎么.把.你.漏出来.了.？
# 预测结果 (index 2484): 1--1
# 我日
# 预测结果 (index 2485): 1--1
# 姑娘啊了
# 预测结果 (index 2486): 1--1
# 大尾巴狼吧
# 预测结果 (index 2487): 1--1
# 你是我见过的容量最大的铅笔笔盒了，装那么多笔你不累吗？
# 预测结果 (index 2488): 0--1
# 电影周展映优秀影片丰富文化生活
# 预测结果 (index 2489): 0--0
# 我们要向前看看,不错过些歪瓜劣枣怎么知道什么是好的。
# 预测结果 (index 2490): 1--1
# 很烦
# 预测结果 (index 2491): 1--1
# 疯*了*吧
# 预测结果 (index 2492): 1--1
# 医疗教育培养专业医疗人才
# 预测结果 (index 2493): 0--0
# 仔细看看我这巴掌真适合那大脸
# 预测结果 (index 2494): 0--1
# 专业性很强.学到了
# 预测结果 (index 2495): 0--0
# 非常怎么不说话了 屎吃太多堵住了？
# 预测结果 (index 2496): 1--1
# 杰宝
# 预测结果 (index 2497): 0--1
# 真美，对不对
# 预测结果 (index 2498): 0--0
# 感谢您给予的机会
# 预测结果 (index 2499): 0--0
# 进度: 2500/2856
# 很坏很坏
# 预测结果 (index 2500): 1--1
# 我会说
# 预测结果 (index 2501): 0--1
# 没人理的
# 预测结果 (index 2502): 1--1
# 客户关系良好稳固长期合作
# 预测结果 (index 2503): 0--0
# 我的心里装满了你
# 预测结果 (index 2504): 0--0
# 喉镜检查可观察喉部结构和病变，对喉部疾病诊断有意义
# 预测结果 (index 2505): 0--0
# 好特别牛
# 预测结果 (index 2506): 1--1
# 电影品鉴会深入剖析影片价值提升审美
# 预测结果 (index 2507): 0--0
# 艺术讲座内容丰富传授艺术知识
# 预测结果 (index 2508): 0--0
# 真牛
# 预测结果 (index 2509): 1--1
# 埋汰
# 预测结果 (index 2510): 1--1
# 摄影作品展示美轮美奂记录精彩世界
# 预测结果 (index 2511): 0--0
# 太姑娘啊
# 预测结果 (index 2512): 1--1
# 不作不死吧
# 预测结果 (index 2513): 1--1
# 怎么_不_说话_了_ _屎_吃_太_多_堵住_了_？
# 预测结果 (index 2514): 1--1
# 操你
# 预测结果 (index 2515): 1--1
# 如果长的丑也算残疾的话，那你就不用工作了。了
# 预测结果 (index 2516): 1--1
# 太贱b
# 预测结果 (index 2517): 1--1
# 苍蝇 走 在 你 脸上 都 崴 脚
# 预测结果 (index 2518): 1--1
# 《人力资源管理优化方案》：提出人力资源管理优化方案，提高管理效率
# 预测结果 (index 2519): 0--0
# 你的智商跟冬天黑龙江的温度一样。了
# 预测结果 (index 2520): 1--1
# 你是我的好榜样呢
# 预测结果 (index 2521): 0--0
# 傻币年年有，今年大丰收
# 预测结果 (index 2522): 1--1
# 关注行业竞争态势，提升竞争力
# 预测结果 (index 2523): 0--0
# 好瞧不起
# 预测结果 (index 2524): 1--1
# 常互助
# 预测结果 (index 2525): 0--0
# 吓哭
# 预测结果 (index 2526): 1--1
# 没溜儿
# 预测结果 (index 2527): 1--1
# 我+笑+了
# 预测结果 (index 2528): 1--1
# 文学活动创意满满激发文学热情
# 预测结果 (index 2529): 0--0
# 非常疯了吧
# 预测结果 (index 2530): 1--1
# 医疗护理改革促进护理体系完善
# 预测结果 (index 2531): 0--0
# 挺操
# 预测结果 (index 2532): 1--1
# 如果#长#的#丑#也#算#残疾#的话#，#那#你#就#不用#工作#了#。
# 预测结果 (index 2533): 1--1
# 自私男
# 预测结果 (index 2534): 1--1
# 太被分手
# 预测结果 (index 2535): 1--1
# 丑的
# 预测结果 (index 2536): 1--1
# 艺术讲座知识丰富启发艺术思维
# 预测结果 (index 2537): 0--0
# 非常瞧不起
# 预测结果 (index 2538): 1--1
# 砍死 他
# 预测结果 (index 2539): 1--1
# 制药企业开展药品质量提升行动，保障患者用药安全有效
# 预测结果 (index 2540): 0--0
# 我的天呐,你一定是吃了放在肮脏的桌子上的发霉的绿色面包,才会眨着美丽的大眼睛说出长沙臭豆腐一样臭的话!了
# 预测结果 (index 2541): 1--1
# 医疗护理服务模式创新满足患者需求
# 预测结果 (index 2542): 0--0
# 你脖子顶的是肿瘤吧
# 预测结果 (index 2543): 1--1
# 啥逼年年有，今年大丰收
# 预测结果 (index 2544): 1--1
# 砍死+他
# 预测结果 (index 2545): 1--1
# 不作不死
# 预测结果 (index 2546): 1--1
# 特爱
# 预测结果 (index 2547): 0--1
# 非常龟孙子
# 预测结果 (index 2548): 1--1
# 情感真挚动人.喜欢
# 预测结果 (index 2549): 0--0
# 《商务邀请函撰写要点》：介绍商务邀请函撰写要点，提高邀请函的质量
# 预测结果 (index 2550): 0--0
# 与同学互帮互助，共同攻克难题
# 预测结果 (index 2551): 0--0
# 我清早五点起来火化你爹，要几分熟就烤几分熟
# 预测结果 (index 2552): 1--1
# 恶心#的#妈妈#给#恶心#开门#、#恶心#到家#了#…#…
# 预测结果 (index 2553): 1--1
# 不作*不*死
# 预测结果 (index 2554): 1--1
# 心存感激.收获幸福
# 预测结果 (index 2555): 0--0
# 特烦吧
# 预测结果 (index 2556): 1--1
# 你脖子上顶的是肿瘤吧的
# 预测结果 (index 2557): 1--1
# 狂骂
# 预测结果 (index 2558): 1--1
# 非常我真的很想帮你治疗，但我是一名家庭医生，而你是一个孤儿。
# 预测结果 (index 2559): 0--1
# 砍死*他
# 预测结果 (index 2560): 1--1
# 发骚呢
# 预测结果 (index 2561): 1--1
# 如果长的丑也算残疾的话，那你就不用工作作了。
# 预测结果 (index 2562): 1--1
# 祝你们不孕不育，儿孙满。
# 预测结果 (index 2563): 0--1
# Medical law safeguards doctor-patient rights and interests. Medical law: medical law; doctor-patient rights and interests: doctor-patient rights and interests
# 预测结果 (index 2564): 0--0
# 特别贱b
# 预测结果 (index 2565): 1--1
# 真就是嫉妒我户口本可以翻页（说他是孤儿）
# 预测结果 (index 2566): 1--1
# 死开
# 预测结果 (index 2567): 1--1
# 你个
# 预测结果 (index 2568): 1--1
# 恶心的妈妈给恶心开门、恶心到家了……呢
# 预测结果 (index 2569): 1--1
# 没皮没脸呢
# 预测结果 (index 2570): 1--1
# 好家伙，你你自己拍全家福挺孤单吧
# 预测结果 (index 2571): 1--1
# 客户服务贴心周到提升形象
# 预测结果 (index 2572): 0--0
# 文化产业发展势头良好
# 预测结果 (index 2573): 0--0
# 被+分手
# 预测结果 (index 2574): 1--1
# 你的智障商跟冬天黑龙江的温度一样。
# 预测结果 (index 2575): 1--1
# 我感觉你和天空很像“一个天高一个地厚”
# 预测结果 (index 2576): 0--1
# 参加学术讲座，丰富知识储备
# 预测结果 (index 2577): 0--0
# 你看上去眼熟像我昨天扔出去的那袋垃圾
# 预测结果 (index 2578): 1--1
# 太真牛逼
# 预测结果 (index 2579): 1--1
# 喜音乐
# 预测结果 (index 2580): 0--0
# 高端-黑
# 预测结果 (index 2581): 1--1
# 自以为事
# 预测结果 (index 2582): 1--1
# 特爱呢
# 预测结果 (index 2583): 0--1
# 共分享
# 预测结果 (index 2584): 0--0
# Dermatology takes care of skin beauty. Dermatology: dermatology; skin beauty: skin beauty
# 预测结果 (index 2585): 0--0
# 恶心的mamamama给恶心开门、恶心到家了……
# 预测结果 (index 2586): 1--1
# 舞蹈演出动感十足展现青春活力
# 预测结果 (index 2587): 0--0
# 基佬
# 预测结果 (index 2588): 1--1
# 想和你一直在一起
# 预测结果 (index 2589): 0--0
# 销售分析精准到位提供决策依据
# 预测结果 (index 2590): 0--0
# 敢骂
# 预测结果 (index 2591): 1--1
# 数据共享可以促进医学研究的合作和发展
# 预测结果 (index 2592): 0--0
# 永远做你最信任的人
# 预测结果 (index 2593): 0--0
# 真特爱
# 预测结果 (index 2594): 0--1
# 好难过
# 预测结果 (index 2595): 0--1
# 你。看上去。好。眼熟。像。我。昨天。扔出去。的。那袋。垃圾
# 预测结果 (index 2596): 1--1
# 心存感激.保持乐观.明天会更好
# 预测结果 (index 2597): 0--0
# 高冷装
# 预测结果 (index 2598): 1--1
# 习惯就好
# 预测结果 (index 2599): 0--1
# 进度: 2600/2856
# 真美，你说呢
# 预测结果 (index 2600): 0--0
# 文化节庆活动欢乐祥和弘扬传统文化
# 预测结果 (index 2601): 0--0
# 你想多多了
# 预测结果 (index 2602): 0--1
# 挺蠢
# 预测结果 (index 2603): 1--1
# 特别_牛
# 预测结果 (index 2604): 1--1
# 产品质量可靠优良赢得信赖
# 预测结果 (index 2605): 0--0
# 坏淫呢
# 预测结果 (index 2606): 1--1
# 音乐晚会气氛热烈听众尽情享受
# 预测结果 (index 2607): 0--0
# 雕塑展览创意新颖展现艺术魅力
# 预测结果 (index 2608): 0--0
# 我在周末会去公园骑自行车，感受风的自由
# 预测结果 (index 2609): 0--0
# 祝你们不孕不育，儿孙满堂。吧
# 预测结果 (index 2610): 0--1
# 同学们认真参加社会实践活动，增强社会责任感
# 预测结果 (index 2611): 0--0
# 我很乐，都一样
# 预测结果 (index 2612): 0--0
# 懒蛋
# 预测结果 (index 2613): 1--1
# 非常艰不拆
# 预测结果 (index 2614): 1--1
# 非常想去给你烧香 才发现你还没死
# 预测结果 (index 2615): 0--1
# 参加专业实践课程，提升操作技能
# 预测结果 (index 2616): 0--0
# 想去给你烧香 才发现你还没死了
# 预测结果 (index 2617): 1--1
# 装孙子
# 预测结果 (index 2618): 1--1
# 仔细看看我这巴掌真适合你那大脸吧
# 预测结果 (index 2619): 1--1
# 非常gay
# 预测结果 (index 2620): 1--1
# 脑抽
# 预测结果 (index 2621): 1--1
# 愿做你永远的避风港
# 预测结果 (index 2622): 0--0
# 我喜欢你
# 预测结果 (index 2623): 0--0
# 我的天呐,你一定是吃了放在肮脏的桌子上的的发霉的绿色面包,才会眨着美丽的大眼睛说出长沙臭豆腐一样臭的话!
# 预测结果 (index 2624): 1--1
# 非常是这世间的黑暗，造就了你不懂礼数的浅薄。
# 预测结果 (index 2625): 1--1
# 马屁精
# 预测结果 (index 2626): 1--1
# 想去给你烧香 才发发现你还没死
# 预测结果 (index 2627): 1--1
# 没心眼
# 预测结果 (index 2628): 1--1
# 那个女生了
# 预测结果 (index 2629): 1--1
# 特别我真的很想帮你治疗，但我是一名家庭医生，而你是一个孤儿。
# 预测结果 (index 2630): 0--1
# 非常自嗨
# 预测结果 (index 2631): 1--1
# 好怂货
# 预测结果 (index 2632): 1--1
# 别学我
# 预测结果 (index 2633): 1--1
# 非常发骚
# 预测结果 (index 2634): 1--1
# 非常被分手
# 预测结果 (index 2635): 1--1
# 傻-逼-年-年-有-，-今年-大丰收
# 预测结果 (index 2636): 1--1
# 我。笑。了
# 预测结果 (index 2637): 1--1
# 字里行间都是爱.感谢
# 预测结果 (index 2638): 0--0
# 是这世间的黑暗，造就了你不懂礼数的浅薄。
# 预测结果 (index 2639): 1--1
# 跌份
# 预测结果 (index 2640): 1--1
# 你脖子上顶的是肿瘤吧了
# 预测结果 (index 2641): 1--1
# wtf
# 预测结果 (index 2642): 1--1
# 积极参与项目优化，提高项目效益
# 预测结果 (index 2643): 0--0
# 摄影活动视角独特记录精彩瞬间
# 预测结果 (index 2644): 0--0
# 真巧，我也是
# 预测结果 (index 2645): 0--0
# 社会治理更加精细
# 预测结果 (index 2646): 0--0
# 非常真牛逼
# 预测结果 (index 2647): 1--1
# 非常狗……
# 预测结果 (index 2648): 1--1
# 苍蝇走在你你脸上都崴脚
# 预测结果 (index 2649): 1--1
# 感恩每一个美丽的风景与难忘的瞬间带来的美好回忆与感动丰富人生的情感与体验
# 预测结果 (index 2650): 0--0
# 制定学习计划安排，有序推进学习
# 预测结果 (index 2651): 0--0
# 产品优势突出显著提升竞争力
# 预测结果 (index 2652): 0--0
# 恶心+的+妈妈+给+恶心+开门+、+恶心+到家+了+…+…
# 预测结果 (index 2653): 1--1
# 挺|逗
# 预测结果 (index 2654): 1--1
# 励志用奋斗与坚持成就更好的自己创造美好未来实现人生梦想丰富人生的追求与目标
# 预测结果 (index 2655): 0--0
# 观点很有价值.学习了
# 预测结果 (index 2656): 0--0
# 好家伙-，-你-自己-拍-全家福-挺-孤单-吧
# 预测结果 (index 2657): 0--1
# 怎么不说话了 si吃太多堵住了？
# 预测结果 (index 2658): 1--1
# 欢乐的烧烤派对享受美食与欢乐的社交时光
# 预测结果 (index 2659): 0--0
# 你的智商跟跟冬天黑龙江的温度一样。
# 预测结果 (index 2660): 1--1
# 请问您对这个方案有何建议?
# 预测结果 (index 2661): 0--0
# 伪球迷
# 预测结果 (index 2662): 1--1
# 如果的丑也算残疾的话，那你就不用工作了。
# 预测结果 (index 2663): 1--1
# 商业合作互惠互利共同发展
# 预测结果 (index 2664): 0--0
# 真老狗
# 预测结果 (index 2665): 1--1
# 最蠢
# 预测结果 (index 2666): 1--1
# 高血压病的发病机制包括遗传因素和环境因素的相互作用
# 预测结果 (index 2667): 0--0
# 真特码
# 预测结果 (index 2668): 1--1
# 他特吧
# 预测结果 (index 2669): 1--1
# 医院开展医院精细化管理，提高医院管理效能
# 预测结果 (index 2670): 0--0
# 你想多了啊
# 预测结果 (index 2671): 1--1
# 非常祝你们不孕不育，儿孙满堂。
# 预测结果 (index 2672): 0--1
# 瞧不起
# 预测结果 (index 2673): 1--1
# 医院开展医院医疗服务质量提升行动宣传活动，营造良好的医疗服务质量提升氛围
# 预测结果 (index 2674): 0--0
# 真姑娘啊
# 预测结果 (index 2675): 1--1
# 太自嗨
# 预测结果 (index 2676): 1--1
# 我们会一起去河边钓鱼，享受宁静的时光，感受大自然的美好，放松自己的身心，缓解压力和疲劳
# 预测结果 (index 2677): 0--0
# 怎么不说话了 屎吃太多堵住？
# 预测结果 (index 2678): 1--1
# 瓜婆娘
# 预测结果 (index 2679): 1--1
# 暖心的好文章.感谢
# 预测结果 (index 2680): 0--0
# 真真牛逼
# 预测结果 (index 2681): 1--1
# 极品渣男
# 预测结果 (index 2682): 1--1
# 真挺逗
# 预测结果 (index 2683): 1--1
# 我-真的-很-想-帮-你-治疗-，-但-我-是-一名-家庭医生-，-而-你-是-一个-孤儿-。
# 预测结果 (index 2684): 0--1
# 逼逼
# 预测结果 (index 2685): 1--1
# 去看猪圈都不用跑趟农村，去你家里就行了。
# 预测结果 (index 2686): 1--1
# 医院提升医院医疗技术水平和服务能力，满足人民群众日益增长的医疗服务需求
# 预测结果 (index 2687): 0--0
# 你家开的火葬场是用来自娱自乐的吗？
# 预测结果 (index 2688): 1--1
# 好记得下点调料，这样你家人吃起来才会有味道
# 预测结果 (index 2689): 0--1
# 特别牛吧
# 预测结果 (index 2690): 1--1
# 苦逼脸
# 预测结果 (index 2691): 1--1
# 特爱吧
# 预测结果 (index 2692): 0--1
# 真想把你的头扭下来放在洗衣机里搅一搅，刚好能洗一缸衣服，虽然有点臭，但节约水资源源刻不容缓。
# 预测结果 (index 2693): 0--1
# 逗比
# 预测结果 (index 2694): 1--1
# 情感真挚.写得很好
# 预测结果 (index 2695): 0--0
# 你_的_智商_跟_冬天_黑龙江_的_温度_一样_。
# 预测结果 (index 2696): 1--1
# 制药企业提升药品包装质量，增强产品市场竞争力
# 预测结果 (index 2697): 0--0
# 医疗护理服务模式创新满足患者需求
# 预测结果 (index 2698): 0--0
# 太你屌
# 预测结果 (index 2699): 1--1
# 进度: 2700/2856
# ！这是谁裤裆门没拉，怎么把你漏出来了？
# 预测结果 (index 2700): 1--1
# 你脖子上长的是什么，公共厕所吗？你鼻子下长的是什么，屎壳郎之家吗？
# 预测结果 (index 2701): 1--1
# 恶心的妈妈给恶心开门、恶心到家了……了
# 预测结果 (index 2702): 1--1
# 医疗护理服务技术创新提高护理质量
# 预测结果 (index 2703): 0--0
# 骂他
# 预测结果 (index 2704): 1--1
# 感谢您的支持与信任
# 预测结果 (index 2705): 0--0
# 你-再-骂-？-信不信-👴-把-你-脑袋-拧下来-当-夜壶-？-！
# 预测结果 (index 2706): 1--1
# 你再骂？信不信👴把你脑袋拧下来当夜壶！
# 预测结果 (index 2707): 1--1
# 那个生
# 预测结果 (index 2708): 1--1
# 好家伙，你自己拍全家福挺孤单吧吧
# 预测结果 (index 2709): 1--1
# 认真完成课程设计，锻炼实践能力
# 预测结果 (index 2710): 0--0
# 美术作品展示独具匠心展现艺术风格
# 预测结果 (index 2711): 0--0
# 我不想和狗吵架。
# 预测结果 (index 2712): 1--1
# 注孤了
# 预测结果 (index 2713): 1--1
# 朋友常相聚
# 预测结果 (index 2714): 0--0
# dia
# 预测结果 (index 2715): 1--1
# 制杖啊
# 预测结果 (index 2716): 1--1
# 你的智商跟冬天黑江的温度一样。
# 预测结果 (index 2717): 1--1
# 我的天呐,,你一定是吃了放在肮脏的桌子上的发霉的绿色面包,才会眨着美丽的大眼睛说出长沙臭豆腐一样臭的话!
# 预测结果 (index 2718): 1--1
# 那个~女生
# 预测结果 (index 2719): 1--1
# 我们期待继续为您服务
# 预测结果 (index 2720): 0--0
# 没-人理
# 预测结果 (index 2721): 1--1
# 盆腔炎的治疗需综合使用抗生素、中药等多种方法
# 预测结果 (index 2722): 0--0
# 你看上去好眼熟我昨天扔出去的那袋垃圾
# 预测结果 (index 2723): 1--1
# 医院加强医院医疗安全管理教育培训长效机制建设，不断提高医务人员的医疗安全意识和能力
# 预测结果 (index 2724): 0--0
# 真那个女生
# 预测结果 (index 2725): 1--1
# 坑货
# 预测结果 (index 2726): 1--1
# 挫人
# 预测结果 (index 2727): 1--1
# 戏剧表演精彩动人演员演技精湛
# 预测结果 (index 2728): 0--0
# 请问您需要什么具体信息?
# 预测结果 (index 2729): 0--0
# 好家伙|，|你|自己|拍|全家福|挺|孤单|吧
# 预测结果 (index 2730): 0--1
# 返祖现象在你身上贯彻的很彻底嘛，尤其是脑子
# 预测结果 (index 2731): 0--1
# 好你是我见过的容量最大的铅笔盒了，装那么多笔你不累吗？
# 预测结果 (index 2732): 0--1
# 我会好好孝顺你们
# 预测结果 (index 2733): 0--0
# 真瞧不起
# 预测结果 (index 2734): 1--1
# 我们要向前,不错过些歪瓜劣枣怎么知道什么是好的。
# 预测结果 (index 2735): 1--1
# 仔细~看看~我~这~巴掌~真~适合~你~那大~脸
# 预测结果 (index 2736): 1--1
# 自找罪受
# 预测结果 (index 2737): 1--1
# 真我的天呐,你一定是吃了放在肮脏的桌子上的发霉的绿色面包,才会眨着美丽的大眼睛说出长沙臭豆腐一样臭的话!
# 预测结果 (index 2738): 1--1
# gay
# 预测结果 (index 2739): 1--1
# 余生请你指教
# 预测结果 (index 2740): 0--0
# 艺术展览特色鲜明吸引观众目光
# 预测结果 (index 2741): 0--0
# 我*笑*了
# 预测结果 (index 2742): 1--1
# Medical nursing humanities cares for patients' psychological needs. Medical nursing humanities: medical nursing humanities; psychological needs: psychological needs
# 预测结果 (index 2743): 0--0
# 非常特别牛
# 预测结果 (index 2744): 1--1
# 大|尾巴|狼
# 预测结果 (index 2745): 1--1
# 姑娘.啊
# 预测结果 (index 2746): 1--1
# 你这种人永远买不到自己适的鞋 因为你码没了
# 预测结果 (index 2747): 1--1
# 请问您觉得还需要补充吗?
# 预测结果 (index 2748): 0--0
# 医疗保障更加健全
# 预测结果 (index 2749): 0--0
# 医学研究需要加强对罕见病的研究和治疗
# 预测结果 (index 2750): 0--0
# 参加专业进修课程，提升专业能力
# 预测结果 (index 2751): 0--0
# 那个女生呢
# 预测结果 (index 2752): 1--1
# 愿与你友谊长存
# 预测结果 (index 2753): 0--0
# 是这世间间的黑暗，造就了你不懂礼数的浅薄。
# 预测结果 (index 2754): 1--1
# 充满爱意的文字.很棒
# 预测结果 (index 2755): 0--0
# 好家伙，你自己己拍全家福挺孤单吧
# 预测结果 (index 2756): 1--1
# 你想了
# 预测结果 (index 2757): 1--1
# 大~尾巴~狼
# 预测结果 (index 2758): 1--1
# 欢乐的新年庆祝活动充满希望与祝福迎接新的一年
# 预测结果 (index 2759): 0--0
# 高端 黑
# 预测结果 (index 2760): 1--1
# 被分手了
# 预测结果 (index 2761): 0--1
# 恶心 的 妈妈 给 恶心 开门 、 恶心 到家 了 … …
# 预测结果 (index 2762): 1--1
# 我真的很想帮你治疗，但我是一名家庭医生，而你是一个孤孤儿。
# 预测结果 (index 2763): 0--1
# 真是这世间的黑暗，造就了你不懂礼数的浅薄。
# 预测结果 (index 2764): 1--1
# 民间艺术展示独具魅力传承古老文化
# 预测结果 (index 2765): 0--0
# 你.脖子.上顶.的.是.肿瘤.吧
# 预测结果 (index 2766): 1--1
# 看你儿子是做老师的，天天去爬山
# 预测结果 (index 2767): 0--1
# 特别你是我见过的容量最大的铅笔盒了，装那么多笔你不累吗？
# 预测结果 (index 2768): 0--1
# 你.再.骂.？.信不信.👴.把.你.脑袋.拧下来.当.夜壶.？.！
# 预测结果 (index 2769): 1--1
# 大_尾巴_狼
# 预测结果 (index 2770): 1--1
# 她每天都会做一些简单的运动，保持良好的身体状态
# 预测结果 (index 2771): 0--0
# 音乐演出活力满满听众热情高涨
# 预测结果 (index 2772): 0--0
# 自 嗨
# 预测结果 (index 2773): 1--1
# 自-嗨
# 预测结果 (index 2774): 1--1
# 教育改革更加深化
# 预测结果 (index 2775): 0--0
# 《生产管理方案》：优化生产流程，提高生产效率和产品质量
# 预测结果 (index 2776): 0--0
# 我们期待为您提供服务
# 预测结果 (index 2777): 0--0
# 祝你们们不孕不育，儿孙满堂。
# 预测结果 (index 2778): 0--1
# 你屌呢
# 预测结果 (index 2779): 1--1
# 逻辑很严密.收获很多
# 预测结果 (index 2780): 0--0
# 摄影活动视角独特记录精彩瞬间
# 预测结果 (index 2781): 0--0
# 医疗护理应急救援创新保障公共安全
# 预测结果 (index 2782): 0--0
# 没人理吧
# 预测结果 (index 2783): 1--1
# 自找-虐
# 预测结果 (index 2784): 1--1
# 生态保护更加有效
# 预测结果 (index 2785): 0--0
# 要脸
# 预测结果 (index 2786): 1--1
# 音乐晚会气氛热烈听众尽情享受
# 预测结果 (index 2787): 0--0
# 女汉子吧
# 预测结果 (index 2788): 1--1
# 财务状况稳健良好支持发展
# 预测结果 (index 2789): 0--0
# 就是#嫉妒#我#户口本#可以#翻页#（#说#他#是#孤儿#）
# 预测结果 (index 2790): 1--1
# 真记得下点调料，这样你家人吃起来才会有味道
# 预测结果 (index 2791): 0--1
# 挺逗的
# 预测结果 (index 2792): 0--1
# 瞎搞
# 预测结果 (index 2793): 1--1
# 姑娘#啊
# 预测结果 (index 2794): 1--1
# 立牌坊
# 预测结果 (index 2795): 0--1
# 文艺狗
# 预测结果 (index 2796): 1--1
# 采用问卷调查收集数据时，问卷的设计要科学合理
# 预测结果 (index 2797): 0--0
# 我真的很想帮你治疗，但我是一名家庭医生，而你是一个孤儿。的
# 预测结果 (index 2798): 0--1
# 我的天呐,你一定是吃了放在肮脏的桌子上的发霉的绿绿色面包,才会眨着美丽的大眼睛说出长沙臭豆腐一样臭的话!
# 预测结果 (index 2799): 1--1
# 进度: 2800/2856
# 艰不拆啊
# 预测结果 (index 2800): 1--1
# 字里行间都是温度.棒
# 预测结果 (index 2801): 0--0
# 艺术展览互动性强观众参与度高
# 预测结果 (index 2802): 0--0
# 加速科研成果转化
# 预测结果 (index 2803): 0--0
# 字里行间都是温暖.喜欢
# 预测结果 (index 2804): 0--0
# 瞅你写那两个破壁字吧，跟几把刚当人类没进化好似的
# 预测结果 (index 2805): 1--1
# 商务合作平等友好共同进步
# 预测结果 (index 2806): 0--0
# 没品
# 预测结果 (index 2807): 1--1
# 真酷，是吗
# 预测结果 (index 2808): 1--0
# 你屌的
# 预测结果 (index 2809): 1--1
# 被|分手
# 预测结果 (index 2810): 1--1
# 真牛币
# 预测结果 (index 2811): 1--1
# 不作 不 死
# 预测结果 (index 2812): 1--1
# 财务管理规范确保资金安全
# 预测结果 (index 2813): 0--0
# 太艰不拆
# 预测结果 (index 2814): 1--1
# 虽然大脑和大肠长的挺像，但也不要什么都往里面装。对不起，忘了你没大脑。
# 预测结果 (index 2815): 1--1
# 特别你这种人永远买不到自己合适的鞋 因为你码没了
# 预测结果 (index 2816): 1--1
# 砍死_他
# 预测结果 (index 2817): 1--1
# 医疗护理消毒灭菌创新确保护理安全
# 预测结果 (index 2818): 0--0
# 祝你们不孕不育，儿孙满堂。了
# 预测结果 (index 2819): 0--1
# 太不作不死
# 预测结果 (index 2820): 1--1
# 医疗服务更加优化
# 预测结果 (index 2821): 0--0
# 医用耗材满足医疗需求
# 预测结果 (index 2822): 0--0
# 仔细看看我这巴掌真适合你那大脸啊
# 预测结果 (index 2823): 1--1
# 特爱
# 预测结果 (index 2824): 0--1
# 仔细_看看_我_这_巴掌_真_适合_你_那大_脸
# 预测结果 (index 2825): 1--1
# 我 笑 了
# 预测结果 (index 2826): 0--1
# 你怕是中华剑术凝聚而成的产物将中国所有的剑结合在一起俗称贱人
# 预测结果 (index 2827): 1--1
# 恶心的妈妈给恶心开门、恶心到家了……的
# 预测结果 (index 2828): 1--1
# 发癫
# 预测结果 (index 2829): 1--1
# 曾经我
# 预测结果 (index 2830): 0--1
# 特烦呢
# 预测结果 (index 2831): 1--1
# 自|嗨
# 预测结果 (index 2832): 1--1
# 你+脖子+上顶+的+是+肿瘤+吧
# 预测结果 (index 2833): 1--1
# 特别大尾巴狼
# 预测结果 (index 2834): 1--1
# 心怀感恩.快乐生活
# 预测结果 (index 2835): 0--0
# 传统文化活动内涵丰富传承历史智慧
# 预测结果 (index 2836): 0--0
# 《绩效考核方案》：激励员工积极性，提高工作绩效
# 预测结果 (index 2837): 0--0
# 研究的局限性应在论文中明确指出
# 预测结果 (index 2838): 0--0
# 呦！这是谁裤裆门没拉，怎么把你漏出来了？
# 预测结果 (index 2839): 1--1
# 砍死他啊
# 预测结果 (index 2840): 1--1
# 主动学习新知识，适应行业变化
# 预测结果 (index 2841): 0--0
# 同学们共同参与课程实践，提高实践能力
# 预测结果 (index 2842): 0--0
# 特特烦
# 预测结果 (index 2843): 1--1
# 真想*把*你*的*头*扭*下来*放在*洗衣机*里*搅*一*搅*，*刚好*能*洗*一缸*衣服*，*虽然*有点*臭*，*但*节约*水资源*刻不容缓*。
# 预测结果 (index 2844): 1--1
# 读完心里百感交集
# 预测结果 (index 2845): 0--0
# 狗……啊
# 预测结果 (index 2846): 1--1
# 励志用奋斗和拼搏书写人生壮丽篇章
# 预测结果 (index 2847): 0--0
# 没品味
# 预测结果 (index 2848): 1--1
# 合作前景光明灿烂充满希望
# 预测结果 (index 2849): 0--0
# 我们的情谊最真诚
# 预测结果 (index 2850): 0--0
# 我~笑~了
# 预测结果 (index 2851): 1--1
# 医疗护理服务人性化关注患者感受
# 预测结果 (index 2852): 0--0
# 傻瓜
# 预测结果 (index 2853): 1--1
# 你#脖子#上顶#的#是#肿瘤#吧
# 预测结果 (index 2854): 1--1
# 市场调研全面客观掌握信息
# 预测结果 (index 2855): 0--0
#
# === 评估结果 ===
#
# 分类报告:
#               precision    recall  f1-score   support
#
#            0       0.80      1.00      0.89       952
#            1       1.00      0.87      0.93      1904
#
#     accuracy                           0.91      2856
#    macro avg       0.90      0.93      0.91      2856
# weighted avg       0.93      0.91      0.92      2856
#
#
# 混淆矩阵:
# [[ 949    3]
#  [ 243 1661]]
#
# 模型性能统计:
# 总样本数: 2856
# 准确率: 0.9139
# 平均置信度: 0.9478
#
# 错误预测分析:
#
# 高置信度错误案例:
#
# 文本: 记得下点调料，这样你家人吃起来才会有味道的
# 真实标签: 1
# 预测标签: 0
# 置信度: 0.9946
#
# 文本: 非常记得下点调料，这样你家人吃起来才会有味道
# 真实标签: 1
# 预测标签: 0
# 置信度: 0.9946
#
# 文本: 记得下点调料，这样家人吃起来才会有味道
# 真实标签: 1
# 预测标签: 0
# 置信度: 0.9940
#
# 文本: 记得下点调料，这样你家人吃起来才会有味道了
# 真实标签: 1
# 预测标签: 0
# 置信度: 0.9940
#
# 文本: 记得下点调料，这样你家人吃起来才会有味道道
# 真实标签: 1
# 预测标签: 0
# 置信度: 0.9939
# 评估结果已保存到 model_evaluation_results-3.csv

# %%
# !source ../ven
